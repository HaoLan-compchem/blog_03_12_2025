# %%
import copy
import openmm as mm
from openmm import app, unit
from openmm.app import PDBFile

# %%
with open('system_with_ligand_only.xml', 'r') as f:
    system_1 = mm.XmlSerializer.deserialize(f.read())
pdb = PDBFile('ligand_in_solvent.pdb')
system_1.addForce(mm.MonteCarloBarostat(1*unit.atmosphere, 300*unit.kelvin))
system_1.getForces()
# Out:
# [<openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x783563605ef0> >,
#  <openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x783560341020> >,
#  <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x783560341110> >,
#  <openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x783560341050> >,
#  <openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x783560340f90> >,
#  <openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x783560340e10> >]

# %%
ligand = list(pdb.topology.residues())[0]
rest_atoms = [atom.index for atom in ligand.atoms()]
len(rest_atoms)
# Out:
# 151

# %%
# Create REST system
rest_system = mm.System()
# Create dict of vanilla system forces (for easy retrieval of force objects later)
system_forces = {type(force).__name__ : force for force in system_1.getForces()}

# Add particles
for particle_idx in range(system_1.getNumParticles()):
    particle_mass = system_1.getParticleMass(particle_idx)
    rest_system.addParticle(particle_mass)

# Copy barostat
if "MonteCarloBarostat" in system_forces:
    barostat = copy.deepcopy(system_forces["MonteCarloBarostat"])
    rest_system.addForce(barostat)

# Copy box vectors
box_vectors = system_1.getDefaultPeriodicBoxVectors()
rest_system.setDefaultPeriodicBoxVectors(*box_vectors)

# Copy constraints
for constraint_idx in range(system_1.getNumConstraints()):
    atom1, atom2, length = system_1.getConstraintParameters(constraint_idx)
    rest_system.addConstraint(atom1, atom2, length)

# %%
# Define the custom expression
bond_expression = "rest_scale * (K / 2) * (r - length)^2;"
bond_expression += "rest_scale = is_rest * lambda_rest_bonds * lambda_rest_bonds " \
                   "+ is_inter * lambda_rest_bonds " \
                   "+ is_nonrest;"

# Create custom force
rest_bond_force = mm.CustomBondForce(bond_expression)
rest_system.addForce(rest_bond_force)

# Add global parameters
rest_bond_force.addGlobalParameter("lambda_rest_bonds", 1.0)

# Add per-bond parameters for rest scaling
rest_bond_force.addPerBondParameter("is_rest")
rest_bond_force.addPerBondParameter("is_inter")
rest_bond_force.addPerBondParameter("is_nonrest")

# Add per-bond parameters for defining bond energy
rest_bond_force.addPerBondParameter('length')  # equilibrium bond length
rest_bond_force.addPerBondParameter('K')  # force constant
# Out:
# 4

# %%
def get_rest_identifier(atoms, rest_atoms):
    """
    For a given atom or set of atoms, get the rest_id which is a list of binary ints that defines which
    (mutually exclusive) set the atom(s) belong to.

    If there is a single atom, the sets are: is_rest, is_nonrest
    If there is a set of atoms, the sets are: is_rest, is_inter, is_nonrest

    Example: if there is a single atom that is in the nonrest set, the rest_id is [0, 1]

    Arguments
    ---------
    atoms : set or int
        a set of hybrid atom indices or single atom
    rest_atoms : set or list
        a list (or list-like) of atoms whose interactions will be scaled by REST
    Returns
    -------
    rest_id : list
        list of binaries indicating which set the atom(s) belong to
    """

    if isinstance(atoms, int):
        rest_id = [0, 1] # Set the default rest_id to non-REST
        if atoms in rest_atoms:
            rest_id = [1, 0]
        return rest_id

    elif isinstance(atoms, set):
        rest_id = [0, 0, 1] # Set the default rest_id to non-REST
        if atoms.intersection(rest_atoms) != set(): # At least one of the atoms is REST
            if atoms.issubset(rest_atoms): # All atoms are REST
                rest_id = [1, 0, 0]
            else: # At least one (but not all) of the atoms is are REST
                rest_id = [0, 1, 0]
        return rest_id

    else:
        raise Exception(f"atoms is of type {type(atoms)}, but only `int` and `set` are allowable")

# %%
# Get vanilla system bond force
bond_force = system_forces['HarmonicBondForce']

# Set periodicity
if bond_force.usesPeriodicBoundaryConditions():
    rest_bond_force.setUsesPeriodicBoundaryConditions(True)

# Add bonds to rest_system
for term_idx in range(bond_force.getNumBonds()):
    # Get the bond parameters and rest id
    p1, p2, r0, k = bond_force.getBondParameters(term_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add the bond
    bond_term = (p1, p2, rest_id + [r0, k])
    rest_bond_force.addBond(*bond_term)

# %%
# Define the custom expression
angle_expression = "rest_scale * (K / 2) * (theta - theta0)^2;"
angle_expression += "rest_scale = is_rest * lambda_rest_angles * lambda_rest_angles " \
                    "+ is_inter * lambda_rest_angles " \
                    "+ is_nonrest;"

# Create custom force
rest_angle_force = mm.CustomAngleForce(angle_expression)
rest_system.addForce(rest_angle_force)

# Add global parameters
rest_angle_force.addGlobalParameter("lambda_rest_angles", 1.0)

# Add per-angle parameters for rest scaling
rest_angle_force.addPerAngleParameter("is_rest")
rest_angle_force.addPerAngleParameter("is_inter")
rest_angle_force.addPerAngleParameter("is_nonrest")

# Add per-angle parameters for defining angle energy
rest_angle_force.addPerAngleParameter('theta0')  # equilibrium angle
rest_angle_force.addPerAngleParameter('K')  # force constant

# Get vanilla system angle force
angle_force = system_forces['HarmonicAngleForce']

# Set periodicity
if angle_force.usesPeriodicBoundaryConditions():
    rest_angle_force.setUsesPeriodicBoundaryConditions(True)

# Add angles to rest_system
for term_idx in range(angle_force.getNumAngles()):
    # Get the angle parameters and rest id
    p1, p2, p3, theta0, k = angle_force.getAngleParameters(term_idx)
    idx_set = set([p1, p2, p3])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add the angle
    angle_term = (p1, p2, p3, rest_id + [theta0, k])
    rest_angle_force.addAngle(*angle_term)

# %%
# Define the custom expression
torsion_expression = "rest_scale * U;"
torsion_expression += "rest_scale = is_rest * lambda_rest_torsions * lambda_rest_torsions " \
                      "+ is_inter * lambda_rest_torsions " \
                      "+ is_nonrest;"
torsion_expression += "U = (K * (1 + cos(periodicity * theta - phase)));"

# Create custom force
rest_torsion_force = mm.CustomTorsionForce(torsion_expression)
rest_system.addForce(rest_torsion_force)

# Add global parameters
rest_torsion_force.addGlobalParameter("lambda_rest_torsions", 1.0)

# Add per-torsion parameters for rest scaling
rest_torsion_force.addPerTorsionParameter("is_rest")
rest_torsion_force.addPerTorsionParameter("is_inter")
rest_torsion_force.addPerTorsionParameter("is_nonrest")

# Add per-torsion parameters for defining torsion energy
rest_torsion_force.addPerTorsionParameter('periodicity')
rest_torsion_force.addPerTorsionParameter('phase') # phase offset
rest_torsion_force.addPerTorsionParameter('K') # force constant

# Get vanilla system torsion force
torsion_force = system_forces['PeriodicTorsionForce']

# Set periodicity
if torsion_force.usesPeriodicBoundaryConditions():
    rest_torsion_force.setUsesPeriodicBoundaryConditions(True)

# Add torsions to rest_system
for torsion_idx in range(torsion_force.getNumTorsions()):
    # Get the torsion parameters and rest id
    p1, p2, p3, p4, periodicity, phase, K = torsion_force.getTorsionParameters(torsion_idx)
    idx_set = set([p1, p2, p3, p4])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add torsion
    torsion_term = (p1, p2, p3, p4, rest_id + [periodicity, phase, K])
    rest_torsion_force.addTorsion(*torsion_term)

# %%
# Create nonbonded force
rest_nonbonded_force = mm.NonbondedForce()
rest_system.addForce(rest_nonbonded_force)

# Get vanilla system nonbonded force
nonbonded_force = system_forces['NonbondedForce']

# Set the nonbonded method and related parameters
nonbonded_method = nonbonded_force.getNonbondedMethod()
rest_nonbonded_force.setNonbondedMethod(nonbonded_method)
if nonbonded_method != mm.NonbondedForce.NoCutoff:
    epsilon_solvent = nonbonded_force.getReactionFieldDielectric()
    cutoff = nonbonded_force.getCutoffDistance()
    rest_nonbonded_force.setReactionFieldDielectric(epsilon_solvent)
    rest_nonbonded_force.setCutoffDistance(cutoff)
if nonbonded_method in [mm.NonbondedForce.PME, mm.NonbondedForce.Ewald]:
    [alpha_ewald, nx, ny, nz] = nonbonded_force.getPMEParameters()
    delta = nonbonded_force.getEwaldErrorTolerance()
    rest_nonbonded_force.setPMEParameters(alpha_ewald, nx, ny, nz)
    rest_nonbonded_force.setEwaldErrorTolerance(delta)

# Copy switching function from vanilla system
switch_bool = nonbonded_force.getUseSwitchingFunction()
rest_nonbonded_force.setUseSwitchingFunction(switch_bool)
if switch_bool:
    switching_distance = nonbonded_force.getSwitchingDistance()
    rest_nonbonded_force.setSwitchingDistance(switching_distance)

# Copy dispersion correction
dispersion_bool = nonbonded_force.getUseDispersionCorrection()
rest_nonbonded_force.setUseDispersionCorrection(dispersion_bool)

# Add global parameters
rest_nonbonded_force.addGlobalParameter('lambda_rest_electrostatics', 0.)
rest_nonbonded_force.addGlobalParameter('lambda_rest_sterics', 0.)
# Out:
# 1

# %%
# Add nonbondeds to rest_system
for particle_idx in range(nonbonded_force.getNumParticles()):
    # Get the nonbonded parameters and rest id
    q, sigma, epsilon = nonbonded_force.getParticleParameters(particle_idx)
    rest_id = get_rest_identifier(particle_idx, rest_atoms)

    # Add particles and offsets
    if rest_id == [0, 1]: # nonrest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)

    else: # rest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_electrostatics', particle_idx, q, 0.0*sigma, epsilon*0.0)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_sterics', particle_idx, q*0.0, 0.0*sigma, epsilon)

# Handle exceptions
for exception_idx in range(nonbonded_force.getNumExceptions()):
    # Get exception parameters and rest id
    p1, p2, chargeProd, sigma, epsilon = nonbonded_force.getExceptionParameters(exception_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add exceptions and offsets
    exc_idx = rest_nonbonded_force.addException(p1, p2, chargeProd, sigma, epsilon)
    if rest_id == [0, 0, 1]: # nonrest
        pass

    elif rest_id == [1, 0, 0]: # rest
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_sterics', exc_idx, chargeProd, 0.0*sigma, epsilon)

    elif rest_id == [0, 1, 0]: # inter
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_electrostatics', exc_idx, chargeProd, 0.0*sigma, epsilon)

# %%
import math
import logging
import numpy as np
from openmmtools.constants import kB
from openmmtools import cache, mcmc, multistate
from openmmtools.multistate import ReplicaExchangeSampler
from openmmtools.states import GlobalParameterState, SamplerState, ThermodynamicState, CompoundThermodynamicState

# %%
class RESTState(GlobalParameterState):
    lambda_rest_bonds = GlobalParameterState.GlobalParameter('lambda_rest_bonds', standard_value=1.0)
    lambda_rest_angles = GlobalParameterState.GlobalParameter('lambda_rest_angles', standard_value=1.0)
    lambda_rest_torsions = GlobalParameterState.GlobalParameter('lambda_rest_torsions', standard_value=1.0)
    lambda_rest_electrostatics = GlobalParameterState.GlobalParameter('lambda_rest_electrostatics', standard_value=0.0)
    lambda_rest_sterics = GlobalParameterState.GlobalParameter('lambda_rest_sterics', standard_value=0.0)

    def set_rest_parameters(self, beta_m, beta_0):
        """Set all defined lambda parameters to the given value.

        The undefined parameters (i.e. those being set to None) remain undefined.

        Parameters
        ----------
        new_value : float
            The new value for all defined parameters.
        """
        lambda_functions = {'lambda_rest_bonds': lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_angles' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_torsions' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_electrostatics' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0) - 1,
                 'lambda_rest_sterics' : lambda beta_m, beta_0 : beta_m / beta_0 - 1
                 }

        for parameter_name in self._parameters:
            if self._parameters[parameter_name] is not None:
                new_value = lambda_functions[parameter_name](beta_m, beta_0)
                setattr(self, parameter_name, new_value)

# %% [markdown]
# Need set temperatures for replicas

# %%
# Set temperatures for each thermodynamic state
n_replicas = 12  # Number of temperature replicas
T_min = 300 * unit.kelvin  # Minimum temperature (i.e., temperature of desired distribution)
T_max = 600 * unit.kelvin  # Maximum temperature
temperatures = [T_min + (T_max - T_min) * (math.exp(float(i) / float(n_replicas-1)) - 1.0) / (math.e - 1.0)
                for i in range(n_replicas)]
temperatures
# Out:
# [Quantity(value=300.0, unit=kelvin),
#  Quantity(value=316.61591916385663, unit=kelvin),
#  Quantity(value=334.8131660475402, unit=kelvin),
#  Quantity(value=354.74223472440497, unit=kelvin),
#  Quantity(value=376.5679417044706, unit=kelvin),
#  Quantity(value=400.4707889926977, unit=kelvin),
#  Quantity(value=426.6484568687549, unit=kelvin),
#  Quantity(value=455.31743873380157, unit=kelvin),
#  Quantity(value=486.7148315447216, unit=kelvin),
#  Quantity(value=521.1002966429818, unit=kelvin),
#  Quantity(value=558.758207194473, unit=kelvin),
#  Quantity(value=600.0, unit=kelvin)]

# %%
# Create reference thermodynamic state
rest_state = RESTState.from_system(rest_system)
thermostate = ThermodynamicState(rest_system, temperature=T_min)
compound_thermodynamic_state = CompoundThermodynamicState(thermostate, composable_states=[rest_state])

# %%
# Create thermodynamic states
sampler_state =  SamplerState(pdb.positions, box_vectors=rest_system.getDefaultPeriodicBoxVectors())
beta_0 = 1/(kB*T_min)
thermodynamic_state_list = []
sampler_state_list = []
for temperature in temperatures:
    # Create a thermodynamic state with REST interactions scaled to the given temperature
    beta_m = 1/(kB*temperature)
    compound_thermodynamic_state_copy = copy.deepcopy(compound_thermodynamic_state)
    compound_thermodynamic_state_copy.set_rest_parameters(beta_m, beta_0)
    thermodynamic_state_list.append(compound_thermodynamic_state_copy)

    # Generate a sampler_state with minimized positions
    context, integrator = cache.global_context_cache.get_context(compound_thermodynamic_state_copy)
    sampler_state.apply_to_context(context, ignore_velocities=True)
    mm.LocalEnergyMinimizer.minimize(context)
    sampler_state.update_from_context(context)
    sampler_state_list.append(copy.deepcopy(sampler_state))

# %% [markdown]
# setting mcmc move interval and iteration numbers

# %%
# Set up sampler
_logger = logging.getLogger()
_logger.setLevel(logging.DEBUG)
move = mcmc.LangevinDynamicsMove(timestep=2*unit.femtoseconds, n_steps=500)
simulation = ReplicaExchangeSampler(mcmc_moves=move, number_of_iterations=5000)

# Run repex
reporter_file = "test_run.nc"
reporter = multistate.MultiStateReporter(reporter_file)
simulation.create(thermodynamic_states=thermodynamic_state_list,
                  sampler_states=sampler_state_list,
                  storage=reporter)
simulation.run()
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Please cite the following:
#
#         Friedrichs MS, Eastman P, Vaidyanathan V, Houston M, LeGrand S, Beberg AL, Ensign DL, Bruns CM, and Pande VS. Accelerating molecular dynamic simulations on graphics processing unit. J. Comput. Chem. 30:864, 2009. DOI: 10.1002/jcc.21209
#         Eastman P and Pande VS. OpenMM: A hardware-independent framework for molecular simulations. Comput. Sci. Eng. 12:34, 2010. DOI: 10.1109/MCSE.2010.27
#         Eastman P and Pande VS. Efficient nonbonded interactions for molecular dynamics on a graphics processing unit. J. Comput. Chem. 31:1268, 2010. DOI: 10.1002/jcc.21413
#         Eastman P and Pande VS. Constant constraint matrix approximation: A robust, parallelizable constraint method for molecular simulations. J. Chem. Theor. Comput. 6:434, 2010. DOI: 10.1021/ct900463w
#         Chodera JD and Shirts MR. Replica exchange and expanded ensemble simulations as Gibbs multistate: Simple improvements for enhanced mixing. J. Chem. Phys., 135:194110, 2011. DOI:10.1063/1.3660669
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# DEBUG:2025-09-14 15:39:52,616:jax._src.dispatch:198: Finished tracing + transforming _reduce_min for pjit in 0.000722408 sec
# DEBUG:2025-09-14 15:39:52,618:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000356913 sec
# DEBUG:2025-09-14 15:39:52,619:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000190496 sec
# DEBUG:2025-09-14 15:39:52,620:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000199080 sec
# DEBUG:2025-09-14 15:39:52,621:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001331329 sec
# DEBUG:2025-09-14 15:39:52,622:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000070333 sec
# DEBUG:2025-09-14 15:39:52,622:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000337124 sec
# DEBUG:2025-09-14 15:39:52,623:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000105143 sec
# DEBUG:2025-09-14 15:39:52,624:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000205278 sec
# DEBUG:2025-09-14 15:39:52,625:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000140429 sec
# DEBUG:2025-09-14 15:39:52,626:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.000814676 sec
# DEBUG:2025-09-14 15:39:52,627:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000216722 sec
# DEBUG:2025-09-14 15:39:52,628:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000218391 sec
# DEBUG:2025-09-14 15:39:52,628:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.000987530 sec
# DEBUG:2025-09-14 15:39:52,629:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000129461 sec
# DEBUG:2025-09-14 15:39:52,629:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000219107 sec
# DEBUG:2025-09-14 15:39:52,630:jax._src.dispatch:198: Finished tracing + transforming jax_precondition_u_kn for pjit in 0.014565468 sec
# DEBUG:2025-09-14 15:39:52,631:jax._src.interpreters.pxla:1865: Compiling jax_precondition_u_kn with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(float64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,636:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_precondition_u_kn) in 0.004648685 sec
# DEBUG:2025-09-14 15:39:52,637:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,637:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,638:jax._src.cache_key:156: get_cache_key hash of serialized computation: 503160d8cdf853eb84e4b8f102fca35fe3f164bd013462eaceca4118f1c316d0
# DEBUG:2025-09-14 15:39:52,638:jax._src.cache_key:162: get_cache_key hash after serializing computation: 503160d8cdf853eb84e4b8f102fca35fe3f164bd013462eaceca4118f1c316d0
# DEBUG:2025-09-14 15:39:52,639:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,639:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: d8e5ecfc108a7d6e960b481abdcfc0f6c748f3e65d8f91ce18dba6b60a2a6bc9
# DEBUG:2025-09-14 15:39:52,639:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,639:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 849ec64ba3cc08d8466bc6e5a95d8117e3f7346c5248330f83bb1b37613e077e
# DEBUG:2025-09-14 15:39:52,640:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,640:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 849ec64ba3cc08d8466bc6e5a95d8117e3f7346c5248330f83bb1b37613e077e
# DEBUG:2025-09-14 15:39:52,640:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 1b2c5ba83c05cd9813ea984a81ab799e2b5f8f32d58c4a8085f5c6075f600bd4
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 05f7f7937970eafde091afcd0e4ec7d208018c2845907cd2b1b9f1c7bf6d98ea
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:162: get_cache_key hash after serializing compression: 1135b7b18ff07311eef6218c8dba357b462664d501764f425f3f4752a6da0340
# DEBUG:2025-09-14 15:39:52,641:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,642:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 1135b7b18ff07311eef6218c8dba357b462664d501764f425f3f4752a6da0340
# DEBUG:2025-09-14 15:39:52,642:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,642:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_precondition_u_kn' with key 'jit_jax_precondition_u_kn-1135b7b18ff07311eef6218c8dba357b462664d501764f425f3f4752a6da0340'
# DEBUG:2025-09-14 15:39:52,671:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_precondition_u_kn' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 15:39:52,673:jax._src.dispatch:198: Finished XLA compilation of jit(jax_precondition_u_kn) in 0.035308123 sec
# DEBUG:2025-09-14 15:39:52,682:jax._src.dispatch:198: Finished tracing + transforming negative for pjit in 0.000152826 sec
# DEBUG:2025-09-14 15:39:52,684:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000680923 sec
# DEBUG:2025-09-14 15:39:52,685:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000078440 sec
# DEBUG:2025-09-14 15:39:52,686:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000378132 sec
# DEBUG:2025-09-14 15:39:52,687:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000219584 sec
# DEBUG:2025-09-14 15:39:52,688:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.012308121 sec
# DEBUG:2025-09-14 15:39:52,690:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(float64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,698:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.007788420 sec
# DEBUG:2025-09-14 15:39:52,699:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,700:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,701:jax._src.cache_key:156: get_cache_key hash of serialized computation: b41b489ca1448a95ae1e95c9887e48644ccd1051025950fec7a2511eb2b9b562
# DEBUG:2025-09-14 15:39:52,702:jax._src.cache_key:162: get_cache_key hash after serializing computation: b41b489ca1448a95ae1e95c9887e48644ccd1051025950fec7a2511eb2b9b562
# DEBUG:2025-09-14 15:39:52,702:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,703:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 9c2cf16e87dd5d5ebcd3f8a55ffa2e014fb0eacc7e74ae478674e8a487cc2508
# DEBUG:2025-09-14 15:39:52,703:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,703:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 1ec3e6e5002e0cebeac075d04c648423259eb7f707f57bb1909f3897f7804bcb
# DEBUG:2025-09-14 15:39:52,704:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,704:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 1ec3e6e5002e0cebeac075d04c648423259eb7f707f57bb1909f3897f7804bcb
# DEBUG:2025-09-14 15:39:52,704:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:39:52,705:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: bed11d1bd954084fa74186a558fc1edb9b985e1182772c3cb4b1608cee05e22f
# DEBUG:2025-09-14 15:39:52,705:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,705:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 80ac4bf82c4a26c7c6b33752e71d9eb635b8893b663e8aba7830e89b8371c89e
# DEBUG:2025-09-14 15:39:52,706:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,706:jax._src.cache_key:162: get_cache_key hash after serializing compression: 32034256102b6f505fb29c09aa07c3898592a7cf94fdece7dd473af16abd3e06
# DEBUG:2025-09-14 15:39:52,706:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,706:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 32034256102b6f505fb29c09aa07c3898592a7cf94fdece7dd473af16abd3e06
# DEBUG:2025-09-14 15:39:52,707:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,707:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-32034256102b6f505fb29c09aa07c3898592a7cf94fdece7dd473af16abd3e06'
# DEBUG:2025-09-14 15:39:52,741:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 15:39:52,743:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.042426825 sec
# DEBUG:2025-09-14 15:39:52,748:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000160217 sec
# DEBUG:2025-09-14 15:39:52,749:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000180960 sec
# DEBUG:2025-09-14 15:39:52,750:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000274658 sec
# DEBUG:2025-09-14 15:39:52,751:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000241518 sec
# DEBUG:2025-09-14 15:39:52,751:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_hessian for pjit in 0.006426573 sec
# DEBUG:2025-09-14 15:39:52,755:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.002353907 sec
# DEBUG:2025-09-14 15:39:52,756:jax._src.dispatch:198: Finished tracing + transforming jax_core_adaptive for pjit in 0.011631012 sec
# DEBUG:2025-09-14 15:39:52,758:jax._src.interpreters.pxla:1865: Compiling jax_core_adaptive with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(float64[12]), ShapedArray(float64[12]), ShapedArray(float64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,770:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_core_adaptive) in 0.011858702 sec
# DEBUG:2025-09-14 15:39:52,771:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,772:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,774:jax._src.cache_key:156: get_cache_key hash of serialized computation: ff04f4b32946c0c0b431d97f20c2cd2f1453d54a6e54f3c4e1e2fbcd45e65280
# DEBUG:2025-09-14 15:39:52,774:jax._src.cache_key:162: get_cache_key hash after serializing computation: ff04f4b32946c0c0b431d97f20c2cd2f1453d54a6e54f3c4e1e2fbcd45e65280
# DEBUG:2025-09-14 15:39:52,774:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,775:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 797853a2add9d6478acbfdb3cff74587d3b06014de5e05b74312b77db5f81a73
# DEBUG:2025-09-14 15:39:52,775:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,776:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a0a2bd8a893c8990b4c667e98ef73c708713d8e6b9e7610ad22a23abb6a56c99
# DEBUG:2025-09-14 15:39:52,776:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,776:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a0a2bd8a893c8990b4c667e98ef73c708713d8e6b9e7610ad22a23abb6a56c99
# DEBUG:2025-09-14 15:39:52,777:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 83304184391a34b36a6bf318011c4ef852e95b6be0c32398b7fa5d4edee2caf6
# DEBUG:2025-09-14 15:39:52,777:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 937fba7d9addf120d7951a3e0584e834d2a6b173c683fb9d0aa8ccfb0760278d
# DEBUG:2025-09-14 15:39:52,777:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,777:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: f18956f1b5794f690c5f6f84157bf495a4dbfb6cfb902187b64e06c609213d73
# DEBUG:2025-09-14 15:39:52,777:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,778:jax._src.cache_key:162: get_cache_key hash after serializing compression: 33e0768716500bc9638b8b78b3bd5444ca3a08e40620a63393394f2abf1149ac
# DEBUG:2025-09-14 15:39:52,778:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,778:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 33e0768716500bc9638b8b78b3bd5444ca3a08e40620a63393394f2abf1149ac
# DEBUG:2025-09-14 15:39:52,778:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,779:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-33e0768716500bc9638b8b78b3bd5444ca3a08e40620a63393394f2abf1149ac'
# DEBUG:2025-09-14 15:39:52,850:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.07s)
# DEBUG:2025-09-14 15:39:52,851:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.078671694 sec
# DEBUG:2025-09-14 15:39:52,868:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.003557920 sec
# DEBUG:2025-09-14 15:39:52,869:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,875:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.005064011 sec
# DEBUG:2025-09-14 15:39:52,876:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,877:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,878:jax._src.cache_key:156: get_cache_key hash of serialized computation: abd69e3f3c22e7bc9f55d926056d62ec6b03a1dc5e8c71b0fc2e92f8ba086218
# DEBUG:2025-09-14 15:39:52,879:jax._src.cache_key:162: get_cache_key hash after serializing computation: abd69e3f3c22e7bc9f55d926056d62ec6b03a1dc5e8c71b0fc2e92f8ba086218
# DEBUG:2025-09-14 15:39:52,879:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,879:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 83e1211a5db2d53e87f171dde78535994e4b34d92cc99ef3f4f71703129b7e07
# DEBUG:2025-09-14 15:39:52,880:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,880:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 0f529132fca388b2bf186144977fcbec5fc39bb33f7aa30bf3048d1b1163ff09
# DEBUG:2025-09-14 15:39:52,880:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,881:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 0f529132fca388b2bf186144977fcbec5fc39bb33f7aa30bf3048d1b1163ff09
# DEBUG:2025-09-14 15:39:52,882:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:39:52,882:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 50033cde212acaf6999e2900cc16b400c538a7084a51b55035cc00638e460d48
# DEBUG:2025-09-14 15:39:52,882:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,882:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 006f11cceb3b2ee6dbb9c7afe7f78fc482ec3c003c60d10d7aed9ea4d75f7174
# DEBUG:2025-09-14 15:39:52,883:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,883:jax._src.cache_key:162: get_cache_key hash after serializing compression: d6c1029ffc4b5bf7648b4e6c2c05ae5466c973ef4236a75026f4920a47d07c6f
# DEBUG:2025-09-14 15:39:52,883:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,884:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: d6c1029ffc4b5bf7648b4e6c2c05ae5466c973ef4236a75026f4920a47d07c6f
# DEBUG:2025-09-14 15:39:52,884:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,884:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-d6c1029ffc4b5bf7648b4e6c2c05ae5466c973ef4236a75026f4920a47d07c6f'
# DEBUG:2025-09-14 15:39:52,915:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 15:39:52,917:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.039327860 sec
# DEBUG:2025-09-14 15:39:52,923:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.003569603 sec
# DEBUG:2025-09-14 15:39:52,924:jax._src.interpreters.pxla:1865: Compiling _jit_self_consistent_update with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,929:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_jit_self_consistent_update) in 0.005026579 sec
# DEBUG:2025-09-14 15:39:52,930:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,931:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,932:jax._src.cache_key:156: get_cache_key hash of serialized computation: 62588bb479ce8678e761923b874cfdb157d4951daeb1c4287fd11b518d359fc8
# DEBUG:2025-09-14 15:39:52,932:jax._src.cache_key:162: get_cache_key hash after serializing computation: 62588bb479ce8678e761923b874cfdb157d4951daeb1c4287fd11b518d359fc8
# DEBUG:2025-09-14 15:39:52,932:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,933:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: d54ed722a9b2f082bc9b4c4797f0cb0aa412062d6e935ecd27c69f5a17bc2f3e
# DEBUG:2025-09-14 15:39:52,933:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,934:jax._src.cache_key:162: get_cache_key hash after serializing backend version: d8014bf1896a996aece0f5036bf08fe1f7dfed56eca09cbd61010b6cd58a1e1f
# DEBUG:2025-09-14 15:39:52,934:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,934:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: d8014bf1896a996aece0f5036bf08fe1f7dfed56eca09cbd61010b6cd58a1e1f
# DEBUG:2025-09-14 15:39:52,935:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:39:52,935:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 1fc780027118829b78849c4aa72723a70e788d21bb34c309af1caf5f2b9662da
# DEBUG:2025-09-14 15:39:52,935:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,936:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 6d0ce2046b074646f6913468c7d97260ccf09f5d5097779d035a0350292bbe48
# DEBUG:2025-09-14 15:39:52,936:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,937:jax._src.cache_key:162: get_cache_key hash after serializing compression: 8281e9b7aa16afe4f9a757ab83b39d6cad2061137e866099f0a02f153041ba46
# DEBUG:2025-09-14 15:39:52,937:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,937:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 8281e9b7aa16afe4f9a757ab83b39d6cad2061137e866099f0a02f153041ba46
# DEBUG:2025-09-14 15:39:52,938:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,938:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__jit_self_consistent_update' with key 'jit__jit_self_consistent_update-8281e9b7aa16afe4f9a757ab83b39d6cad2061137e866099f0a02f153041ba46'
# DEBUG:2025-09-14 15:39:52,968:jax._src.compiler:839: Not writing persistent cache entry for 'jit__jit_self_consistent_update' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 15:39:52,970:jax._src.dispatch:198: Finished XLA compilation of jit(_jit_self_consistent_update) in 0.038643599 sec
# DEBUG:2025-09-14 15:39:52,975:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_log_W_nk for pjit in 0.003123522 sec
# DEBUG:2025-09-14 15:39:52,976:jax._src.interpreters.pxla:1865: Compiling jax_mbar_log_W_nk with global shapes and types [ShapedArray(float64[12,900]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:39:52,981:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_log_W_nk) in 0.003997564 sec
# DEBUG:2025-09-14 15:39:52,982:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:39:52,982:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:39:52,984:jax._src.cache_key:156: get_cache_key hash of serialized computation: 2cdf920b4b34ba516300322ad80b1f3dde8acd5d2263bad10cf560c85b538513
# DEBUG:2025-09-14 15:39:52,984:jax._src.cache_key:162: get_cache_key hash after serializing computation: 2cdf920b4b34ba516300322ad80b1f3dde8acd5d2263bad10cf560c85b538513
# DEBUG:2025-09-14 15:39:52,984:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:39:52,985:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 45cffa04152c22e73d735f55a645163efb2e0434c09c7cfebdcecebfbcbef13f
# DEBUG:2025-09-14 15:39:52,985:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:39:52,985:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 1f177c7bd80a7d34dc4cd70bca0d0542030045eaae993e1a993e2035906c90fa
# DEBUG:2025-09-14 15:39:52,986:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,986:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 1f177c7bd80a7d34dc4cd70bca0d0542030045eaae993e1a993e2035906c90fa
# DEBUG:2025-09-14 15:39:52,987:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:39:52,987:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: e35fb5ed65400581d58a11b21499f4c7587f38f5e8b68736df8b89ccedfea14c
# DEBUG:2025-09-14 15:39:52,987:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:39:52,988:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 7c958f979cd5cc1f8229b0c8384e1249c467caed57fccc23b09e416e077d6015
# DEBUG:2025-09-14 15:39:52,988:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:39:52,988:jax._src.cache_key:162: get_cache_key hash after serializing compression: 358f7afcdcdfae459e8bf7c2675b0a2d9a0471d41a443872f55ed6e6ebf275c0
# DEBUG:2025-09-14 15:39:52,989:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:39:52,989:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 358f7afcdcdfae459e8bf7c2675b0a2d9a0471d41a443872f55ed6e6ebf275c0
# DEBUG:2025-09-14 15:39:52,990:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:39:52,990:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_log_W_nk' with key 'jit_jax_mbar_log_W_nk-358f7afcdcdfae459e8bf7c2675b0a2d9a0471d41a443872f55ed6e6ebf275c0'
# DEBUG:2025-09-14 15:39:53,017:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_log_W_nk' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 15:39:53,019:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_log_W_nk) in 0.035925865 sec
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# DEBUG:2025-09-14 15:50:07,882:jax._src.dispatch:198: Finished tracing + transforming _reduce_min for pjit in 0.000480890 sec
# DEBUG:2025-09-14 15:50:07,883:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000319719 sec
# DEBUG:2025-09-14 15:50:07,884:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000179529 sec
# DEBUG:2025-09-14 15:50:07,885:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000197172 sec
# DEBUG:2025-09-14 15:50:07,886:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001865387 sec
# DEBUG:2025-09-14 15:50:07,887:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000069380 sec
# DEBUG:2025-09-14 15:50:07,888:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000365496 sec
# DEBUG:2025-09-14 15:50:07,889:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000113249 sec
# DEBUG:2025-09-14 15:50:07,890:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000247002 sec
# DEBUG:2025-09-14 15:50:07,892:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000127792 sec
# DEBUG:2025-09-14 15:50:07,892:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.001719713 sec
# DEBUG:2025-09-14 15:50:07,893:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000209332 sec
# DEBUG:2025-09-14 15:50:07,894:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000151396 sec
# DEBUG:2025-09-14 15:50:07,895:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.000809908 sec
# DEBUG:2025-09-14 15:50:07,896:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000161648 sec
# DEBUG:2025-09-14 15:50:07,896:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000214338 sec
# DEBUG:2025-09-14 15:50:07,897:jax._src.dispatch:198: Finished tracing + transforming jax_precondition_u_kn for pjit in 0.015922070 sec
# DEBUG:2025-09-14 15:50:07,898:jax._src.interpreters.pxla:1865: Compiling jax_precondition_u_kn with global shapes and types [ShapedArray(float64[12,2112]), ShapedArray(float64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:50:07,903:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_precondition_u_kn) in 0.004761457 sec
# DEBUG:2025-09-14 15:50:07,904:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:50:07,904:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:50:07,906:jax._src.cache_key:156: get_cache_key hash of serialized computation: e5a9c4996ffd3bc687882a1dce59d48fd6fb798a968afca102abaa16105333ae
# DEBUG:2025-09-14 15:50:07,906:jax._src.cache_key:162: get_cache_key hash after serializing computation: e5a9c4996ffd3bc687882a1dce59d48fd6fb798a968afca102abaa16105333ae
# DEBUG:2025-09-14 15:50:07,907:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:50:07,907:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 17b7e0da9bfb8e7722b236daea19d2fffbf7b066e08ad2c97f0650c17ecd5173
# DEBUG:2025-09-14 15:50:07,908:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:50:07,908:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 278b2a8075d143baa2c294a17993d57638a499637adf7a2a310303ca36e33fdf
# DEBUG:2025-09-14 15:50:07,909:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:07,909:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 278b2a8075d143baa2c294a17993d57638a499637adf7a2a310303ca36e33fdf
# DEBUG:2025-09-14 15:50:07,910:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:50:07,910:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: cbc3ec0c0f8466584f47d61517430ea0d64c3bc86f739b32b52f6b245355652b
# DEBUG:2025-09-14 15:50:07,910:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:50:07,911:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 34365e5f72c5c690c66dbd348d4a4e8dd22ce89c0e0aa1c0595fac67db6a5b93
# DEBUG:2025-09-14 15:50:07,912:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:50:07,912:jax._src.cache_key:162: get_cache_key hash after serializing compression: ae99954104bbeb3466e51efbba4ca2cd45b2b7c92ebc7bb500e4ad181fb85650
# DEBUG:2025-09-14 15:50:07,912:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:07,913:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: ae99954104bbeb3466e51efbba4ca2cd45b2b7c92ebc7bb500e4ad181fb85650
# DEBUG:2025-09-14 15:50:07,913:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:50:07,914:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_precondition_u_kn' with key 'jit_jax_precondition_u_kn-ae99954104bbeb3466e51efbba4ca2cd45b2b7c92ebc7bb500e4ad181fb85650'
# DEBUG:2025-09-14 15:50:07,951:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_precondition_u_kn' because it took < 1.00 seconds to compile (0.04s)
# DEBUG:2025-09-14 15:50:07,952:jax._src.dispatch:198: Finished XLA compilation of jit(jax_precondition_u_kn) in 0.047664642 sec
# DEBUG:2025-09-14 15:50:07,958:jax._src.dispatch:198: Finished tracing + transforming negative for pjit in 0.000190496 sec
# DEBUG:2025-09-14 15:50:07,959:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000409842 sec
# DEBUG:2025-09-14 15:50:07,960:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000072956 sec
# DEBUG:2025-09-14 15:50:07,961:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000353336 sec
# DEBUG:2025-09-14 15:50:07,962:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000219822 sec
# DEBUG:2025-09-14 15:50:07,964:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.008854628 sec
# DEBUG:2025-09-14 15:50:07,964:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[12,2112]), ShapedArray(float64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:50:07,969:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.004667044 sec
# DEBUG:2025-09-14 15:50:07,971:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:50:07,971:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:50:07,973:jax._src.cache_key:156: get_cache_key hash of serialized computation: 928265a41429fa7dd9b3419f86bf02ac1852e120b97091c354292ecab9cc142b
# DEBUG:2025-09-14 15:50:07,974:jax._src.cache_key:162: get_cache_key hash after serializing computation: 928265a41429fa7dd9b3419f86bf02ac1852e120b97091c354292ecab9cc142b
# DEBUG:2025-09-14 15:50:07,974:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:50:07,975:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: e47e0da355ff45f2af205492ec7e081f4649a9ce62d74e036d54bb60db5796fb
# DEBUG:2025-09-14 15:50:07,975:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:50:07,975:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 8678299c05a827952404de348756d780a8d251a0dc2cd6587ce614952dc49dcf
# DEBUG:2025-09-14 15:50:07,976:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:07,976:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 8678299c05a827952404de348756d780a8d251a0dc2cd6587ce614952dc49dcf
# DEBUG:2025-09-14 15:50:07,977:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 15:50:07,977:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: eea105f519ea4aa45372864f8daf7d39fb661a227ae6aebc4a00a1616b6b9b14
# DEBUG:2025-09-14 15:50:07,977:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:50:07,978:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 6815dcc59e298303a3bd48a0b80ba3dad15d63f79295da534838256b367076d4
# DEBUG:2025-09-14 15:50:07,978:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:50:07,978:jax._src.cache_key:162: get_cache_key hash after serializing compression: c48c9184fd99ffdcdb73f41945f8fb4fc6a715a81d55597fec9a6554f05b70ab
# DEBUG:2025-09-14 15:50:07,979:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:07,979:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: c48c9184fd99ffdcdb73f41945f8fb4fc6a715a81d55597fec9a6554f05b70ab
# DEBUG:2025-09-14 15:50:07,979:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:50:07,979:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-c48c9184fd99ffdcdb73f41945f8fb4fc6a715a81d55597fec9a6554f05b70ab'
# DEBUG:2025-09-14 15:50:08,021:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.04s)
# DEBUG:2025-09-14 15:50:08,022:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.050383329 sec
# DEBUG:2025-09-14 15:50:08,028:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000177145 sec
# DEBUG:2025-09-14 15:50:08,029:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000144482 sec
# DEBUG:2025-09-14 15:50:08,030:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000386715 sec
# DEBUG:2025-09-14 15:50:08,031:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000291109 sec
# DEBUG:2025-09-14 15:50:08,032:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_hessian for pjit in 0.006959915 sec
# DEBUG:2025-09-14 15:50:08,036:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.002737045 sec
# DEBUG:2025-09-14 15:50:08,037:jax._src.dispatch:198: Finished tracing + transforming jax_core_adaptive for pjit in 0.013342857 sec
# DEBUG:2025-09-14 15:50:08,039:jax._src.interpreters.pxla:1865: Compiling jax_core_adaptive with global shapes and types [ShapedArray(float64[12,2112]), ShapedArray(float64[12]), ShapedArray(float64[12]), ShapedArray(float64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:50:08,052:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_core_adaptive) in 0.012211084 sec
# DEBUG:2025-09-14 15:50:08,053:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:50:08,054:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:50:08,055:jax._src.cache_key:156: get_cache_key hash of serialized computation: 33bf26eec9c722063ac388041ae235238a41f61ecc7e1b3fcfcb2b58b608c3c2
# DEBUG:2025-09-14 15:50:08,056:jax._src.cache_key:162: get_cache_key hash after serializing computation: 33bf26eec9c722063ac388041ae235238a41f61ecc7e1b3fcfcb2b58b608c3c2
# DEBUG:2025-09-14 15:50:08,056:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:50:08,057:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 50ed3d41b0f1c45bf3ee3c97f61c38bb7c3ebe56bfa54323537b7db06d34f0ac
# DEBUG:2025-09-14 15:50:08,057:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:50:08,057:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 709a5fc72ca7959d623b6a36a6ac57fec9e1b5e3852900f51e971a9cf86f973a
# DEBUG:2025-09-14 15:50:08,058:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:08,058:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 709a5fc72ca7959d623b6a36a6ac57fec9e1b5e3852900f51e971a9cf86f973a
# DEBUG:2025-09-14 15:50:08,058:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 83304184391a34b36a6bf318011c4ef852e95b6be0c32398b7fa5d4edee2caf6
# DEBUG:2025-09-14 15:50:08,059:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 11c882cd87a8169972d6994524587a5073579087d946c069ceb557ae9b1eee10
# DEBUG:2025-09-14 15:50:08,059:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 15:50:08,059:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 2232b264d5ce241128532549e5bba27ec8c9bec07acf8dcf1e23a1d292861b3b
# DEBUG:2025-09-14 15:50:08,059:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 15:50:08,060:jax._src.cache_key:162: get_cache_key hash after serializing compression: 236b700ba918b1ff7c8110826676314d7f7fa67a9753275d1bf0fa86e956e0bb
# DEBUG:2025-09-14 15:50:08,060:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:08,060:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 236b700ba918b1ff7c8110826676314d7f7fa67a9753275d1bf0fa86e956e0bb
# DEBUG:2025-09-14 15:50:08,060:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 15:50:08,061:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-236b700ba918b1ff7c8110826676314d7f7fa67a9753275d1bf0fa86e956e0bb'
# DEBUG:2025-09-14 15:50:08,144:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.08s)
# DEBUG:2025-09-14 15:50:08,145:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.091171265 sec
# DEBUG:2025-09-14 15:50:08,162:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.003211021 sec
# DEBUG:2025-09-14 15:50:08,163:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[12,2112]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 15:50:08,169:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.005042315 sec
# DEBUG:2025-09-14 15:50:08,169:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 15:50:08,170:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 15:50:08,171:jax._src.cache_key:156: get_cache_key hash of serialized computation: 167ae6c0988f538b41a3686f12b5c4fb5f44ec2b8ea6f70e2222c059bf6a4ab6
# DEBUG:2025-09-14 15:50:08,172:jax._src.cache_key:162: get_cache_key hash after serializing computation: 167ae6c0988f538b41a3686f12b5c4fb5f44ec2b8ea6f70e2222c059bf6a4ab6
# DEBUG:2025-09-14 15:50:08,172:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 15:50:08,172:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: ffc2f5a4480671a46243abfe8e2095875f27fca7cf9ce71aeacdef066ec5f4b3
# DEBUG:2025-09-14 15:50:08,173:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 15:50:08,173:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a2e87f17fe76aacb67fcf813068e1d2eca9296d06b97d88935efc77bf0b8df87
# DEBUG:2025-09-14 15:50:08,173:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 15:50:08,173:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a2e87f17fe76aacb67fcf813068e1d2eca9296d06b97d88935efc77bf0b8df87
# DEBUG:2025-09-14 15:50:08,174:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# ...
# DEBUG:2025-09-14 19:35:12,826:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 19:35:12,829:jax._src.cache_key:156: get_cache_key hash of serialized computation: 0d987f838f79c30a597b9ce9c50039a5fc1ffd5b6291355e5cbecb8505450927
# DEBUG:2025-09-14 19:35:12,830:jax._src.cache_key:162: get_cache_key hash after serializing computation: 0d987f838f79c30a597b9ce9c50039a5fc1ffd5b6291355e5cbecb8505450927
# DEBUG:2025-09-14 19:35:12,831:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 19:35:12,831:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: f7dc7cb695d8253b9b262cb14fc8ab06e6585efdf95d27381f8f20a763bc28db
# DEBUG:2025-09-14 19:35:12,832:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 19:35:12,832:jax._src.cache_key:162: get_cache_key hash after serializing backend version: c0fcc03466c8d48f46dc1eafe5408f30beb83e5024b681121fa12e97130df2c0
# DEBUG:2025-09-14 19:35:12,832:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:12,833:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: c0fcc03466c8d48f46dc1eafe5408f30beb83e5024b681121fa12e97130df2c0
# DEBUG:2025-09-14 19:35:12,834:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 83304184391a34b36a6bf318011c4ef852e95b6be0c32398b7fa5d4edee2caf6
# DEBUG:2025-09-14 19:35:12,834:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 303e1e63553686c432ef1e3553390e700c3ab3d669b4e5b1b3ac7d075ab57e29
# DEBUG:2025-09-14 19:35:12,835:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 19:35:12,835:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 38acee0d2f0ad41205dac3bcab3bec3639e0aae0d5a6fa2d8a209fa2dc7e1f90
# DEBUG:2025-09-14 19:35:12,836:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 19:35:12,836:jax._src.cache_key:162: get_cache_key hash after serializing compression: 3bdbacaec977618bb259ddd75810a9be8fa8086880605bae99558cdc1a1816cf
# DEBUG:2025-09-14 19:35:12,837:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:12,837:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 3bdbacaec977618bb259ddd75810a9be8fa8086880605bae99558cdc1a1816cf
# DEBUG:2025-09-14 19:35:12,837:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 19:35:12,838:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-3bdbacaec977618bb259ddd75810a9be8fa8086880605bae99558cdc1a1816cf'
# DEBUG:2025-09-14 19:35:12,971:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.13s)
# DEBUG:2025-09-14 19:35:12,972:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.145103216 sec
# DEBUG:2025-09-14 19:35:13,007:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.003565073 sec
# DEBUG:2025-09-14 19:35:13,008:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[12,38292]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 19:35:13,014:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.005184650 sec
# DEBUG:2025-09-14 19:35:13,015:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 19:35:13,016:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 19:35:13,017:jax._src.cache_key:156: get_cache_key hash of serialized computation: 445aa0e92a22967ce7ede76abb02bbe6916849c7fb950fcf571060cb7f6ba644
# DEBUG:2025-09-14 19:35:13,018:jax._src.cache_key:162: get_cache_key hash after serializing computation: 445aa0e92a22967ce7ede76abb02bbe6916849c7fb950fcf571060cb7f6ba644
# DEBUG:2025-09-14 19:35:13,018:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 19:35:13,018:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 5d3c7f5a06cbf68453d95da1d513a23a5d5c589942a18893efb51f5e59213c41
# DEBUG:2025-09-14 19:35:13,019:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 19:35:13,019:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a9ceb29a632f84cd67b82564bd9d255256ad9d428082114cddcb59d22b39ae6b
# DEBUG:2025-09-14 19:35:13,019:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,020:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a9ceb29a632f84cd67b82564bd9d255256ad9d428082114cddcb59d22b39ae6b
# DEBUG:2025-09-14 19:35:13,020:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 19:35:13,020:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: a0621c9fe13d3aff1c4eef56da6d4c28d0011447aa8159e4602f58a51df31ee2
# DEBUG:2025-09-14 19:35:13,021:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 19:35:13,021:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: dd94ea10cf0e96d11402aece0075f2da2fd97ddfd1c50f6a4aca84367f126904
# DEBUG:2025-09-14 19:35:13,021:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 19:35:13,022:jax._src.cache_key:162: get_cache_key hash after serializing compression: 12910a6f03df85ac10b77333a612247d857a2e5636d881a29619c18ea542428b
# DEBUG:2025-09-14 19:35:13,022:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,022:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 12910a6f03df85ac10b77333a612247d857a2e5636d881a29619c18ea542428b
# DEBUG:2025-09-14 19:35:13,022:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 19:35:13,023:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-12910a6f03df85ac10b77333a612247d857a2e5636d881a29619c18ea542428b'
# DEBUG:2025-09-14 19:35:13,085:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.06s)
# DEBUG:2025-09-14 19:35:13,086:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.069909334 sec
# DEBUG:2025-09-14 19:35:13,093:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.003546953 sec
# DEBUG:2025-09-14 19:35:13,095:jax._src.interpreters.pxla:1865: Compiling _jit_self_consistent_update with global shapes and types [ShapedArray(float64[12,38292]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 19:35:13,101:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_jit_self_consistent_update) in 0.005934954 sec
# DEBUG:2025-09-14 19:35:13,102:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 19:35:13,103:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 19:35:13,104:jax._src.cache_key:156: get_cache_key hash of serialized computation: 7d94dda2d48a117460aeb5442554a0caaf9a99b9f5b4ea821e04d185a590fe10
# DEBUG:2025-09-14 19:35:13,104:jax._src.cache_key:162: get_cache_key hash after serializing computation: 7d94dda2d48a117460aeb5442554a0caaf9a99b9f5b4ea821e04d185a590fe10
# DEBUG:2025-09-14 19:35:13,104:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 19:35:13,105:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: b3189f507e495879f385cf71b0a9f59019ee00458656a1bec84ab96d31dab565
# DEBUG:2025-09-14 19:35:13,105:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 19:35:13,105:jax._src.cache_key:162: get_cache_key hash after serializing backend version: bd31ba9b421e4d31a551cf144eae963b8fc1758246d2aed895f11d8fe592e8af
# DEBUG:2025-09-14 19:35:13,106:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,106:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: bd31ba9b421e4d31a551cf144eae963b8fc1758246d2aed895f11d8fe592e8af
# DEBUG:2025-09-14 19:35:13,107:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 19:35:13,108:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: a6d822fcfce4d65a0da79d5b5d9a817c7d2a4dc9f29df4c8deec75756fedb6ac
# DEBUG:2025-09-14 19:35:13,108:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 19:35:13,108:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 5e2a718e6da36ec9566ac4d41ac7270cd913fbe148508d5958730b836506d50a
# DEBUG:2025-09-14 19:35:13,109:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 19:35:13,109:jax._src.cache_key:162: get_cache_key hash after serializing compression: 98ce9a2e2388691d20e5917b39dc3200b8856537f5588dd82ceb528f27b9fd9f
# DEBUG:2025-09-14 19:35:13,109:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,110:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 98ce9a2e2388691d20e5917b39dc3200b8856537f5588dd82ceb528f27b9fd9f
# DEBUG:2025-09-14 19:35:13,110:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 19:35:13,111:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__jit_self_consistent_update' with key 'jit__jit_self_consistent_update-98ce9a2e2388691d20e5917b39dc3200b8856537f5588dd82ceb528f27b9fd9f'
# DEBUG:2025-09-14 19:35:13,171:jax._src.compiler:839: Not writing persistent cache entry for 'jit__jit_self_consistent_update' because it took < 1.00 seconds to compile (0.06s)
# DEBUG:2025-09-14 19:35:13,172:jax._src.dispatch:198: Finished XLA compilation of jit(_jit_self_consistent_update) in 0.069488764 sec
# DEBUG:2025-09-14 19:35:13,178:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_log_W_nk for pjit in 0.003253698 sec
# DEBUG:2025-09-14 19:35:13,180:jax._src.interpreters.pxla:1865: Compiling jax_mbar_log_W_nk with global shapes and types [ShapedArray(float64[12,38292]), ShapedArray(int64[12]), ShapedArray(float64[12])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 19:35:13,186:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_log_W_nk) in 0.006183863 sec
# DEBUG:2025-09-14 19:35:13,188:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 19:35:13,188:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 19:35:13,189:jax._src.cache_key:156: get_cache_key hash of serialized computation: 3f9266974614a243bcdbf64d80153ad839cba4e71684d0eda9ec9454a7898eb9
# DEBUG:2025-09-14 19:35:13,190:jax._src.cache_key:162: get_cache_key hash after serializing computation: 3f9266974614a243bcdbf64d80153ad839cba4e71684d0eda9ec9454a7898eb9
# DEBUG:2025-09-14 19:35:13,190:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 19:35:13,191:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 8d647c08f1eea6cc3190bf42597672e3f94d0458c55dfb02b44a93fbc819d78a
# DEBUG:2025-09-14 19:35:13,191:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 19:35:13,191:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 3171a42f7d13dd888d1e60e1a57ae064d1522cc3d624ae1b98aa0a751f723865
# DEBUG:2025-09-14 19:35:13,192:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,192:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 3171a42f7d13dd888d1e60e1a57ae064d1522cc3d624ae1b98aa0a751f723865
# DEBUG:2025-09-14 19:35:13,193:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 19:35:13,193:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 70511b15e78790874947f005a2ab03e72fa85f565e03655f7da4f6695cc7f942
# DEBUG:2025-09-14 19:35:13,193:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 19:35:13,194:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 146e6038b607e76a85984b91b84a417e6abb872f7c04e1466394513f074bdb65
# DEBUG:2025-09-14 19:35:13,194:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 19:35:13,194:jax._src.cache_key:162: get_cache_key hash after serializing compression: 1a5ac62f1c126efba1c4eb1ee079df2c74d341fb42d05ea87662cbe519971b65
# DEBUG:2025-09-14 19:35:13,195:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 19:35:13,195:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 1a5ac62f1c126efba1c4eb1ee079df2c74d341fb42d05ea87662cbe519971b65
# DEBUG:2025-09-14 19:35:13,196:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 19:35:13,196:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_log_W_nk' with key 'jit_jax_mbar_log_W_nk-1a5ac62f1c126efba1c4eb1ee079df2c74d341fb42d05ea87662cbe519971b65'
# DEBUG:2025-09-14 19:35:13,253:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_log_W_nk' because it took < 1.00 seconds to compile (0.06s)
# DEBUG:2025-09-14 19:35:13,254:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_log_W_nk) in 0.065476179 sec

# %%
from openmmtools.multistate import MultiStateReporter
import mdtraj as md
import numpy as np


reporter_path = 'test_run.nc'
storage_path = 'test_run_checkpoint.nc'
pdb_path = 'ligand_in_solvent.pdb'

'''
# Load the topology from the PDB file
topology = md.load(pdb_path).topology

# Use the MultiStateReporter to read all necessary data
reporter = MultiStateReporter(storage_path, open_mode='r')
reporter.read_from_storage()

# Also open the analysis file to read state assignments
analysis_reporter = MultiStateReporter(analysis_path, open_mode='r')
analysis_reporter.read_from_storage()

# Get the number of states and replicas
n_states = analysis_reporter.n_states
n_iterations = analysis_reporter.last_iteration + 1
n_replicas = reporter.n_replicas


# Read the full history of replica state assignments
replica_thermodynamic_states = analysis_reporter.read_replica_thermodynamic_states()
# `replica_thermodynamic_states` has shape (n_iterations, n_replicas)

# Create a list to store trajectories for each state
state_trajectories = [[] for _ in range(n_states)]

# Iterate through each iteration and each replica
for i in range(n_iterations):
    # Read the positions for all replicas at the current iteration
    all_positions = reporter.read_positions(iteration=i)
    
    for r in range(n_replicas):
        # Get the thermodynamic state that replica 'r' is currently in
        state_index = replica_thermodynamic_states[i, r]
        
        # Append the positions to the correct state's trajectory
        # Note: positions from read_positions() are already quantities, so convert to numpy array
        state_trajectories[state_index].append(all_positions[r].value_in_unit(md.unit.nanometers))

# Write an XTC file for each thermodynamic state
for state_id in range(n_states):
    print(f"Writing trajectory for thermodynamic state {state_id}...")
    
    # Convert the list of position arrays to a single numpy array
    state_xyz = np.array(state_trajectories[state_id])
    
    # Create an MDTraj Trajectory object for the state
    if len(state_xyz) > 0:
        traj = md.Trajectory(state_xyz, topology)
        output_filename = f'state_{state_id}.xtc'
        traj.save_xtc(output_filename)
    else:
        print(f"No trajectory data found for state {state_id}. Skipping.")

print("Trajectory extraction complete.")

# Close the reporters
reporter.close()
analysis_reporter.close()
'''

reporter = MultiStateReporter(reporter_path, open_mode='r')
pdb = md.load(pdb_path)
topology = pdb.topology

last_iteration = reporter.read_last_iteration()    
positions = []
pos_dict = {}

for i in range(last_iteration + 1):
    sampler_states = reporter.read_sampler_states(iteration=i)
    try:
        state_count = len(sampler_states)
        if state_count:
            print(f"Iteration {i} with {state_count} states")
        
        
        for ii in range(state_count):
            pos = sampler_states[ii].positions

            if ii not in pos_dict:
                pos_dict[ii] = []
            pos_dict[ii].append(pos)

            #for iii in dir(sampler_states[ii]):
                #print(iii, getattr(sampler_states[ii], iii))
            
            #if not any(np.array_equal(pos, p) for p in positions):
            positions.append(pos)
    except:
        continue

reporter.close()

traj = md.Trajectory(np.array(positions), topology)
ligand_indices = np.arange(0, 151)
traj.superpose(traj, 0, atom_indices=ligand_indices)
traj_ligand = traj.atom_slice(ligand_indices)

# Remove duplicate geometries
#precision = 1
#rounded_xyz = np.round(traj_ligand.xyz, precision)
#_, unique_indices = np.unique(rounded_xyz.reshape(rounded_xyz.shape[0], -1), axis=0, return_index=True)
#traj_ligand_unique = traj_ligand[unique_indices]
#export to dcd
traj_ligand.save_pdb("rest_ligand_samples.pdb")

for k, v in pos_dict.items():
    traj_k = md.Trajectory(np.array(v), topology)
    ligand_indices = np.arange(0, 151)
    traj_k.superpose(traj_k, 0, atom_indices=ligand_indices)
    traj_k_ligand = traj_k.atom_slice(ligand_indices)

    # Remove duplicate geometries
    #precision = 1
    #rounded_xyz = np.round(traj_ligand.xyz, precision)
    #_, unique_indices = np.unique(rounded_xyz.reshape(rounded_xyz.shape[0], -1), axis=0, return_index=True)
    #traj_ligand_unique = traj_ligand[unique_indices]
    #export to dcd

    traj_k_ligand.save_pdb(f"replca_{k}_ligand_samples.pdb")
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Iteration 0 with 12 states
# Iteration 50 with 12 states
# Iteration 100 with 12 states
# Iteration 150 with 12 states
# Iteration 200 with 12 states
# Iteration 250 with 12 states
# Iteration 300 with 12 states
# Iteration 350 with 12 states
# Iteration 400 with 12 states
# Iteration 450 with 12 states
# Iteration 500 with 12 states
# Iteration 550 with 12 states
# Iteration 600 with 12 states
# Iteration 650 with 12 states
# Iteration 700 with 12 states
# Iteration 750 with 12 states
# Iteration 800 with 12 states
# Iteration 850 with 12 states
# Iteration 900 with 12 states
# Iteration 950 with 12 states
# Iteration 1000 with 12 states
# Iteration 1050 with 12 states
# Iteration 1100 with 12 states
# Iteration 1150 with 12 states
# Iteration 1200 with 12 states
# Iteration 1250 with 12 states
# Iteration 1300 with 12 states
# Iteration 1350 with 12 states
# Iteration 1400 with 12 states
# Iteration 1450 with 12 states
# Iteration 1500 with 12 states
# Iteration 1550 with 12 states
# Iteration 1600 with 12 states
# Iteration 1650 with 12 states
# Iteration 1700 with 12 states
# Iteration 1750 with 12 states
# Iteration 1800 with 12 states
# Iteration 1850 with 12 states
# Iteration 1900 with 12 states
# Iteration 1950 with 12 states
# Iteration 2000 with 12 states
# Iteration 2050 with 12 states
# Iteration 2100 with 12 states
# Iteration 2150 with 12 states
# Iteration 2200 with 12 states
# Iteration 2250 with 12 states
# Iteration 2300 with 12 states
# Iteration 2350 with 12 states
# Iteration 2400 with 12 states
# Iteration 2450 with 12 states
# Iteration 2500 with 12 states
# Iteration 2550 with 12 states
# Iteration 2600 with 12 states
# Iteration 2650 with 12 states
# Iteration 2700 with 12 states
# Iteration 2750 with 12 states
# Iteration 2800 with 12 states
# Iteration 2850 with 12 states
# Iteration 2900 with 12 states
# Iteration 2950 with 12 states
# Iteration 3000 with 12 states
# Iteration 3050 with 12 states
# Iteration 3100 with 12 states
# Iteration 3150 with 12 states
# Iteration 3200 with 12 states
# Iteration 3250 with 12 states
# Iteration 3300 with 12 states
# Iteration 3350 with 12 states
# Iteration 3400 with 12 states
# Iteration 3450 with 12 states
# Iteration 3500 with 12 states
# Iteration 3550 with 12 states
# Iteration 3600 with 12 states
# Iteration 3650 with 12 states
# Iteration 3700 with 12 states
# Iteration 3750 with 12 states
# Iteration 3800 with 12 states
# Iteration 3850 with 12 states
# Iteration 3900 with 12 states
# Iteration 3950 with 12 states
# Iteration 4000 with 12 states
# Iteration 4050 with 12 states
# Iteration 4100 with 12 states
# Iteration 4150 with 12 states
# Iteration 4200 with 12 states
# Iteration 4250 with 12 states
# Iteration 4300 with 12 states
# Iteration 4350 with 12 states
# Iteration 4400 with 12 states
# Iteration 4450 with 12 states
# Iteration 4500 with 12 states
# Iteration 4550 with 12 states
# Iteration 4600 with 12 states
# Iteration 4650 with 12 states
# Iteration 4700 with 12 states
# Iteration 4750 with 12 states
# Iteration 4800 with 12 states
# Iteration 4850 with 12 states
# Iteration 4900 with 12 states
# Iteration 4950 with 12 states
# Iteration 5000 with 12 states

# %%
velocity_data_list = []
reporter = MultiStateReporter(reporter_path, open_mode='r')
pdb = md.load(pdb_path)
topology = pdb.topology
for i in range(0, 5000):
    states = reporter.read_sampler_states(iteration=i)
    if states:
        for re, ii in enumerate(states):
            print('replica', re)
            velocity_data_list.append(ii.velocities)
            #for iii in dir(ii):
                #print(iii, getattr(ii, iii))
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11

# %%
import pandas as pd
import numpy as np
from pint import UnitRegistry
import mdtraj as md
from openmm import unit
from openmm.unit import Quantity

BOLTZ = 1.380649e-23 # J/K
AMU_TO_KG = 1.66053906660e-27      # kg/amu
NM_TO_M = 1.0e-9                  # m/nm
PS_TO_S = 1.0e-12                 # s/ps

masses = np.array([atom.element.mass for atom in traj_ligand.topology.atoms])
masses_in_si = masses * AMU_TO_KG  # Convert to kg

temperatures = []

# Loop through each frame's velocity data
for frame_velocities_data in velocity_data_list:
    velocities = unit.Quantity(frame_velocities_data[:151], unit.nanometer/unit.picosecond)
    velocities_in_si = velocities * (NM_TO_M / PS_TO_S)  # Convert to m/s
    
    # Calculate kinetic energy per atom using openmm.unit
    v2_per_atom = np.sum(velocities_in_si**2, axis=1) # (m/s)^2
    ke_per_atom = 0.5 * masses_in_si * v2_per_atom # kg*(m/s)^2 = J
    total_kinetic_energy = np.sum(ke_per_atom) # J

    # Degrees of freedom (approximated as 3N)
    num_dof = 3 * traj_ligand.topology.n_atoms
    
    # Calculate temperature using openmm.unit
    temperature = (2 * total_kinetic_energy) / (num_dof * BOLTZ)
    temp = temperature._value
    temperatures.append(temp)

temperatures = [q._value for q in temperatures]
df = pd.DataFrame() 
for frame, i in enumerate(temperatures): 
    df.loc[frame, 'Temperature'] = i

df.sort_values(by='Temperature', inplace=True)
df.index.name = 'Frame'
frames_to_extract = list(df.iloc[:101, :].index)
df.to_csv('rest_temperatures.csv', index=True)

# %%
subset_traj = traj[frames_to_extract]
subset_traj.save_pdb(f"lambda_1_tempering_samples.pdb")

# %%
NMPS_TO_MS = NM_TO_M / PS_TO_S  # = 1e3 -> nm/ps -> m/s

masses_amu = np.array([atom.element.mass for atom in traj.topology.atoms])  # amu
masses_kg = masses_amu * AMU_TO_KG
N = traj.topology.n_atoms

def analyze_frame(frame_velocities_nmps, masses_kg, masses_amu, print_out=True):
    # Convert velocities to m/s
    v_ms = np.array(frame_velocities_nmps) * NMPS_TO_MS   # m/s

    # Mass-weighted COM velocity (use kg)
    v_com = np.sum(masses_kg[:,None] * v_ms, axis=0) / np.sum(masses_kg)

    # velocities relative to COM
    v_rel = v_ms - v_com

    # per-atom v^2
    v2_per_atom = np.sum(v_rel**2, axis=1)   # m^2/s^2

    # KE per atom (J)
    ke_per_atom = 0.5 * masses_kg * v2_per_atom
    total_ke = np.sum(ke_per_atom)

    # diagnostics
    # DOF choices:
    dof_3N = 3 * N
    dof_3N_minus_COM3 = 3 * N - 3   # if you remove overall translation
    # if you have constraints (e.g. bonds fixed), reduce DOF by number_constraints

    temp_3N = (2.0 * total_ke) / (dof_3N * BOLTZ)
    temp_minus3 = (2.0 * total_ke) / (dof_3N_minus_COM3 * BOLTZ)

    mean_ke_per_dof = total_ke / dof_3N_minus_COM3   # choose one denominator for comparison
    expected_ke_per_dof_300 = 0.5 * BOLTZ * 300.0

    rms_speed = np.sqrt(np.mean(v2_per_atom))
    mean_speed = np.mean(np.sqrt(v2_per_atom))

    if print_out:
        print("N atoms:", N)
        print("Sample masses (amu):", masses_amu[:6])
        print("Sample masses (kg):", masses_kg[:6])
        print("v_com (m/s):", v_com)
        print("RMS speed (m/s):", rms_speed)
        print("Mean speed (m/s):", mean_speed)
        print("Total KE (J):", total_ke)
        print("Mean KE per DOF (J):", mean_ke_per_dof)
        print("Expected <KE> per DOF at 300K (J):", expected_ke_per_dof_300)
        print("Ratio (observed / expected) per-DOF:", mean_ke_per_dof / expected_ke_per_dof_300)
        print("Temperature using DOF = 3N ->", temp_3N, "K")
        print("Temperature using DOF = 3N-3 ->", temp_minus3, "K")
        print("If you expect 300K but you get ~200K, ratio temp_observed/300K =", float(temp_minus3)/300.0)
    return {
        'v_com': v_com,
        'rms_speed': rms_speed,
        'mean_speed': mean_speed,
        'total_ke': total_ke,
        'temp_3N': float(temp_3N),
        'temp_minus3': float(temp_minus3),
        'mean_ke_per_dof': mean_ke_per_dof,
        'expected_ke_per_dof_300': expected_ke_per_dof_300
    }


# Run diagnostics on first frame (or a few frames)
res = analyze_frame(velocity_data_list[0], masses_kg, masses_amu)
# Out:
# N atoms: 5047
# Sample masses (amu): [12.01078 12.01078 15.99943 12.01078 12.01078 14.00672]
# Sample masses (kg): [1.99443694e-26 1.99443694e-26 2.65676786e-26 1.99443694e-26
#  1.99443694e-26 2.32587058e-26]
# v_com (m/s): [ 3.95485192 19.92314695  9.77000429]
# RMS speed (m/s): 1684.1336776708038
# Mean speed (m/s): 1397.7420805614388
# Total KE (J): 2.110643791426421e-17
# Mean KE per DOF (J): 1.3942685899236498e-21
# Expected <KE> per DOF at 300K (J): 2.0709735e-21
# Ratio (observed / expected) per-DOF: 0.6732430858838366
# Temperature using DOF = 3N -> 201.93290735307147 K
# Temperature using DOF = 3N-3 -> 201.972925765151 K
# If you expect 300K but you get ~200K, ratio temp_observed/300K = 0.6732430858838366

# %%
states = reporter.read_thermodynamic_states()
print(len(states), len(states[0]))
for replica_idx, state in enumerate(states[0]):
    print(f"Replica {replica_idx}")
    print(state.lambda_rest_bonds, state.lambda_rest_angles, state.lambda_rest_torsions, state.lambda_rest_electrostatics, state.lambda_rest_sterics)
# Out:
# 2 12
# Replica 0
# 1.0 1.0 1.0 0.0 0.0
# Replica 1
# 0.9734065266735387 0.9734065266735387 0.9734065266735387 -0.026593473326461337 -0.052479733829357555
# Replica 2
# 0.9465844449917015 0.9465844449917015 0.9465844449917015 -0.05341555500829853 -0.10397788849975242
# Replica 3
# 0.919611044679672 0.919611044679672 0.919611044679672 -0.08038895532032797 -0.15431552650316227
# Replica 4
# 0.8925631547752036 0.8925631547752036 0.8925631547752036 -0.10743684522479635 -0.20333101473773585
# Replica 5
# 0.865516209187028 0.865516209187028 0.865516209187028 -0.13448379081297201 -0.2508816916345169
# Replica 6
# 0.8385433859396005 0.8385433859396005 0.8385433859396005 -0.16145661406039946 -0.2968449898969501
# Replica 7
# 0.8117148387605542 0.8117148387605542 0.8117148387605542 -0.18828516123944583 -0.34111902053592746
# Replica 8
# 0.7850970347407514 0.7850970347407514 0.7850970347407514 -0.21490296525924857 -0.38362264604127927
# Replica 9
# 0.7587522067118707 0.7587522067118707 0.7587522067118707 -0.2412477932881293 -0.42429508880986655
# Replica 10
# 0.7327379240597882 0.7327379240597882 0.7327379240597882 -0.2672620759402118 -0.4630951346445521
# Replica 11
# 0.7071067811865476 0.7071067811865476 0.7071067811865476 -0.2928932188134524 -0.5
