# %%
import copy
import openmm as mm
from openmm import app, unit
from openmm.app import PDBFile

# %%
with open('system_with_ligand_only.xml', 'r') as f:
    system_1 = mm.XmlSerializer.deserialize(f.read())
pdb = PDBFile('ligand_in_solvent.pdb')
system_1.addForce(mm.MonteCarloBarostat(1*unit.atmosphere, 300*unit.kelvin))
system_1.getForces()
# Out:
# [<openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x71041083def0> >,
#  <openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x71041083de60> >,
#  <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x71041083dce0> >,
#  <openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x71041083dd70> >,
#  <openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x71041083dc20> >,
#  <openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x71041083db60> >]

# %%
ligand = list(pdb.topology.residues())[0]
rest_atoms = [atom.index for atom in ligand.atoms()]
len(rest_atoms)
# Out:
# 151

# %%
# Create REST system
rest_system = mm.System()
# Create dict of vanilla system forces (for easy retrieval of force objects later)
system_forces = {type(force).__name__ : force for force in system_1.getForces()}

# Add particles
for particle_idx in range(system_1.getNumParticles()):
    particle_mass = system_1.getParticleMass(particle_idx)
    rest_system.addParticle(particle_mass)

# Copy barostat
if "MonteCarloBarostat" in system_forces:
    barostat = copy.deepcopy(system_forces["MonteCarloBarostat"])
    rest_system.addForce(barostat)

# Copy box vectors
box_vectors = system_1.getDefaultPeriodicBoxVectors()
rest_system.setDefaultPeriodicBoxVectors(*box_vectors)

# Copy constraints
for constraint_idx in range(system_1.getNumConstraints()):
    atom1, atom2, length = system_1.getConstraintParameters(constraint_idx)
    rest_system.addConstraint(atom1, atom2, length)

# %%
# Define the custom expression
bond_expression = "rest_scale * (K / 2) * (r - length)^2;"
bond_expression += "rest_scale = is_rest * lambda_rest_bonds * lambda_rest_bonds " \
                   "+ is_inter * lambda_rest_bonds " \
                   "+ is_nonrest;"

# Create custom force
rest_bond_force = mm.CustomBondForce(bond_expression)
rest_system.addForce(rest_bond_force)

# Add global parameters
rest_bond_force.addGlobalParameter("lambda_rest_bonds", 1.0)

# Add per-bond parameters for rest scaling
rest_bond_force.addPerBondParameter("is_rest")
rest_bond_force.addPerBondParameter("is_inter")
rest_bond_force.addPerBondParameter("is_nonrest")

# Add per-bond parameters for defining bond energy
rest_bond_force.addPerBondParameter('length')  # equilibrium bond length
rest_bond_force.addPerBondParameter('K')  # force constant
# Out:
# 4

# %%
def get_rest_identifier(atoms, rest_atoms):
    """
    For a given atom or set of atoms, get the rest_id which is a list of binary ints that defines which
    (mutually exclusive) set the atom(s) belong to.

    If there is a single atom, the sets are: is_rest, is_nonrest
    If there is a set of atoms, the sets are: is_rest, is_inter, is_nonrest

    Example: if there is a single atom that is in the nonrest set, the rest_id is [0, 1]

    Arguments
    ---------
    atoms : set or int
        a set of hybrid atom indices or single atom
    rest_atoms : set or list
        a list (or list-like) of atoms whose interactions will be scaled by REST
    Returns
    -------
    rest_id : list
        list of binaries indicating which set the atom(s) belong to
    """

    if isinstance(atoms, int):
        rest_id = [0, 1] # Set the default rest_id to non-REST
        if atoms in rest_atoms:
            rest_id = [1, 0]
        return rest_id

    elif isinstance(atoms, set):
        rest_id = [0, 0, 1] # Set the default rest_id to non-REST
        if atoms.intersection(rest_atoms) != set(): # At least one of the atoms is REST
            if atoms.issubset(rest_atoms): # All atoms are REST
                rest_id = [1, 0, 0]
            else: # At least one (but not all) of the atoms is are REST
                rest_id = [0, 1, 0]
        return rest_id

    else:
        raise Exception(f"atoms is of type {type(atoms)}, but only `int` and `set` are allowable")

# %%
# Get vanilla system bond force
bond_force = system_forces['HarmonicBondForce']

# Set periodicity
if bond_force.usesPeriodicBoundaryConditions():
    rest_bond_force.setUsesPeriodicBoundaryConditions(True)

# Add bonds to rest_system
for term_idx in range(bond_force.getNumBonds()):
    # Get the bond parameters and rest id
    p1, p2, r0, k = bond_force.getBondParameters(term_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add the bond
    bond_term = (p1, p2, rest_id + [r0, k])
    rest_bond_force.addBond(*bond_term)

# %%
# Define the custom expression
angle_expression = "rest_scale * (K / 2) * (theta - theta0)^2;"
angle_expression += "rest_scale = is_rest * lambda_rest_angles * lambda_rest_angles " \
                    "+ is_inter * lambda_rest_angles " \
                    "+ is_nonrest;"

# Create custom force
rest_angle_force = mm.CustomAngleForce(angle_expression)
rest_system.addForce(rest_angle_force)

# Add global parameters
rest_angle_force.addGlobalParameter("lambda_rest_angles", 1.0)

# Add per-angle parameters for rest scaling
rest_angle_force.addPerAngleParameter("is_rest")
rest_angle_force.addPerAngleParameter("is_inter")
rest_angle_force.addPerAngleParameter("is_nonrest")

# Add per-angle parameters for defining angle energy
rest_angle_force.addPerAngleParameter('theta0')  # equilibrium angle
rest_angle_force.addPerAngleParameter('K')  # force constant

# Get vanilla system angle force
angle_force = system_forces['HarmonicAngleForce']

# Set periodicity
if angle_force.usesPeriodicBoundaryConditions():
    rest_angle_force.setUsesPeriodicBoundaryConditions(True)

# Add angles to rest_system
for term_idx in range(angle_force.getNumAngles()):
    # Get the angle parameters and rest id
    p1, p2, p3, theta0, k = angle_force.getAngleParameters(term_idx)
    idx_set = set([p1, p2, p3])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add the angle
    angle_term = (p1, p2, p3, rest_id + [theta0, k])
    rest_angle_force.addAngle(*angle_term)

# %%
# Define the custom expression
torsion_expression = "rest_scale * U;"
torsion_expression += "rest_scale = is_rest * lambda_rest_torsions * lambda_rest_torsions " \
                      "+ is_inter * lambda_rest_torsions " \
                      "+ is_nonrest;"
torsion_expression += "U = (K * (1 + cos(periodicity * theta - phase)));"

# Create custom force
rest_torsion_force = mm.CustomTorsionForce(torsion_expression)
rest_system.addForce(rest_torsion_force)

# Add global parameters
rest_torsion_force.addGlobalParameter("lambda_rest_torsions", 1.0)

# Add per-torsion parameters for rest scaling
rest_torsion_force.addPerTorsionParameter("is_rest")
rest_torsion_force.addPerTorsionParameter("is_inter")
rest_torsion_force.addPerTorsionParameter("is_nonrest")

# Add per-torsion parameters for defining torsion energy
rest_torsion_force.addPerTorsionParameter('periodicity')
rest_torsion_force.addPerTorsionParameter('phase') # phase offset
rest_torsion_force.addPerTorsionParameter('K') # force constant

# Get vanilla system torsion force
torsion_force = system_forces['PeriodicTorsionForce']

# Set periodicity
if torsion_force.usesPeriodicBoundaryConditions():
    rest_torsion_force.setUsesPeriodicBoundaryConditions(True)

# Add torsions to rest_system
for torsion_idx in range(torsion_force.getNumTorsions()):
    # Get the torsion parameters and rest id
    p1, p2, p3, p4, periodicity, phase, K = torsion_force.getTorsionParameters(torsion_idx)
    idx_set = set([p1, p2, p3, p4])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add torsion
    torsion_term = (p1, p2, p3, p4, rest_id + [periodicity, phase, K])
    rest_torsion_force.addTorsion(*torsion_term)

# %%
# Create nonbonded force
rest_nonbonded_force = mm.NonbondedForce()
rest_system.addForce(rest_nonbonded_force)

# Get vanilla system nonbonded force
nonbonded_force = system_forces['NonbondedForce']

# Set the nonbonded method and related parameters
nonbonded_method = nonbonded_force.getNonbondedMethod()
rest_nonbonded_force.setNonbondedMethod(nonbonded_method)
if nonbonded_method != mm.NonbondedForce.NoCutoff:
    epsilon_solvent = nonbonded_force.getReactionFieldDielectric()
    cutoff = nonbonded_force.getCutoffDistance()
    rest_nonbonded_force.setReactionFieldDielectric(epsilon_solvent)
    rest_nonbonded_force.setCutoffDistance(cutoff)
if nonbonded_method in [mm.NonbondedForce.PME, mm.NonbondedForce.Ewald]:
    [alpha_ewald, nx, ny, nz] = nonbonded_force.getPMEParameters()
    delta = nonbonded_force.getEwaldErrorTolerance()
    rest_nonbonded_force.setPMEParameters(alpha_ewald, nx, ny, nz)
    rest_nonbonded_force.setEwaldErrorTolerance(delta)

# Copy switching function from vanilla system
switch_bool = nonbonded_force.getUseSwitchingFunction()
rest_nonbonded_force.setUseSwitchingFunction(switch_bool)
if switch_bool:
    switching_distance = nonbonded_force.getSwitchingDistance()
    rest_nonbonded_force.setSwitchingDistance(switching_distance)

# Copy dispersion correction
dispersion_bool = nonbonded_force.getUseDispersionCorrection()
rest_nonbonded_force.setUseDispersionCorrection(dispersion_bool)

# Add global parameters
rest_nonbonded_force.addGlobalParameter('lambda_rest_electrostatics', 0.)
rest_nonbonded_force.addGlobalParameter('lambda_rest_sterics', 0.)
# Out:
# 1

# %%
# Add nonbondeds to rest_system
for particle_idx in range(nonbonded_force.getNumParticles()):
    # Get the nonbonded parameters and rest id
    q, sigma, epsilon = nonbonded_force.getParticleParameters(particle_idx)
    rest_id = get_rest_identifier(particle_idx, rest_atoms)

    # Add particles and offsets
    if rest_id == [0, 1]: # nonrest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)

    else: # rest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_electrostatics', particle_idx, q, 0.0*sigma, epsilon*0.0)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_sterics', particle_idx, q*0.0, 0.0*sigma, epsilon)

# Handle exceptions
for exception_idx in range(nonbonded_force.getNumExceptions()):
    # Get exception parameters and rest id
    p1, p2, chargeProd, sigma, epsilon = nonbonded_force.getExceptionParameters(exception_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add exceptions and offsets
    exc_idx = rest_nonbonded_force.addException(p1, p2, chargeProd, sigma, epsilon)
    if rest_id == [0, 0, 1]: # nonrest
        pass

    elif rest_id == [1, 0, 0]: # rest
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_sterics', exc_idx, chargeProd, 0.0*sigma, epsilon)

    elif rest_id == [0, 1, 0]: # inter
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_electrostatics', exc_idx, chargeProd, 0.0*sigma, epsilon)

# %%
import math
import logging
import numpy as np
from openmmtools.constants import kB
from openmmtools import cache, mcmc, multistate
from openmmtools.multistate import ReplicaExchangeSampler
from openmmtools.states import GlobalParameterState, SamplerState, ThermodynamicState, CompoundThermodynamicState

# %%
class RESTState(GlobalParameterState):
    lambda_rest_bonds = GlobalParameterState.GlobalParameter('lambda_rest_bonds', standard_value=1.0)
    lambda_rest_angles = GlobalParameterState.GlobalParameter('lambda_rest_angles', standard_value=1.0)
    lambda_rest_torsions = GlobalParameterState.GlobalParameter('lambda_rest_torsions', standard_value=1.0)
    lambda_rest_electrostatics = GlobalParameterState.GlobalParameter('lambda_rest_electrostatics', standard_value=0.0)
    lambda_rest_sterics = GlobalParameterState.GlobalParameter('lambda_rest_sterics', standard_value=0.0)

    def set_rest_parameters(self, beta_m, beta_0):
        """Set all defined lambda parameters to the given value.

        The undefined parameters (i.e. those being set to None) remain undefined.

        Parameters
        ----------
        new_value : float
            The new value for all defined parameters.
        """
        lambda_functions = {'lambda_rest_bonds': lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_angles' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_torsions' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_electrostatics' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0) - 1,
                 'lambda_rest_sterics' : lambda beta_m, beta_0 : beta_m / beta_0 - 1
                 }

        for parameter_name in self._parameters:
            if self._parameters[parameter_name] is not None:
                new_value = lambda_functions[parameter_name](beta_m, beta_0)
                setattr(self, parameter_name, new_value)

# %%
# Set temperatures for each thermodynamic state
n_replicas = 40  # Number of temperature replicas
T_min = 300 * unit.kelvin  # Minimum temperature (i.e., temperature of desired distribution)
T_max = 500 * unit.kelvin  # Maximum temperature
temperatures = [T_min + (T_max - T_min) * (math.exp(float(i) / float(n_replicas-1)) - 1.0) / (math.e - 1.0)
                for i in range(n_replicas)]
temperatures
# Out:
# [Quantity(value=300.0, unit=kelvin),
#  Quantity(value=303.02308784039593, unit=kelvin),
#  Quantity(value=306.1246930852075, unit=kelvin),
#  Quantity(value=309.3068550343565, unit=kelvin),
#  Quantity(value=312.571665953654, unit=kelvin),
#  Quantity(value=315.92127245046197, unit=kelvin),
#  Quantity(value=319.3578768850833, unit=kelvin),
#  Quantity(value=322.88373881881006, unit=kelvin),
#  Quantity(value=326.50117649958094, unit=kelvin),
#  Quantity(value=330.21256838622503, unit=kelvin),
#  Quantity(value=334.02035471229453, unit=kelvin),
#  Quantity(value=337.9270390905137, unit=kelvin),
#  Quantity(value=341.9351901588998, unit=kelvin),
#  Quantity(value=346.0474432696381, unit=kelvin),
#  Quantity(value=350.2665022218214, unit=kelvin),
#  Quantity(value=354.59514103919264, unit=kelvin),
#  Quantity(value=359.036205794061, unit=kelvin),
#  Quantity(value=363.5926164785894, unit=kelvin),
#  Quantity(value=368.26736892468364, unit=kelvin),
#  Quantity(value=373.06353677374716, unit=kelvin),
#  Quantity(value=377.9842734975943, unit=kelvin),
#  Quantity(value=383.0328144718527, unit=kelvin),
#  Quantity(value=388.212479103217, unit=kelvin),
#  Quantity(value=393.5266730119525, unit=kelvin),
#  Quantity(value=398.9788902710848, unit=kelvin),
#  Quantity(value=404.57271570374655, unit=kelvin),
#  Quantity(value=410.31182724019186, unit=kelvin),
#  Quantity(value=416.19999833602947, unit=kelvin),
#  Quantity(value=422.2411004532628, unit=kelvin),
#  Quantity(value=428.4391056057691, unit=kelvin),
#  Quantity(value=434.7980889708919, unit=kelvin),
#  Quantity(value=441.3222315688626, unit=kelvin),
#  Quantity(value=448.015823011814, unit=kelvin),
#  Quantity(value=454.8832643241925, unit=kelvin),
#  Quantity(value=461.9290708364239, unit=kelvin),
#  Quantity(value=469.1578751537347, unit=kelvin),
#  Quantity(value=476.57443020208285, unit=kelvin),
#  Quantity(value=484.18361235319674, unit=kelvin),
#  Quantity(value=491.99042463078194, unit=kelvin),
#  Quantity(value=500.0, unit=kelvin)]

# %%
# Create reference thermodynamic state
rest_state = RESTState.from_system(rest_system)
thermostate = ThermodynamicState(rest_system, temperature=T_min)
compound_thermodynamic_state = CompoundThermodynamicState(thermostate, composable_states=[rest_state])

# %%
# Create thermodynamic states
sampler_state =  SamplerState(pdb.positions, box_vectors=rest_system.getDefaultPeriodicBoxVectors())
beta_0 = 1/(kB*T_min)
thermodynamic_state_list = []
sampler_state_list = []
for temperature in temperatures:
    # Create a thermodynamic state with REST interactions scaled to the given temperature
    beta_m = 1/(kB*temperature)
    compound_thermodynamic_state_copy = copy.deepcopy(compound_thermodynamic_state)
    compound_thermodynamic_state_copy.set_rest_parameters(beta_m, beta_0)
    thermodynamic_state_list.append(compound_thermodynamic_state_copy)

    # Generate a sampler_state with minimized positions
    context, integrator = cache.global_context_cache.get_context(compound_thermodynamic_state_copy)
    sampler_state.apply_to_context(context, ignore_velocities=True)
    mm.LocalEnergyMinimizer.minimize(context)
    sampler_state.update_from_context(context)
    sampler_state_list.append(copy.deepcopy(sampler_state))

# %%
# Set up sampler
_logger = logging.getLogger()
_logger.setLevel(logging.DEBUG)
move = mcmc.LangevinDynamicsMove(timestep=4*unit.femtoseconds, n_steps=10000)
simulation = ReplicaExchangeSampler(mcmc_moves=move, number_of_iterations=400)

# Run repex
reporter_file = "test_run.nc"
reporter = multistate.MultiStateReporter(reporter_file, checkpoint_interval=100)
simulation.create(thermodynamic_states=thermodynamic_state_list,
                  sampler_states=sampler_state_list,
                  storage=reporter)
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Please cite the following:
#
#         Friedrichs MS, Eastman P, Vaidyanathan V, Houston M, LeGrand S, Beberg AL, Ensign DL, Bruns CM, and Pande VS. Accelerating molecular dynamic simulations on graphics processing unit. J. Comput. Chem. 30:864, 2009. DOI: 10.1002/jcc.21209
#         Eastman P and Pande VS. OpenMM: A hardware-independent framework for molecular simulations. Comput. Sci. Eng. 12:34, 2010. DOI: 10.1109/MCSE.2010.27
#         Eastman P and Pande VS. Efficient nonbonded interactions for molecular dynamics on a graphics processing unit. J. Comput. Chem. 31:1268, 2010. DOI: 10.1002/jcc.21413
#         Eastman P and Pande VS. Constant constraint matrix approximation: A robust, parallelizable constraint method for molecular simulations. J. Chem. Theor. Comput. 6:434, 2010. DOI: 10.1021/ct900463w
#         Chodera JD and Shirts MR. Replica exchange and expanded ensemble simulations as Gibbs multistate: Simple improvements for enhanced mixing. J. Chem. Phys., 135:194110, 2011. DOI:10.1063/1.3660669

# %%
simulation.run()
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
#
# ******* JAX 64-bit mode is now on! *******
# *     JAX is now set to 64-bit mode!     *
# *   This MAY cause problems with other   *
# *      uses of JAX in the same code.     *
# ******************************************
#
# DEBUG:2025-09-14 10:03:10,688:jax._src.dispatch:198: Finished tracing + transforming _reduce_min for pjit in 0.001800537 sec
# DEBUG:2025-09-14 10:03:10,691:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000864506 sec
# DEBUG:2025-09-14 10:03:10,692:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000325918 sec
# DEBUG:2025-09-14 10:03:10,694:jax._src.dispatch:198: Finished tracing + transforming not_equal for pjit in 0.000584126 sec
# DEBUG:2025-09-14 10:03:10,695:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000298500 sec
# DEBUG:2025-09-14 10:03:10,696:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001558304 sec
# DEBUG:2025-09-14 10:03:10,697:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000068665 sec
# DEBUG:2025-09-14 10:03:10,698:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000401497 sec
# DEBUG:2025-09-14 10:03:10,698:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000121832 sec
# DEBUG:2025-09-14 10:03:10,700:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000459671 sec
# DEBUG:2025-09-14 10:03:10,701:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000132322 sec
# DEBUG:2025-09-14 10:03:10,701:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.000720978 sec
# DEBUG:2025-09-14 10:03:10,702:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000241995 sec
# DEBUG:2025-09-14 10:03:10,704:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000207663 sec
# DEBUG:2025-09-14 10:03:10,704:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001009703 sec
# DEBUG:2025-09-14 10:03:10,706:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000969648 sec
# DEBUG:2025-09-14 10:03:10,709:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.001043081 sec
# DEBUG:2025-09-14 10:03:10,711:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000262499 sec
# DEBUG:2025-09-14 10:03:10,712:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000204086 sec
# DEBUG:2025-09-14 10:03:10,713:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000330687 sec
# DEBUG:2025-09-14 10:03:10,713:jax._src.dispatch:198: Finished tracing + transforming jax_precondition_u_kn for pjit in 0.031055450 sec
# DEBUG:2025-09-14 10:03:10,714:jax._src.xla_bridge:417: No jax_plugins namespace packages available
# DEBUG:2025-09-14 10:03:10,750:jax._src.xla_bridge:827: Initializing backend 'cpu'
# DEBUG:2025-09-14 10:03:10,780:jax._src.xla_bridge:841: Backend 'cpu' initialized
# DEBUG:2025-09-14 10:03:10,782:jax._src.xla_bridge:827: Initializing backend 'tpu'
# INFO:2025-09-14 10:03:10,810:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# WARNING:2025-09-14 10:03:10,811:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# DEBUG:2025-09-14 10:03:10,813:jax._src.interpreters.pxla:1865: Compiling jax_precondition_u_kn with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(float64[40]), ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:10,895:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_precondition_u_kn) in 0.081741095 sec
# DEBUG:2025-09-14 10:03:10,898:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:10,899:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:10,907:jax._src.cache_key:156: get_cache_key hash of serialized computation: d77c5313169416d5fb4d335139adf87ed27188327afbee5bff0a6ca2f61b043e
# DEBUG:2025-09-14 10:03:10,908:jax._src.cache_key:162: get_cache_key hash after serializing computation: d77c5313169416d5fb4d335139adf87ed27188327afbee5bff0a6ca2f61b043e
# DEBUG:2025-09-14 10:03:10,909:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:10,909:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 516282ed3d7bd10cc7a90ebae7a575740b81afc1ec7251277f3e57f050d4260a
# DEBUG:2025-09-14 10:03:10,910:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:10,911:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a8aa0d56a359b21bad752ad12615f82f6e415e8c580a226be7faee126a93c52a
# DEBUG:2025-09-14 10:03:10,911:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:10,911:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a8aa0d56a359b21bad752ad12615f82f6e415e8c580a226be7faee126a93c52a
# DEBUG:2025-09-14 10:03:10,915:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 10:03:10,916:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: dbcae6ab9cd27be995fa3d6a55b8ad51f75f9ba2b9062edd878cf464899ca836
# DEBUG:2025-09-14 10:03:10,917:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:10,918:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 484478e7f48819745e70c7429158ac43c485d4aedc9aafb197bbf9338af5e60e
# DEBUG:2025-09-14 10:03:10,918:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:10,918:jax._src.cache_key:162: get_cache_key hash after serializing compression: e9affbd7532278ab711fedcdb41ab7e19d318fb9579934083e8489d2f7820ea8
# DEBUG:2025-09-14 10:03:10,919:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:10,919:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: e9affbd7532278ab711fedcdb41ab7e19d318fb9579934083e8489d2f7820ea8
# DEBUG:2025-09-14 10:03:10,920:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:10,920:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_precondition_u_kn' with key 'jit_jax_precondition_u_kn-e9affbd7532278ab711fedcdb41ab7e19d318fb9579934083e8489d2f7820ea8'
# DEBUG:2025-09-14 10:03:11,153:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_precondition_u_kn' because it took < 1.00 seconds to compile (0.23s)
# DEBUG:2025-09-14 10:03:11,154:jax._src.dispatch:198: Finished XLA compilation of jit(jax_precondition_u_kn) in 0.254181147 sec
# DEBUG:2025-09-14 10:03:11,162:jax._src.dispatch:198: Finished tracing + transforming negative for pjit in 0.000167370 sec
# DEBUG:2025-09-14 10:03:11,165:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.001552105 sec
# DEBUG:2025-09-14 10:03:11,166:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000072479 sec
# DEBUG:2025-09-14 10:03:11,167:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000515938 sec
# DEBUG:2025-09-14 10:03:11,168:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000151396 sec
# DEBUG:2025-09-14 10:03:11,170:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000404596 sec
# DEBUG:2025-09-14 10:03:11,172:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000167370 sec
# DEBUG:2025-09-14 10:03:11,173:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.001124144 sec
# DEBUG:2025-09-14 10:03:11,174:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000306845 sec
# DEBUG:2025-09-14 10:03:11,175:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000182390 sec
# DEBUG:2025-09-14 10:03:11,176:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000137091 sec
# DEBUG:2025-09-14 10:03:11,177:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000267982 sec
# DEBUG:2025-09-14 10:03:11,178:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000171423 sec
# DEBUG:2025-09-14 10:03:11,179:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.020937443 sec
# DEBUG:2025-09-14 10:03:11,180:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(float64[40]), ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,185:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.004596472 sec
# DEBUG:2025-09-14 10:03:11,186:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,187:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,188:jax._src.cache_key:156: get_cache_key hash of serialized computation: c94d89b623872d6e2dc9db5194b837d09184c9f99deabdbd265b9480b0343896
# DEBUG:2025-09-14 10:03:11,188:jax._src.cache_key:162: get_cache_key hash after serializing computation: c94d89b623872d6e2dc9db5194b837d09184c9f99deabdbd265b9480b0343896
# DEBUG:2025-09-14 10:03:11,189:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,189:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 14b2c0abd6dd6faaab7c25584caa0ec81cd09a17b2df23e8947f45a5fa3717c7
# DEBUG:2025-09-14 10:03:11,189:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,190:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a815efef8873c24766dc1f14ce95ccce2b6ebc7a0d3bece1131979eb6d90dc4b
# DEBUG:2025-09-14 10:03:11,190:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,191:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a815efef8873c24766dc1f14ce95ccce2b6ebc7a0d3bece1131979eb6d90dc4b
# DEBUG:2025-09-14 10:03:11,191:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 10:03:11,191:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: efd2b047b62e74b9dc98d9d8a2a71de7a4b43ca9a21b6e9e9f15d16a5ea5bc00
# DEBUG:2025-09-14 10:03:11,192:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,192:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 2519d69cedaa2b15b6d76bb6cdd77131db7d38616a09ba17080af6dff4635bcd
# DEBUG:2025-09-14 10:03:11,193:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,193:jax._src.cache_key:162: get_cache_key hash after serializing compression: 5cab2777fb39d45fa1d4d81968be6b00a0f3edddf56c39a25524d9ec477adbec
# DEBUG:2025-09-14 10:03:11,193:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,194:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 5cab2777fb39d45fa1d4d81968be6b00a0f3edddf56c39a25524d9ec477adbec
# DEBUG:2025-09-14 10:03:11,194:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,194:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-5cab2777fb39d45fa1d4d81968be6b00a0f3edddf56c39a25524d9ec477adbec'
# DEBUG:2025-09-14 10:03:11,231:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.04s)
# DEBUG:2025-09-14 10:03:11,232:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.045073509 sec
# DEBUG:2025-09-14 10:03:11,238:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000180006 sec
# DEBUG:2025-09-14 10:03:11,239:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000324488 sec
# DEBUG:2025-09-14 10:03:11,240:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000332832 sec
# DEBUG:2025-09-14 10:03:11,241:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000268698 sec
# DEBUG:2025-09-14 10:03:11,242:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000210762 sec
# DEBUG:2025-09-14 10:03:11,244:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000432491 sec
# DEBUG:2025-09-14 10:03:11,246:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000457525 sec
# DEBUG:2025-09-14 10:03:11,248:jax._src.dispatch:198: Finished tracing + transforming equal for pjit in 0.000263691 sec
# DEBUG:2025-09-14 10:03:11,250:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000240564 sec
# DEBUG:2025-09-14 10:03:11,251:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001199722 sec
# DEBUG:2025-09-14 10:03:11,251:jax._src.dispatch:198: Finished tracing + transforming _diag for pjit in 0.006209135 sec
# DEBUG:2025-09-14 10:03:11,252:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000198603 sec
# DEBUG:2025-09-14 10:03:11,253:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000259399 sec
# DEBUG:2025-09-14 10:03:11,253:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_hessian for pjit in 0.018567801 sec
# DEBUG:2025-09-14 10:03:11,254:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000177622 sec
# DEBUG:2025-09-14 10:03:11,255:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000064611 sec
# DEBUG:2025-09-14 10:03:11,256:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001098871 sec
# DEBUG:2025-09-14 10:03:11,257:jax._src.dispatch:198: Finished tracing + transforming svd for pjit in 0.000660896 sec
# DEBUG:2025-09-14 10:03:11,259:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000355959 sec
# DEBUG:2025-09-14 10:03:11,260:jax._src.dispatch:198: Finished tracing + transforming greater_equal for pjit in 0.000184536 sec
# DEBUG:2025-09-14 10:03:11,261:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000532150 sec
# DEBUG:2025-09-14 10:03:11,262:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000325918 sec
# DEBUG:2025-09-14 10:03:11,263:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001298666 sec
# DEBUG:2025-09-14 10:03:11,265:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000616074 sec
# DEBUG:2025-09-14 10:03:11,266:jax._src.dispatch:198: Finished tracing + transforming conjugate for pjit in 0.000084639 sec
# DEBUG:2025-09-14 10:03:11,271:jax._src.dispatch:198: Finished tracing + transforming matmul for pjit in 0.003239155 sec
# DEBUG:2025-09-14 10:03:11,272:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000216007 sec
# DEBUG:2025-09-14 10:03:11,273:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000257730 sec
# DEBUG:2025-09-14 10:03:11,274:jax._src.dispatch:198: Finished tracing + transforming conjugate for pjit in 0.000068665 sec
# DEBUG:2025-09-14 10:03:11,276:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000125170 sec
# DEBUG:2025-09-14 10:03:11,278:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000985146 sec
# DEBUG:2025-09-14 10:03:11,279:jax._src.dispatch:198: Finished tracing + transforming sqrt for pjit in 0.000224352 sec
# DEBUG:2025-09-14 10:03:11,279:jax._src.dispatch:198: Finished tracing + transforming norm for pjit in 0.005369186 sec
# DEBUG:2025-09-14 10:03:11,280:jax._src.dispatch:198: Finished tracing + transforming ravel for pjit in 0.000209093 sec
# DEBUG:2025-09-14 10:03:11,281:jax._src.dispatch:198: Finished tracing + transforming _lstsq for pjit in 0.027453899 sec
# DEBUG:2025-09-14 10:03:11,282:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000187159 sec
# DEBUG:2025-09-14 10:03:11,283:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000223160 sec
# DEBUG:2025-09-14 10:03:11,284:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000167370 sec
# DEBUG:2025-09-14 10:03:11,288:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.003492117 sec
# DEBUG:2025-09-14 10:03:11,290:jax._src.dispatch:198: Finished tracing + transforming jax_core_adaptive for pjit in 0.056251526 sec
# DEBUG:2025-09-14 10:03:11,291:jax._src.interpreters.pxla:1865: Compiling jax_core_adaptive with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(float64[40]), ShapedArray(float64[40]), ShapedArray(float64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,307:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_core_adaptive) in 0.015001774 sec
# DEBUG:2025-09-14 10:03:11,308:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,308:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,310:jax._src.cache_key:156: get_cache_key hash of serialized computation: 838562613a1e38528f4f3f38708660f98361bbb5bf99727bfbc0a6280821c44c
# DEBUG:2025-09-14 10:03:11,311:jax._src.cache_key:162: get_cache_key hash after serializing computation: 838562613a1e38528f4f3f38708660f98361bbb5bf99727bfbc0a6280821c44c
# DEBUG:2025-09-14 10:03:11,312:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,312:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 3c636a8f0f74e7666ee68c6e14286620ba889246ffb1faf200a01536ef5b0ad3
# DEBUG:2025-09-14 10:03:11,312:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,313:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 8628dbb8849795684c7b0448cf0a4bef882accf45a30524c112139a5a45587f9
# DEBUG:2025-09-14 10:03:11,313:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,313:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 8628dbb8849795684c7b0448cf0a4bef882accf45a30524c112139a5a45587f9
# DEBUG:2025-09-14 10:03:11,314:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 83304184391a34b36a6bf318011c4ef852e95b6be0c32398b7fa5d4edee2caf6
# DEBUG:2025-09-14 10:03:11,314:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: d135ea78421604be41c7b3470812ffeba4b2b79f4614463707ded0314564462a
# DEBUG:2025-09-14 10:03:11,315:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,315:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 945604df36db065a5bc11e36dd3ad750e03a54c66a4fab088fb46f153cca1635
# DEBUG:2025-09-14 10:03:11,315:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,316:jax._src.cache_key:162: get_cache_key hash after serializing compression: 6c3149ed4bafa4469d3b0b173d4ca6d45ca6c8314c2c54f5e504b784bcded1fb
# DEBUG:2025-09-14 10:03:11,316:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,316:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 6c3149ed4bafa4469d3b0b173d4ca6d45ca6c8314c2c54f5e504b784bcded1fb
# DEBUG:2025-09-14 10:03:11,317:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,317:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-6c3149ed4bafa4469d3b0b173d4ca6d45ca6c8314c2c54f5e504b784bcded1fb'
# DEBUG:2025-09-14 10:03:11,440:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.12s)
# DEBUG:2025-09-14 10:03:11,441:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.131907940 sec
# DEBUG:2025-09-14 10:03:11,444:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000526428 sec
# DEBUG:2025-09-14 10:03:11,445:jax._src.interpreters.pxla:1865: Compiling less with global shapes and types [ShapedArray(float64[]), ShapedArray(float64[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,448:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(less) in 0.002151728 sec
# DEBUG:2025-09-14 10:03:11,449:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,449:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,450:jax._src.cache_key:156: get_cache_key hash of serialized computation: 956df7836d0412b2f0e52d732bb88e3eb008da73f89b3364e6179169b339c615
# DEBUG:2025-09-14 10:03:11,451:jax._src.cache_key:162: get_cache_key hash after serializing computation: 956df7836d0412b2f0e52d732bb88e3eb008da73f89b3364e6179169b339c615
# DEBUG:2025-09-14 10:03:11,451:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,451:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: aad7b7473689b8e8057f1e7e379cf398eaeb22592cb3c84ac30650016b414bac
# DEBUG:2025-09-14 10:03:11,452:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,452:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 3a046639733876c0c60b6a52b64881b1d0b1c6689ba8a92cdfae0a1e5aed3379
# DEBUG:2025-09-14 10:03:11,452:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,453:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 3a046639733876c0c60b6a52b64881b1d0b1c6689ba8a92cdfae0a1e5aed3379
# DEBUG:2025-09-14 10:03:11,453:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,453:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: bce466e19fd82af8289d955e8692c19a4cb4e8ea6d763841945c339d8d349d78
# DEBUG:2025-09-14 10:03:11,454:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,455:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 49702cd82962f5c0321bd95e171c3e3ff1cda399c3d31b403bd49bf2fdbf3cb9
# DEBUG:2025-09-14 10:03:11,455:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,456:jax._src.cache_key:162: get_cache_key hash after serializing compression: b286777679e08eebf17257e78031929420f6e82d9bedbec699bc9ff982c6a210
# DEBUG:2025-09-14 10:03:11,456:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,456:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: b286777679e08eebf17257e78031929420f6e82d9bedbec699bc9ff982c6a210
# DEBUG:2025-09-14 10:03:11,457:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,457:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_less' with key 'jit_less-b286777679e08eebf17257e78031929420f6e82d9bedbec699bc9ff982c6a210'
# DEBUG:2025-09-14 10:03:11,466:jax._src.compiler:839: Not writing persistent cache entry for 'jit_less' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,468:jax._src.dispatch:198: Finished XLA compilation of jit(less) in 0.017282009 sec
# DEBUG:2025-09-14 10:03:11,471:jax._src.dispatch:198: Finished tracing + transforming dynamic_slice for pjit in 0.000402689 sec
# DEBUG:2025-09-14 10:03:11,472:jax._src.interpreters.pxla:1865: Compiling dynamic_slice with global shapes and types [ShapedArray(float64[40]), ShapedArray(int64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,475:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.002407074 sec
# DEBUG:2025-09-14 10:03:11,476:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,477:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,478:jax._src.cache_key:156: get_cache_key hash of serialized computation: c146e84870f6120ccdbc5b47614f33053ffb3bfc2ad0894a71c6f29c62e79528
# DEBUG:2025-09-14 10:03:11,479:jax._src.cache_key:162: get_cache_key hash after serializing computation: c146e84870f6120ccdbc5b47614f33053ffb3bfc2ad0894a71c6f29c62e79528
# DEBUG:2025-09-14 10:03:11,479:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,480:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: ebc5b4d7be264833a64835a03edaea5a0c7d9e6b5185434f75d490b932b7fb4a
# DEBUG:2025-09-14 10:03:11,480:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,481:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 50ae780818f648c36a2279bea2a0a52ea302a74e1ded3f3f6ac690b283e71aaa
# DEBUG:2025-09-14 10:03:11,481:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,481:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 50ae780818f648c36a2279bea2a0a52ea302a74e1ded3f3f6ac690b283e71aaa
# DEBUG:2025-09-14 10:03:11,482:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,482:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: c8a6e626426ed9ad9f93dd0b9420c3538f4f4d92951eefcce0f4347bb5348df2
# DEBUG:2025-09-14 10:03:11,483:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,483:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 6571e52b54da30d00090a7a47ff3931d29da4aee29bd9e959bcf043eb2daaf97
# DEBUG:2025-09-14 10:03:11,484:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,484:jax._src.cache_key:162: get_cache_key hash after serializing compression: ec359d8d63ae64d1ccee01cbec50191c0e99c03a3ad2b5f2e232d8ac602faf05
# DEBUG:2025-09-14 10:03:11,485:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,485:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: ec359d8d63ae64d1ccee01cbec50191c0e99c03a3ad2b5f2e232d8ac602faf05
# DEBUG:2025-09-14 10:03:11,486:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,486:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_dynamic_slice' with key 'jit_dynamic_slice-ec359d8d63ae64d1ccee01cbec50191c0e99c03a3ad2b5f2e232d8ac602faf05'
# DEBUG:2025-09-14 10:03:11,497:jax._src.compiler:839: Not writing persistent cache entry for 'jit_dynamic_slice' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,498:jax._src.dispatch:198: Finished XLA compilation of jit(dynamic_slice) in 0.020513296 sec
# DEBUG:2025-09-14 10:03:11,501:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000390291 sec
# DEBUG:2025-09-14 10:03:11,502:jax._src.interpreters.pxla:1865: Compiling subtract with global shapes and types [ShapedArray(float64[39]), ShapedArray(float64[39])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,504:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(subtract) in 0.001908779 sec
# DEBUG:2025-09-14 10:03:11,505:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,505:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,506:jax._src.cache_key:156: get_cache_key hash of serialized computation: 209245a900a77c6776e5fcb610978bb53e7c51c006d52fb6e94930a230738e40
# DEBUG:2025-09-14 10:03:11,506:jax._src.cache_key:162: get_cache_key hash after serializing computation: 209245a900a77c6776e5fcb610978bb53e7c51c006d52fb6e94930a230738e40
# DEBUG:2025-09-14 10:03:11,506:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,507:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 696e608e0f819814bca6345f294dccb2a605df16586b452a77f4c9f41cb92af4
# DEBUG:2025-09-14 10:03:11,507:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,507:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 9962bfca7076ff38a843dd4f17c955e75937d6aecd85d4f636e115ffbef37d4f
# DEBUG:2025-09-14 10:03:11,508:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,508:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 9962bfca7076ff38a843dd4f17c955e75937d6aecd85d4f636e115ffbef37d4f
# DEBUG:2025-09-14 10:03:11,509:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,509:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 02cd44f50ea619b6bf9c37270b77bc401d3e933cfdb877df078ce97d81010f8b
# DEBUG:2025-09-14 10:03:11,509:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,509:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: cb514e25e0f8d18470dae24794b12ccb6905ce640e15dbbd326f7a28f67d5c9d
# DEBUG:2025-09-14 10:03:11,510:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,510:jax._src.cache_key:162: get_cache_key hash after serializing compression: d2a4e0d636195499c8d74dedb203433038a15271f034925cf162c28aa1243821
# DEBUG:2025-09-14 10:03:11,510:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,510:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: d2a4e0d636195499c8d74dedb203433038a15271f034925cf162c28aa1243821
# DEBUG:2025-09-14 10:03:11,511:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,511:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-d2a4e0d636195499c8d74dedb203433038a15271f034925cf162c28aa1243821'
# DEBUG:2025-09-14 10:03:11,521:jax._src.compiler:839: Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,522:jax._src.dispatch:198: Finished XLA compilation of jit(subtract) in 0.016625643 sec
# DEBUG:2025-09-14 10:03:11,582:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000412464 sec
# DEBUG:2025-09-14 10:03:11,584:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000411510 sec
# DEBUG:2025-09-14 10:03:11,586:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.007826567 sec
# DEBUG:2025-09-14 10:03:11,587:jax._src.interpreters.pxla:1865: Compiling jax_mbar_gradient with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(int64[40]), ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,594:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.005013466 sec
# DEBUG:2025-09-14 10:03:11,595:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,595:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,596:jax._src.cache_key:156: get_cache_key hash of serialized computation: 3aff330d3c5be3b0216392ddb253e7157e55617aa530c2cda6587562878e65d2
# DEBUG:2025-09-14 10:03:11,597:jax._src.cache_key:162: get_cache_key hash after serializing computation: 3aff330d3c5be3b0216392ddb253e7157e55617aa530c2cda6587562878e65d2
# DEBUG:2025-09-14 10:03:11,597:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,597:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 69cff5acdcc9a71dadea53303135b1214cff25928d3c5d021fe8c5df0c2d780a
# DEBUG:2025-09-14 10:03:11,597:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,597:jax._src.cache_key:162: get_cache_key hash after serializing backend version: f43076beb6499e33193ce82ea6e23cf9dd7e4e895e34c23bb672a77b73494d5d
# DEBUG:2025-09-14 10:03:11,598:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,598:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: f43076beb6499e33193ce82ea6e23cf9dd7e4e895e34c23bb672a77b73494d5d
# DEBUG:2025-09-14 10:03:11,598:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 10:03:11,599:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 16e3f3a1b85af30b88a9537b148b2b954cde7cc9a6ac7c124605f680ba8726ad
# DEBUG:2025-09-14 10:03:11,599:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,599:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 2662e5d8d44b0da6ddc990c96ba7ea9c91f347c453aa9c16c7f99dcd09f3a695
# DEBUG:2025-09-14 10:03:11,599:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,599:jax._src.cache_key:162: get_cache_key hash after serializing compression: 7668cb38e622bc50d40346850487c6383cda3f97a4725b12d4c8fb4ef42c3d1c
# DEBUG:2025-09-14 10:03:11,600:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,600:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 7668cb38e622bc50d40346850487c6383cda3f97a4725b12d4c8fb4ef42c3d1c
# DEBUG:2025-09-14 10:03:11,600:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,601:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-7668cb38e622bc50d40346850487c6383cda3f97a4725b12d4c8fb4ef42c3d1c'
# DEBUG:2025-09-14 10:03:11,644:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.04s)
# DEBUG:2025-09-14 10:03:11,645:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.049947262 sec
# DEBUG:2025-09-14 10:03:11,654:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.005198479 sec
# DEBUG:2025-09-14 10:03:11,656:jax._src.interpreters.pxla:1865: Compiling _jit_self_consistent_update with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(int64[40]), ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,662:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_jit_self_consistent_update) in 0.005619764 sec
# DEBUG:2025-09-14 10:03:11,663:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,664:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,665:jax._src.cache_key:156: get_cache_key hash of serialized computation: 9ad0fb8e71cb3133995b3beb70b86af3e599bf7cd7a494bf0c019fc767ed08f9
# DEBUG:2025-09-14 10:03:11,665:jax._src.cache_key:162: get_cache_key hash after serializing computation: 9ad0fb8e71cb3133995b3beb70b86af3e599bf7cd7a494bf0c019fc767ed08f9
# DEBUG:2025-09-14 10:03:11,666:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,666:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: bc942386fc6709f7951f61cb4e80f93c162af31c0c46ca2ae68ee840d3919dc2
# DEBUG:2025-09-14 10:03:11,666:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,666:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 86f179d03f804316b79023053780423cee317f731750bd3722de83da74603558
# DEBUG:2025-09-14 10:03:11,667:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,668:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 86f179d03f804316b79023053780423cee317f731750bd3722de83da74603558
# DEBUG:2025-09-14 10:03:11,669:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 10:03:11,669:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 3072cbde76efce4de757ebf60f72484a73b903cd4edf703f0675d5be675e0a0c
# DEBUG:2025-09-14 10:03:11,669:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,670:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: b2ecaa472c42a20a21b7ada099b402ab384f9da47501cc504c0c73f8cee72ee4
# DEBUG:2025-09-14 10:03:11,670:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,670:jax._src.cache_key:162: get_cache_key hash after serializing compression: 1ecf7d33cf89df48e3806084bf59f8729b6c99126b4f2954390a19f4bbfad5e9
# DEBUG:2025-09-14 10:03:11,670:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,671:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 1ecf7d33cf89df48e3806084bf59f8729b6c99126b4f2954390a19f4bbfad5e9
# DEBUG:2025-09-14 10:03:11,671:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,671:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__jit_self_consistent_update' with key 'jit__jit_self_consistent_update-1ecf7d33cf89df48e3806084bf59f8729b6c99126b4f2954390a19f4bbfad5e9'
# DEBUG:2025-09-14 10:03:11,707:jax._src.compiler:839: Not writing persistent cache entry for 'jit__jit_self_consistent_update' because it took < 1.00 seconds to compile (0.04s)
# DEBUG:2025-09-14 10:03:11,709:jax._src.dispatch:198: Finished XLA compilation of jit(_jit_self_consistent_update) in 0.044754505 sec
# DEBUG:2025-09-14 10:03:11,711:jax._src.dispatch:198: Finished tracing + transforming dynamic_slice for pjit in 0.000352144 sec
# DEBUG:2025-09-14 10:03:11,712:jax._src.interpreters.pxla:1865: Compiling dynamic_slice with global shapes and types [ShapedArray(float64[40]), ShapedArray(int64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,715:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.002427578 sec
# DEBUG:2025-09-14 10:03:11,717:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,717:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,718:jax._src.cache_key:156: get_cache_key hash of serialized computation: 49e6dace15b8ec4acf63157794bebf4df57131142983c8a59069bb99cc45b3b1
# DEBUG:2025-09-14 10:03:11,718:jax._src.cache_key:162: get_cache_key hash after serializing computation: 49e6dace15b8ec4acf63157794bebf4df57131142983c8a59069bb99cc45b3b1
# DEBUG:2025-09-14 10:03:11,718:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,719:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: d628ef87c4b86bac56065ca508bdd6e3e9a35301eaeadb9e038c6cb6ce69a555
# DEBUG:2025-09-14 10:03:11,719:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,719:jax._src.cache_key:162: get_cache_key hash after serializing backend version: d8a2216d63749a06444f9c3d27f8642a4b419289c0394dd1d260ce43e7c4d3dd
# DEBUG:2025-09-14 10:03:11,720:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,720:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: d8a2216d63749a06444f9c3d27f8642a4b419289c0394dd1d260ce43e7c4d3dd
# DEBUG:2025-09-14 10:03:11,720:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,721:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 929efbcb65eba9c3392d105142cfb22ed55c4c3019cf7964593816aeb92eda20
# DEBUG:2025-09-14 10:03:11,721:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,721:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 5afc9aa7620529b454122238a6412cebef1520bd034a0b3b9c47ce94bc202957
# DEBUG:2025-09-14 10:03:11,722:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,722:jax._src.cache_key:162: get_cache_key hash after serializing compression: c6bd3289452e81640886160e345c0dc14f84aa47be1442f9b4edccce5492eb97
# DEBUG:2025-09-14 10:03:11,722:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,723:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: c6bd3289452e81640886160e345c0dc14f84aa47be1442f9b4edccce5492eb97
# DEBUG:2025-09-14 10:03:11,723:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,723:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_dynamic_slice' with key 'jit_dynamic_slice-c6bd3289452e81640886160e345c0dc14f84aa47be1442f9b4edccce5492eb97'
# DEBUG:2025-09-14 10:03:11,733:jax._src.compiler:839: Not writing persistent cache entry for 'jit_dynamic_slice' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,734:jax._src.dispatch:198: Finished XLA compilation of jit(dynamic_slice) in 0.016081572 sec
# DEBUG:2025-09-14 10:03:11,736:jax._src.dispatch:198: Finished tracing + transforming squeeze for pjit in 0.000547409 sec
# DEBUG:2025-09-14 10:03:11,737:jax._src.interpreters.pxla:1865: Compiling squeeze with global shapes and types [ShapedArray(float64[1])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-09-14 10:03:11,740:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(squeeze) in 0.001985550 sec
# DEBUG:2025-09-14 10:03:11,740:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,741:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# ...
# DEBUG:2025-09-14 10:03:11,762:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(subtract) in 0.001961708 sec
# DEBUG:2025-09-14 10:03:11,763:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,763:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,764:jax._src.cache_key:156: get_cache_key hash of serialized computation: 443c8420a04843ac9764ff35c144aff65d0bf6131b542588df83cc2538e24fa0
# DEBUG:2025-09-14 10:03:11,764:jax._src.cache_key:162: get_cache_key hash after serializing computation: 443c8420a04843ac9764ff35c144aff65d0bf6131b542588df83cc2538e24fa0
# DEBUG:2025-09-14 10:03:11,764:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,765:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 8df6078d99152c53d30550daf086b8dfee3fb46f1080f538710664a25cf15117
# DEBUG:2025-09-14 10:03:11,765:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,765:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 3fcd6eb60b4bcb9ebcf372364b5f9c07c08ca89facf85db47961c450d48115d7
# DEBUG:2025-09-14 10:03:11,765:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,766:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 3fcd6eb60b4bcb9ebcf372364b5f9c07c08ca89facf85db47961c450d48115d7
# DEBUG:2025-09-14 10:03:11,766:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,766:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 40b1b5a3c99bad6851059717db816200bb46c963c744c62f34ea4221810b93ec
# DEBUG:2025-09-14 10:03:11,767:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,767:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: da4cdfdb0a5ce3693e106650c65656534ed23592372e9aef2f77333fe4e0db3b
# DEBUG:2025-09-14 10:03:11,768:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,768:jax._src.cache_key:162: get_cache_key hash after serializing compression: 69aa81147d2058e8fae4453974e936d3d6b3f13d91ad9c8dc3d0dde14c6d1fbd
# DEBUG:2025-09-14 10:03:11,768:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,768:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 69aa81147d2058e8fae4453974e936d3d6b3f13d91ad9c8dc3d0dde14c6d1fbd
# DEBUG:2025-09-14 10:03:11,769:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,769:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-69aa81147d2058e8fae4453974e936d3d6b3f13d91ad9c8dc3d0dde14c6d1fbd'
# DEBUG:2025-09-14 10:03:11,779:jax._src.compiler:839: Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,780:jax._src.dispatch:198: Finished XLA compilation of jit(subtract) in 0.016939640 sec
# DEBUG:2025-09-14 10:03:11,785:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_log_W_nk for pjit in 0.002881289 sec
# DEBUG:2025-09-14 10:03:11,786:jax._src.interpreters.pxla:1865: Compiling jax_mbar_log_W_nk with global shapes and types [ShapedArray(float64[40,6560]), ShapedArray(int64[40]), ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,791:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_log_W_nk) in 0.004434109 sec
# DEBUG:2025-09-14 10:03:11,792:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,793:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,794:jax._src.cache_key:156: get_cache_key hash of serialized computation: bda507a12576d1f504851625dc7724ee6e2e88cc22b6507aa5a981c5d704a57a
# DEBUG:2025-09-14 10:03:11,794:jax._src.cache_key:162: get_cache_key hash after serializing computation: bda507a12576d1f504851625dc7724ee6e2e88cc22b6507aa5a981c5d704a57a
# DEBUG:2025-09-14 10:03:11,795:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,795:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: aabb57b3ea231667c98691d0d2c3cdf1075c86f275c7097cde6529d514495255
# DEBUG:2025-09-14 10:03:11,795:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,796:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 0b32c86933806db09b7efc7d11a06b4c7c9beb3b94ea27303d5b13b8c01ae1cb
# DEBUG:2025-09-14 10:03:11,796:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,796:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 0b32c86933806db09b7efc7d11a06b4c7c9beb3b94ea27303d5b13b8c01ae1cb
# DEBUG:2025-09-14 10:03:11,797:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 5ba4fc1ac7356bae4c4a0bb8d5adeec226b0d3f9470098c8769db0e424976544
# DEBUG:2025-09-14 10:03:11,797:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 51bb2da2f384ffc96a830b512a30d3bc5fdb29d8fbfbbcdb1f42a7cf1d12ad34
# DEBUG:2025-09-14 10:03:11,798:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,798:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 13dc38886f3f0dd088ae15df71e84d33d698a65a378ca50498d460974c935785
# DEBUG:2025-09-14 10:03:11,798:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,798:jax._src.cache_key:162: get_cache_key hash after serializing compression: c915f7443f732a3062140dba6767741efa4ab9a3cdaa76f1e7d22fe3e02f9c9b
# DEBUG:2025-09-14 10:03:11,799:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,799:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: c915f7443f732a3062140dba6767741efa4ab9a3cdaa76f1e7d22fe3e02f9c9b
# DEBUG:2025-09-14 10:03:11,799:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,800:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_log_W_nk' with key 'jit_jax_mbar_log_W_nk-c915f7443f732a3062140dba6767741efa4ab9a3cdaa76f1e7d22fe3e02f9c9b'
# DEBUG:2025-09-14 10:03:11,831:jax._src.compiler:839: Not writing persistent cache entry for 'jit_jax_mbar_log_W_nk' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-09-14 10:03:11,832:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_log_W_nk) in 0.038861275 sec
# DEBUG:2025-09-14 10:03:11,836:jax._src.dispatch:198: Finished tracing + transforming _unstack for pjit in 0.001950979 sec
# DEBUG:2025-09-14 10:03:11,837:jax._src.interpreters.pxla:1865: Compiling _unstack with global shapes and types [ShapedArray(float64[40])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-09-14 10:03:11,841:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_unstack) in 0.003129721 sec
# DEBUG:2025-09-14 10:03:11,842:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,842:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,843:jax._src.cache_key:156: get_cache_key hash of serialized computation: 7a6e8e9770c1a4d10309cd6a0bddcca976b3da4a1ff839f15fa9b6ec2588a20e
# DEBUG:2025-09-14 10:03:11,843:jax._src.cache_key:162: get_cache_key hash after serializing computation: 7a6e8e9770c1a4d10309cd6a0bddcca976b3da4a1ff839f15fa9b6ec2588a20e
# DEBUG:2025-09-14 10:03:11,844:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,844:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: a6bcf8ead4a5236f1a47d222fb4233309ad4f68ad951f563cca3f452432fe16e
# DEBUG:2025-09-14 10:03:11,844:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,845:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 6d820319eb2c7d0ea1229b60ddc1d28b9de4f83d9c3e8feb43c3279b15b4e6e1
# DEBUG:2025-09-14 10:03:11,845:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,845:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 6d820319eb2c7d0ea1229b60ddc1d28b9de4f83d9c3e8feb43c3279b15b4e6e1
# DEBUG:2025-09-14 10:03:11,846:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: fd87503854a676ea6fb3c1c9564f6f177d67825607267b23d4eababafe4fb193
# DEBUG:2025-09-14 10:03:11,846:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: b7d96a91a8e8d7a1d9847fc1388b55dde798e7ea188898bdaed2fe31af38ca19
# DEBUG:2025-09-14 10:03:11,847:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,848:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 7c74854f4cad693d741fd77bd22bcb22c7aca36abf0ad0e7d2d4eced950082ef
# DEBUG:2025-09-14 10:03:11,848:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,848:jax._src.cache_key:162: get_cache_key hash after serializing compression: b4369d48b66a5fa218680bfd3c5f62d0226df1777e4ee1d896294cc79b3803c1
# DEBUG:2025-09-14 10:03:11,849:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,850:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: b4369d48b66a5fa218680bfd3c5f62d0226df1777e4ee1d896294cc79b3803c1
# DEBUG:2025-09-14 10:03:11,850:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,850:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__unstack' with key 'jit__unstack-b4369d48b66a5fa218680bfd3c5f62d0226df1777e4ee1d896294cc79b3803c1'
# DEBUG:2025-09-14 10:03:11,875:jax._src.compiler:839: Not writing persistent cache entry for 'jit__unstack' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-09-14 10:03:11,876:jax._src.dispatch:198: Finished XLA compilation of jit(_unstack) in 0.033230782 sec
# DEBUG:2025-09-14 10:03:11,878:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000495195 sec
# DEBUG:2025-09-14 10:03:11,879:jax._src.interpreters.pxla:1865: Compiling subtract with global shapes and types [ShapedArray(float64[40]), ShapedArray(float64[40,1])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-09-14 10:03:11,882:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(subtract) in 0.001961231 sec
# DEBUG:2025-09-14 10:03:11,883:jax._src.compiler:170: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-09-14 10:03:11,883:jax._src.compiler:252: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-09-14 10:03:11,884:jax._src.cache_key:156: get_cache_key hash of serialized computation: c15d4b102dd3e3da06979d60fcd6ba5308f3f7c66e3612b8457a3832fb8df601
# DEBUG:2025-09-14 10:03:11,884:jax._src.cache_key:162: get_cache_key hash after serializing computation: c15d4b102dd3e3da06979d60fcd6ba5308f3f7c66e3612b8457a3832fb8df601
# DEBUG:2025-09-14 10:03:11,884:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: 276ac86581d06a6a2089de6284a136fe303d490a711d879f275cc9a55f1cd807
# DEBUG:2025-09-14 10:03:11,885:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 572c0331493184ac38fcae954a5c9dac7ec608d486ee8de92e4efc3cb8450147
# DEBUG:2025-09-14 10:03:11,885:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-09-14 10:03:11,885:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 23d77f8b307de18c4c38c1f7e1a7ee2723991f0513e20debebb0bae2ee37aa31
# DEBUG:2025-09-14 10:03:11,886:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,886:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 23d77f8b307de18c4c38c1f7e1a7ee2723991f0513e20debebb0bae2ee37aa31
# DEBUG:2025-09-14 10:03:11,886:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 74feed591061bf7000606f7d534a05a4c69546ca0b79950ab67fb14700f5ade2
# DEBUG:2025-09-14 10:03:11,887:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 49f1c72f64b4ad31a7d8298bfb7ca836afebfead0d1b9118a089958c6258a6e5
# DEBUG:2025-09-14 10:03:11,887:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-09-14 10:03:11,887:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 8f4fcb55324822add5dbb86ddf1a9278edb52f77f41eccf77cc0071ce0e005ed
# DEBUG:2025-09-14 10:03:11,888:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-09-14 10:03:11,888:jax._src.cache_key:162: get_cache_key hash after serializing compression: 4e75a548bd0da536c0d1f92446fa7aa516d4f78e8a296f9034d1a7fa1da5f1fa
# DEBUG:2025-09-14 10:03:11,888:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-09-14 10:03:11,889:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 4e75a548bd0da536c0d1f92446fa7aa516d4f78e8a296f9034d1a7fa1da5f1fa
# DEBUG:2025-09-14 10:03:11,889:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-09-14 10:03:11,889:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-4e75a548bd0da536c0d1f92446fa7aa516d4f78e8a296f9034d1a7fa1da5f1fa'
# DEBUG:2025-09-14 10:03:11,904:jax._src.compiler:839: Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-09-14 10:03:11,905:jax._src.dispatch:198: Finished XLA compilation of jit(subtract) in 0.021738052 sec

# %%
from openmmtools.multistate import MultiStateReporter
import mdtraj as md
import numpy as np


reporter_path = "test_run.nc"
pdb_path = 'ligand_in_solvent.pdb'


reporter = MultiStateReporter(reporter_path, open_mode='r')
pdb = md.load(pdb_path)
topology = pdb.topology

# Read the total number of saved iterations
last_iteration = reporter.read_last_iteration()
    
# Create an empty list to store the positions from each iteration
positions = []
    
# Loop through all iterations to extract the positions
# We add 1 to the last_iteration because the iterations are zero-indexed
print(f"Reading {last_iteration + 1} iterations from {reporter_path}...")
for i in range(last_iteration + 1):
    # Read the sampler states for the current iteration
    sampler_states = reporter.read_sampler_states(iteration=i)
        
    # Check if sampler_states is not None and not empty
    if sampler_states is None or len(sampler_states) == 0:
        print(f"Warning: No sampler states found for iteration {i}. Skipping.")
        continue

    # Extract the positions from the first sampler state.
    # This assumes a single-replica simulation or that you only need
    # the trajectory from the first replica.
    print(f"Reading positions from iteration {i}...")
    pos = sampler_states[0].positions
        
    # Append the positions (in nanometers) to our list
    positions.append(pos)

reporter.close()    

traj = md.Trajectory(np.array(positions), topology)
output_dcd_path = "rest_traj.dcd"
traj.save_dcd(output_dcd_path)
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Reading 101 iterations from test_run.nc...
# Reading positions from iteration 0...
# Reading positions from iteration 100...
# Conversion complete! The DCD file has been created at: rest_traj.dcd
