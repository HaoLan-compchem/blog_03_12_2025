# %%
import copy
import openmm as mm
from openmm import app, unit
from openmm.app import PDBFile

# %%
with open('system_with_ligand_only.xml', 'r') as f:
    system_1 = mm.XmlSerializer.deserialize(f.read())
pdb = PDBFile('ligand_in_solvent.pdb')
system_1.addForce(mm.MonteCarloBarostat(1*unit.atmosphere, 300*unit.kelvin))
system_1.getForces()
# Out:
# [<openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7a27ff987f90> >,
#  <openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7a27ff987f30> >,
#  <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7a27ff987f00> >,
#  <openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x7a27ff987ed0> >,
#  <openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7a27ff987ea0> >,
#  <openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x7a27ff987e70> >]

# %%
ligand = list(pdb.topology.residues())[0]
rest_atoms = [atom.index for atom in ligand.atoms()]
len(rest_atoms)
# Out:
# 151

# %%
# Create REST system
rest_system = mm.System()
# Create dict of vanilla system forces (for easy retrieval of force objects later)
system_forces = {type(force).__name__ : force for force in system_1.getForces()}

# Add particles
for particle_idx in range(system_1.getNumParticles()):
    particle_mass = system_1.getParticleMass(particle_idx)
    rest_system.addParticle(particle_mass)

# Copy barostat
if "MonteCarloBarostat" in system_forces:
    barostat = copy.deepcopy(system_forces["MonteCarloBarostat"])
    rest_system.addForce(barostat)

# Copy box vectors
box_vectors = system_1.getDefaultPeriodicBoxVectors()
rest_system.setDefaultPeriodicBoxVectors(*box_vectors)

# Copy constraints
for constraint_idx in range(system_1.getNumConstraints()):
    atom1, atom2, length = system_1.getConstraintParameters(constraint_idx)
    rest_system.addConstraint(atom1, atom2, length)

# %%
# Define the custom expression
bond_expression = "rest_scale * (K / 2) * (r - length)^2;"
bond_expression += "rest_scale = is_rest * lambda_rest_bonds * lambda_rest_bonds " \
                   "+ is_inter * lambda_rest_bonds " \
                   "+ is_nonrest;"

# Create custom force
rest_bond_force = mm.CustomBondForce(bond_expression)
rest_system.addForce(rest_bond_force)

# Add global parameters
rest_bond_force.addGlobalParameter("lambda_rest_bonds", 1.0)

# Add per-bond parameters for rest scaling
rest_bond_force.addPerBondParameter("is_rest")
rest_bond_force.addPerBondParameter("is_inter")
rest_bond_force.addPerBondParameter("is_nonrest")

# Add per-bond parameters for defining bond energy
rest_bond_force.addPerBondParameter('length')  # equilibrium bond length
rest_bond_force.addPerBondParameter('K')  # force constant
# Out:
# 4

# %%
def get_rest_identifier(atoms, rest_atoms):
    """
    For a given atom or set of atoms, get the rest_id which is a list of binary ints that defines which
    (mutually exclusive) set the atom(s) belong to.

    If there is a single atom, the sets are: is_rest, is_nonrest
    If there is a set of atoms, the sets are: is_rest, is_inter, is_nonrest

    Example: if there is a single atom that is in the nonrest set, the rest_id is [0, 1]

    Arguments
    ---------
    atoms : set or int
        a set of hybrid atom indices or single atom
    rest_atoms : set or list
        a list (or list-like) of atoms whose interactions will be scaled by REST
    Returns
    -------
    rest_id : list
        list of binaries indicating which set the atom(s) belong to
    """

    if isinstance(atoms, int):
        rest_id = [0, 1] # Set the default rest_id to non-REST
        if atoms in rest_atoms:
            rest_id = [1, 0]
        return rest_id

    elif isinstance(atoms, set):
        rest_id = [0, 0, 1] # Set the default rest_id to non-REST
        if atoms.intersection(rest_atoms) != set(): # At least one of the atoms is REST
            if atoms.issubset(rest_atoms): # All atoms are REST
                rest_id = [1, 0, 0]
            else: # At least one (but not all) of the atoms is are REST
                rest_id = [0, 1, 0]
        return rest_id

    else:
        raise Exception(f"atoms is of type {type(atoms)}, but only `int` and `set` are allowable")

# %%
# Get vanilla system bond force
bond_force = system_forces['HarmonicBondForce']

# Set periodicity
if bond_force.usesPeriodicBoundaryConditions():
    rest_bond_force.setUsesPeriodicBoundaryConditions(True)

# Add bonds to rest_system
for term_idx in range(bond_force.getNumBonds()):
    # Get the bond parameters and rest id
    p1, p2, r0, k = bond_force.getBondParameters(term_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)
    # Add the bond
    bond_term = (p1, p2, rest_id + [r0, k])
    rest_bond_force.addBond(*bond_term)

# %%
range(bond_force.getNumBonds())
# Out:
# range(0, 79)

# %%
# Define the custom expression
angle_expression = "rest_scale * (K / 2) * (theta - theta0)^2;"
angle_expression += "rest_scale = is_rest * lambda_rest_angles * lambda_rest_angles " \
                    "+ is_inter * lambda_rest_angles " \
                    "+ is_nonrest;"

# Create custom force
rest_angle_force = mm.CustomAngleForce(angle_expression)
rest_system.addForce(rest_angle_force)

# Add global parameters
rest_angle_force.addGlobalParameter("lambda_rest_angles", 1.0)

# Add per-angle parameters for rest scaling
rest_angle_force.addPerAngleParameter("is_rest")
rest_angle_force.addPerAngleParameter("is_inter")
rest_angle_force.addPerAngleParameter("is_nonrest")

# Add per-angle parameters for defining angle energy
rest_angle_force.addPerAngleParameter('theta0')  # equilibrium angle
rest_angle_force.addPerAngleParameter('K')  # force constant

# Get vanilla system angle force
angle_force = system_forces['HarmonicAngleForce']

# Set periodicity
if angle_force.usesPeriodicBoundaryConditions():
    rest_angle_force.setUsesPeriodicBoundaryConditions(True)

# Add angles to rest_system
for term_idx in range(angle_force.getNumAngles()):
    # Get the angle parameters and rest id
    p1, p2, p3, theta0, k = angle_force.getAngleParameters(term_idx)
    idx_set = set([p1, p2, p3])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add the angle
    angle_term = (p1, p2, p3, rest_id + [theta0, k])
    rest_angle_force.addAngle(*angle_term)

# %%
range(angle_force.getNumAngles())
# Out:
# range(0, 294)

# %%
# Define the custom expression
torsion_expression = "rest_scale * U;"
torsion_expression += "rest_scale = is_rest * lambda_rest_torsions * lambda_rest_torsions " \
                      "+ is_inter * lambda_rest_torsions " \
                      "+ is_nonrest;"
torsion_expression += "U = (K * (1 + cos(periodicity * theta - phase)));"

# Create custom force
rest_torsion_force = mm.CustomTorsionForce(torsion_expression)
rest_system.addForce(rest_torsion_force)

# Add global parameters
rest_torsion_force.addGlobalParameter("lambda_rest_torsions", 1.0)

# Add per-torsion parameters for rest scaling
rest_torsion_force.addPerTorsionParameter("is_rest")
rest_torsion_force.addPerTorsionParameter("is_inter")
rest_torsion_force.addPerTorsionParameter("is_nonrest")

# Add per-torsion parameters for defining torsion energy
rest_torsion_force.addPerTorsionParameter('periodicity')
rest_torsion_force.addPerTorsionParameter('phase') # phase offset
rest_torsion_force.addPerTorsionParameter('K') # force constant

# Get vanilla system torsion force
torsion_force = system_forces['PeriodicTorsionForce']

# Set periodicity
if torsion_force.usesPeriodicBoundaryConditions():
    rest_torsion_force.setUsesPeriodicBoundaryConditions(True)

# Add torsions to rest_system
for torsion_idx in range(torsion_force.getNumTorsions()):
    # Get the torsion parameters and rest id
    p1, p2, p3, p4, periodicity, phase, K = torsion_force.getTorsionParameters(torsion_idx)
    idx_set = set([p1, p2, p3, p4])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add torsion
    torsion_term = (p1, p2, p3, p4, rest_id + [periodicity, phase, K])
    rest_torsion_force.addTorsion(*torsion_term)

# %%
range(torsion_force.getNumTorsions())
# Out:
# range(0, 617)

# %%
# Create nonbonded force
rest_nonbonded_force = mm.NonbondedForce()
rest_system.addForce(rest_nonbonded_force)

# Get vanilla system nonbonded force
nonbonded_force = system_forces['NonbondedForce']

# Set the nonbonded method and related parameters
nonbonded_method = nonbonded_force.getNonbondedMethod()
rest_nonbonded_force.setNonbondedMethod(nonbonded_method)
if nonbonded_method != mm.NonbondedForce.NoCutoff:
    epsilon_solvent = nonbonded_force.getReactionFieldDielectric()
    cutoff = nonbonded_force.getCutoffDistance()
    rest_nonbonded_force.setReactionFieldDielectric(epsilon_solvent)
    rest_nonbonded_force.setCutoffDistance(cutoff)
if nonbonded_method in [mm.NonbondedForce.PME, mm.NonbondedForce.Ewald]:
    [alpha_ewald, nx, ny, nz] = nonbonded_force.getPMEParameters()
    delta = nonbonded_force.getEwaldErrorTolerance()
    rest_nonbonded_force.setPMEParameters(alpha_ewald, nx, ny, nz)
    rest_nonbonded_force.setEwaldErrorTolerance(delta)

# Copy switching function from vanilla system
switch_bool = nonbonded_force.getUseSwitchingFunction()
rest_nonbonded_force.setUseSwitchingFunction(switch_bool)
if switch_bool:
    switching_distance = nonbonded_force.getSwitchingDistance()
    rest_nonbonded_force.setSwitchingDistance(switching_distance)

# Copy dispersion correction
dispersion_bool = nonbonded_force.getUseDispersionCorrection()
rest_nonbonded_force.setUseDispersionCorrection(dispersion_bool)

# Add global parameters
rest_nonbonded_force.addGlobalParameter('lambda_rest_electrostatics', 0.)
rest_nonbonded_force.addGlobalParameter('lambda_rest_sterics', 0.)
# Out:
# 1

# %%
# Add nonbondeds to rest_system
for particle_idx in range(nonbonded_force.getNumParticles()):
    # Get the nonbonded parameters and rest id
    q, sigma, epsilon = nonbonded_force.getParticleParameters(particle_idx)
    rest_id = get_rest_identifier(particle_idx, rest_atoms)

    # Add particles and offsets
    if rest_id == [0, 1]: # nonrest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)

    else: # rest
        rest_nonbonded_force.addParticle(q, sigma, epsilon)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_electrostatics', particle_idx, q, 0.0*sigma, epsilon*0.0)
        rest_nonbonded_force.addParticleParameterOffset('lambda_rest_sterics', particle_idx, q*0.0, 0.0*sigma, epsilon)

# Handle exceptions
for exception_idx in range(nonbonded_force.getNumExceptions()):
    # Get exception parameters and rest id
    p1, p2, chargeProd, sigma, epsilon = nonbonded_force.getExceptionParameters(exception_idx)
    idx_set = set([p1, p2])
    rest_id = get_rest_identifier(idx_set, rest_atoms)

    # Add exceptions and offsets
    exc_idx = rest_nonbonded_force.addException(p1, p2, chargeProd, sigma, epsilon)
    if rest_id == [0, 0, 1]: # nonrest
        pass

    elif rest_id == [1, 0, 0]: # rest
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_sterics', exc_idx, chargeProd, 0.0*sigma, epsilon)

    elif rest_id == [0, 1, 0]: # inter
        rest_nonbonded_force.addExceptionParameterOffset('lambda_rest_electrostatics', exc_idx, chargeProd, 0.0*sigma, epsilon)

# %%
range(nonbonded_force.getNumParticles())
# Out:
# range(0, 5047)

# %%
import math
import logging
import numpy as np
from openmmtools.constants import kB
from openmmtools import cache, mcmc, multistate
from openmmtools.multistate import ReplicaExchangeSampler
from openmmtools.states import GlobalParameterState, SamplerState, ThermodynamicState, CompoundThermodynamicState
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
#
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************

# %%
class RESTState(GlobalParameterState):
    lambda_rest_bonds = GlobalParameterState.GlobalParameter('lambda_rest_bonds', standard_value=1.0)
    lambda_rest_angles = GlobalParameterState.GlobalParameter('lambda_rest_angles', standard_value=1.0)
    lambda_rest_torsions = GlobalParameterState.GlobalParameter('lambda_rest_torsions', standard_value=1.0)
    lambda_rest_electrostatics = GlobalParameterState.GlobalParameter('lambda_rest_electrostatics', standard_value=0.0)
    lambda_rest_sterics = GlobalParameterState.GlobalParameter('lambda_rest_sterics', standard_value=0.0)

    def set_rest_parameters(self, beta_m, beta_0):
        """Set all defined lambda parameters to the given value.

        The undefined parameters (i.e. those being set to None) remain undefined.

        Parameters
        ----------
        new_value : float
            The new value for all defined parameters.
        """
        lambda_functions = {'lambda_rest_bonds': lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_angles' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_torsions' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0),
                 'lambda_rest_electrostatics' : lambda beta_m, beta_0 : np.sqrt(beta_m / beta_0) - 1,
                 'lambda_rest_sterics' : lambda beta_m, beta_0 : beta_m / beta_0 - 1
                 }

        for parameter_name in self._parameters:
            if self._parameters[parameter_name] is not None:
                new_value = lambda_functions[parameter_name](beta_m, beta_0)
                setattr(self, parameter_name, new_value)

# %% [markdown]
# Need set temperatures for replicas

# %%
# Set temperatures for each thermodynamic state
n_replicas = 16  # Number of temperature replicas
T_min = 300 * unit.kelvin  # Minimum temperature (i.e., temperature of desired distribution)
T_max = 700 * unit.kelvin  # Maximum temperature
temperatures = [T_min + (T_max - T_min) * (math.exp(float(i) / float(n_replicas-1)) - 1.0) / (math.e - 1.0)
                for i in range(n_replicas)]
temperatures
# Out:
# [Quantity(value=300.0, unit=kelvin),
#  Quantity(value=316.04838149491945, unit=kelvin),
#  Quantity(value=333.20312405878934, unit=kelvin),
#  Quantity(value=351.5404992343366, unit=kelvin),
#  Quantity(value=371.1420366562379, unit=kelvin),
#  Quantity(value=392.0948865392762, unit=kelvin),
#  Quantity(value=414.4922071561075, unit=kelvin),
#  Quantity(value=438.43357902739746, unit=kelvin),
#  Quantity(value=464.0254476658565, unit=kelvin),
#  Quantity(value=491.3815968426518, unit=kelvin),
#  Quantity(value=520.6236544803837, unit=kelvin),
#  Quantity(value=551.8816334218703, unit=kelvin),
#  Quantity(value=585.2945094790493, unit=kelvin),
#  Quantity(value=621.0108393320536, unit=kelvin),
#  Quantity(value=659.1894210256978, unit=kelvin),
#  Quantity(value=700.0, unit=kelvin)]

# %%
# Create reference thermodynamic state
rest_state = RESTState.from_system(rest_system)
thermostate = ThermodynamicState(rest_system, temperature=T_min)
compound_thermodynamic_state = CompoundThermodynamicState(thermostate, composable_states=[rest_state])

# %%
# Create thermodynamic states
sampler_state =  SamplerState(pdb.positions, box_vectors=rest_system.getDefaultPeriodicBoxVectors())
beta_0 = 1/(kB*T_min)
thermodynamic_state_list = []
sampler_state_list = []
for temperature in temperatures:
    # Create a thermodynamic state with REST interactions scaled to the given temperature
    beta_m = 1/(kB*temperature)
    compound_thermodynamic_state_copy = copy.deepcopy(compound_thermodynamic_state)
    compound_thermodynamic_state_copy.set_rest_parameters(beta_m, beta_0)
    thermodynamic_state_list.append(compound_thermodynamic_state_copy)

    # Generate a sampler_state with minimized positions
    context, integrator = cache.global_context_cache.get_context(compound_thermodynamic_state_copy)
    sampler_state.apply_to_context(context, ignore_velocities=True)
    mm.LocalEnergyMinimizer.minimize(context)
    sampler_state.update_from_context(context)
    sampler_state_list.append(copy.deepcopy(sampler_state))

# %% [markdown]
# setting mcmc move interval and iteration numbers

# %%
# Set up sampler
_logger = logging.getLogger()
_logger.setLevel(logging.DEBUG)
move = mcmc.LangevinDynamicsMove(timestep=2*unit.femtoseconds, n_steps=500)
simulation = ReplicaExchangeSampler(mcmc_moves=move, number_of_iterations=10000)

# Run repex
reporter_file = "test_run.nc"
reporter = multistate.MultiStateReporter(reporter_file, checkpoint_interval=10)
simulation.create(thermodynamic_states=thermodynamic_state_list,
                  sampler_states=sampler_state_list,
                  storage=reporter)
simulation.run()
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Please cite the following:
#
#         Friedrichs MS, Eastman P, Vaidyanathan V, Houston M, LeGrand S, Beberg AL, Ensign DL, Bruns CM, and Pande VS. Accelerating molecular dynamic simulations on graphics processing unit. J. Comput. Chem. 30:864, 2009. DOI: 10.1002/jcc.21209
#         Eastman P and Pande VS. OpenMM: A hardware-independent framework for molecular simulations. Comput. Sci. Eng. 12:34, 2010. DOI: 10.1109/MCSE.2010.27
#         Eastman P and Pande VS. Efficient nonbonded interactions for molecular dynamics on a graphics processing unit. J. Comput. Chem. 31:1268, 2010. DOI: 10.1002/jcc.21413
#         Eastman P and Pande VS. Constant constraint matrix approximation: A robust, parallelizable constraint method for molecular simulations. J. Chem. Theor. Comput. 6:434, 2010. DOI: 10.1021/ct900463w
#         Chodera JD and Shirts MR. Replica exchange and expanded ensemble simulations as Gibbs multistate: Simple improvements for enhanced mixing. J. Chem. Phys., 135:194110, 2011. DOI:10.1063/1.3660669
# Warning: The openmmtools.multistate API is experimental and may change in future releases
#
# ******* JAX 64-bit mode is now on! *******
# *     JAX is now set to 64-bit mode!     *
# *   This MAY cause problems with other   *
# *      uses of JAX in the same code.     *
# ******************************************
#
# DEBUG:2025-10-01 12:37:21,444:jax._src.dispatch:198: Finished tracing + transforming _reduce_min for pjit in 0.000539541 sec
# DEBUG:2025-10-01 12:37:21,445:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000307083 sec
# DEBUG:2025-10-01 12:37:21,446:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000211954 sec
# DEBUG:2025-10-01 12:37:21,447:jax._src.dispatch:198: Finished tracing + transforming not_equal for pjit in 0.000377893 sec
# DEBUG:2025-10-01 12:37:21,448:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000342369 sec
# DEBUG:2025-10-01 12:37:21,448:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001031399 sec
# DEBUG:2025-10-01 12:37:21,449:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000056982 sec
# DEBUG:2025-10-01 12:37:21,449:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000266552 sec
# DEBUG:2025-10-01 12:37:21,450:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000092745 sec
# DEBUG:2025-10-01 12:37:21,452:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000343561 sec
# DEBUG:2025-10-01 12:37:21,453:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000197887 sec
# DEBUG:2025-10-01 12:37:21,453:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.000672579 sec
# DEBUG:2025-10-01 12:37:21,454:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000239134 sec
# DEBUG:2025-10-01 12:37:21,455:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000221491 sec
# DEBUG:2025-10-01 12:37:21,456:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001289368 sec
# DEBUG:2025-10-01 12:37:21,457:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000381470 sec
# DEBUG:2025-10-01 12:37:21,458:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000344276 sec
# DEBUG:2025-10-01 12:37:21,459:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000149965 sec
# DEBUG:2025-10-01 12:37:21,460:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000330210 sec
# DEBUG:2025-10-01 12:37:21,461:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000207186 sec
# DEBUG:2025-10-01 12:37:21,461:jax._src.dispatch:198: Finished tracing + transforming jax_precondition_u_kn for pjit in 0.018742085 sec
# DEBUG:2025-10-01 12:37:21,462:jax._src.xla_bridge:475: No jax_plugins namespace packages available
# DEBUG:2025-10-01 12:37:21,469:jax._src.xla_bridge:903: Initializing backend 'cpu'
# DEBUG:2025-10-01 12:37:21,481:jax._src.xla_bridge:917: Backend 'cpu' initialized
# DEBUG:2025-10-01 12:37:21,482:jax._src.xla_bridge:903: Initializing backend 'tpu'
# INFO:2025-10-01 12:37:21,491:jax._src.xla_bridge:830: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# WARNING:2025-10-01 12:37:21,492:jax._src.xla_bridge:872: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# DEBUG:2025-10-01 12:37:21,492:jax._src.interpreters.pxla:1861: Compiling jit(jax_precondition_u_kn) with global shapes and types [ShapedArray(float64[16,2096]), ShapedArray(float64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,542:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_precondition_u_kn) in 0.049256086 sec
# DEBUG:2025-10-01 12:37:21,543:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,543:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,546:jax._src.cache_key:156: get_cache_key hash of serialized computation: 05e082347d2e54d2d9a84e26993f8019f3cd4e9980cd6b40fb44badffea312fc
# DEBUG:2025-10-01 12:37:21,547:jax._src.cache_key:162: get_cache_key hash after serializing computation: 05e082347d2e54d2d9a84e26993f8019f3cd4e9980cd6b40fb44badffea312fc
# DEBUG:2025-10-01 12:37:21,547:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,547:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 28d1595f2647d0e59c72bf9fd6c80fc535bd27084e332affe8fca7751d0958c0
# DEBUG:2025-10-01 12:37:21,547:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,547:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 8f3424fe4dae1f9e54e0836c01c39d88c1f2970914759de9c6b8510630dcbccc
# DEBUG:2025-10-01 12:37:21,548:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,548:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 8f3424fe4dae1f9e54e0836c01c39d88c1f2970914759de9c6b8510630dcbccc
# DEBUG:2025-10-01 12:37:21,549:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-01 12:37:21,549:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 73f7ffe2f417e950a5994614c7208af7ff814f09f7d343a9dd0dfbd657ad8846
# DEBUG:2025-10-01 12:37:21,550:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,550:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 4979c161ee0141a58ea4c9a05d5650466a2677cd615dcd797afe41ccc0004dad
# DEBUG:2025-10-01 12:37:21,550:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,550:jax._src.cache_key:162: get_cache_key hash after serializing compression: f39c9e3e26788bc68322bd0d9317f546ff50629f9d93e11167c1c3304025dd35
# DEBUG:2025-10-01 12:37:21,550:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,551:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: f39c9e3e26788bc68322bd0d9317f546ff50629f9d93e11167c1c3304025dd35
# DEBUG:2025-10-01 12:37:21,551:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,551:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_precondition_u_kn' with key 'jit_jax_precondition_u_kn-f39c9e3e26788bc68322bd0d9317f546ff50629f9d93e11167c1c3304025dd35'
# DEBUG:2025-10-01 12:37:21,675:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_precondition_u_kn' because it took < 1.00 seconds to compile (0.12s)
# DEBUG:2025-10-01 12:37:21,675:jax._src.dispatch:198: Finished XLA compilation of jit(jax_precondition_u_kn) in 0.131811380 sec
# DEBUG:2025-10-01 12:37:21,678:jax._src.dispatch:198: Finished tracing + transforming negative for pjit in 0.000117540 sec
# DEBUG:2025-10-01 12:37:21,679:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000198841 sec
# DEBUG:2025-10-01 12:37:21,680:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000043869 sec
# DEBUG:2025-10-01 12:37:21,680:jax._src.dispatch:198: Finished tracing + transforming _reduce_max for pjit in 0.000497103 sec
# DEBUG:2025-10-01 12:37:21,681:jax._src.dispatch:198: Finished tracing + transforming isfinite for pjit in 0.000098944 sec
# DEBUG:2025-10-01 12:37:21,682:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000276566 sec
# DEBUG:2025-10-01 12:37:21,683:jax._src.dispatch:198: Finished tracing + transforming absolute for pjit in 0.000155210 sec
# DEBUG:2025-10-01 12:37:21,683:jax._src.dispatch:198: Finished tracing + transforming abs for pjit in 0.000700712 sec
# DEBUG:2025-10-01 12:37:21,684:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000163078 sec
# DEBUG:2025-10-01 12:37:21,684:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000103712 sec
# DEBUG:2025-10-01 12:37:21,685:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000119209 sec
# DEBUG:2025-10-01 12:37:21,685:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000237465 sec
# DEBUG:2025-10-01 12:37:21,686:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000112057 sec
# DEBUG:2025-10-01 12:37:21,686:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.009392262 sec
# DEBUG:2025-10-01 12:37:21,687:jax._src.interpreters.pxla:1861: Compiling jit(jax_mbar_gradient) with global shapes and types [ShapedArray(float64[16,2096]), ShapedArray(float64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,694:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.007080555 sec
# DEBUG:2025-10-01 12:37:21,695:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,696:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,697:jax._src.cache_key:156: get_cache_key hash of serialized computation: fa99ee404e32f041a3f9c1aa8fdc5b15717c7924fc03a3f1a246a81f5d7fad5e
# DEBUG:2025-10-01 12:37:21,697:jax._src.cache_key:162: get_cache_key hash after serializing computation: fa99ee404e32f041a3f9c1aa8fdc5b15717c7924fc03a3f1a246a81f5d7fad5e
# DEBUG:2025-10-01 12:37:21,697:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,697:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 19501ef58883882068464b43dc59485993dfbdc08e01cd9a5ad347706d5ba022
# DEBUG:2025-10-01 12:37:21,698:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,698:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 033d76dad95edd07c3319fd0792005dcbba042e7bd4d15ea9cfbcd1feb143883
# DEBUG:2025-10-01 12:37:21,698:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,699:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 033d76dad95edd07c3319fd0792005dcbba042e7bd4d15ea9cfbcd1feb143883
# DEBUG:2025-10-01 12:37:21,699:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-01 12:37:21,699:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 352477220f2e0575ec2dbc6aa4bf16dc1b926163af6cd3ce5a1e5bf0cabe2e49
# DEBUG:2025-10-01 12:37:21,700:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,700:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 8d91fb52b4aa2524dab012951743e3cca1410dc4234d00a3a81b74c58ec8ac17
# DEBUG:2025-10-01 12:37:21,700:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,700:jax._src.cache_key:162: get_cache_key hash after serializing compression: 53fd0094b0529f9e53bcb7227c6aa87f002d72dde4d78db20d5ca0e915bd8445
# DEBUG:2025-10-01 12:37:21,701:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,701:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 53fd0094b0529f9e53bcb7227c6aa87f002d72dde4d78db20d5ca0e915bd8445
# DEBUG:2025-10-01 12:37:21,701:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,701:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-53fd0094b0529f9e53bcb7227c6aa87f002d72dde4d78db20d5ca0e915bd8445'
# DEBUG:2025-10-01 12:37:21,735:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-10-01 12:37:21,735:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.039205313 sec
# DEBUG:2025-10-01 12:37:21,739:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000486374 sec
# DEBUG:2025-10-01 12:37:21,740:jax._src.dispatch:198: Finished tracing + transforming exp for pjit in 0.000164270 sec
# DEBUG:2025-10-01 12:37:21,740:jax._src.dispatch:198: Finished tracing + transforming dot for pjit in 0.000322342 sec
# DEBUG:2025-10-01 12:37:21,741:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000252008 sec
# DEBUG:2025-10-01 12:37:21,742:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000221252 sec
# DEBUG:2025-10-01 12:37:21,743:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000449896 sec
# DEBUG:2025-10-01 12:37:21,744:jax._src.dispatch:198: Finished tracing + transforming add for pjit in 0.000150204 sec
# DEBUG:2025-10-01 12:37:21,744:jax._src.dispatch:198: Finished tracing + transforming equal for pjit in 0.000133514 sec
# DEBUG:2025-10-01 12:37:21,745:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000163794 sec
# DEBUG:2025-10-01 12:37:21,746:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.000706434 sec
# DEBUG:2025-10-01 12:37:21,746:jax._src.dispatch:198: Finished tracing + transforming _diag for pjit in 0.002935171 sec
# DEBUG:2025-10-01 12:37:21,747:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000222206 sec
# DEBUG:2025-10-01 12:37:21,748:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000307798 sec
# DEBUG:2025-10-01 12:37:21,749:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_hessian for pjit in 0.012068987 sec
# DEBUG:2025-10-01 12:37:21,750:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000260592 sec
# DEBUG:2025-10-01 12:37:21,751:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000046492 sec
# DEBUG:2025-10-01 12:37:21,751:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.000841856 sec
# DEBUG:2025-10-01 12:37:21,752:jax._src.dispatch:198: Finished tracing + transforming svd for pjit in 0.000266314 sec
# DEBUG:2025-10-01 12:37:21,753:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000191450 sec
# DEBUG:2025-10-01 12:37:21,754:jax._src.dispatch:198: Finished tracing + transforming greater_equal for pjit in 0.000246048 sec
# DEBUG:2025-10-01 12:37:21,755:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000422001 sec
# DEBUG:2025-10-01 12:37:21,756:jax._src.dispatch:198: Finished tracing + transforming _broadcast_arrays for pjit in 0.000113964 sec
# DEBUG:2025-10-01 12:37:21,756:jax._src.dispatch:198: Finished tracing + transforming _where for pjit in 0.001000881 sec
# DEBUG:2025-10-01 12:37:21,757:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000311136 sec
# DEBUG:2025-10-01 12:37:21,758:jax._src.dispatch:198: Finished tracing + transforming conjugate for pjit in 0.000088692 sec
# DEBUG:2025-10-01 12:37:21,759:jax._src.dispatch:198: Finished tracing + transforming matmul for pjit in 0.000695229 sec
# DEBUG:2025-10-01 12:37:21,760:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000211000 sec
# DEBUG:2025-10-01 12:37:21,760:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000225544 sec
# DEBUG:2025-10-01 12:37:21,761:jax._src.dispatch:198: Finished tracing + transforming conjugate for pjit in 0.000047684 sec
# DEBUG:2025-10-01 12:37:21,762:jax._src.dispatch:198: Finished tracing + transforming real for pjit in 0.000899553 sec
# DEBUG:2025-10-01 12:37:21,763:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000284195 sec
# DEBUG:2025-10-01 12:37:21,764:jax._src.dispatch:198: Finished tracing + transforming sqrt for pjit in 0.000148535 sec
# DEBUG:2025-10-01 12:37:21,764:jax._src.dispatch:198: Finished tracing + transforming norm for pjit in 0.003353596 sec
# DEBUG:2025-10-01 12:37:21,765:jax._src.dispatch:198: Finished tracing + transforming ravel for pjit in 0.000182152 sec
# DEBUG:2025-10-01 12:37:21,765:jax._src.dispatch:198: Finished tracing + transforming _lstsq for pjit in 0.016336679 sec
# DEBUG:2025-10-01 12:37:21,766:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000129700 sec
# DEBUG:2025-10-01 12:37:21,767:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000135422 sec
# DEBUG:2025-10-01 12:37:21,767:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000133514 sec
# DEBUG:2025-10-01 12:37:21,770:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.001987696 sec
# DEBUG:2025-10-01 12:37:21,771:jax._src.dispatch:198: Finished tracing + transforming jax_core_adaptive for pjit in 0.034751177 sec
# DEBUG:2025-10-01 12:37:21,773:jax._src.interpreters.pxla:1861: Compiling jit(jax_core_adaptive) with global shapes and types [ShapedArray(float64[16,2096]), ShapedArray(float64[16]), ShapedArray(float64[16]), ShapedArray(float64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,792:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_core_adaptive) in 0.019428015 sec
# DEBUG:2025-10-01 12:37:21,793:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,794:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,795:jax._src.cache_key:156: get_cache_key hash of serialized computation: 5388973bad3131f96d7713313eb0055d66930bb56d17853beffd347f747868d7
# DEBUG:2025-10-01 12:37:21,795:jax._src.cache_key:162: get_cache_key hash after serializing computation: 5388973bad3131f96d7713313eb0055d66930bb56d17853beffd347f747868d7
# DEBUG:2025-10-01 12:37:21,796:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,796:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 83ba52f99df15f43cfb904249da9c5f6fd58cbed54991abb9c3f0381a8302c42
# DEBUG:2025-10-01 12:37:21,796:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,796:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 1dfc5d2ea6a41aba5843b15cc6cb8db5cfc0f3df0cec056d8eddab92c19652e1
# DEBUG:2025-10-01 12:37:21,797:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,797:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 1dfc5d2ea6a41aba5843b15cc6cb8db5cfc0f3df0cec056d8eddab92c19652e1
# DEBUG:2025-10-01 12:37:21,797:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 436aa0af060555ab91ab9ae8eae74bfa4545847128c99291dce22e7a6c5bfc44
# DEBUG:2025-10-01 12:37:21,797:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: fb65a7cac091bff9dccd73a0e067f12c85afd432ae959d005012e33408bbc652
# DEBUG:2025-10-01 12:37:21,798:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,798:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 75449d7f12f4ab6291023339a2edc069426f68ba414607d9642a06037f59626a
# DEBUG:2025-10-01 12:37:21,798:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,798:jax._src.cache_key:162: get_cache_key hash after serializing compression: 6fdafb7d9602a33e594dfceabb53eda6bd6885ed97b13b6633ffea8bbda7a835
# DEBUG:2025-10-01 12:37:21,799:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,799:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 6fdafb7d9602a33e594dfceabb53eda6bd6885ed97b13b6633ffea8bbda7a835
# DEBUG:2025-10-01 12:37:21,799:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,799:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-6fdafb7d9602a33e594dfceabb53eda6bd6885ed97b13b6633ffea8bbda7a835'
# DEBUG:2025-10-01 12:37:21,878:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.08s)
# DEBUG:2025-10-01 12:37:21,879:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.085453749 sec
# DEBUG:2025-10-01 12:37:21,881:jax._src.dispatch:198: Finished tracing + transforming less for pjit in 0.000259399 sec
# DEBUG:2025-10-01 12:37:21,881:jax._src.interpreters.pxla:1861: Compiling jit(less) with global shapes and types [ShapedArray(float64[]), ShapedArray(float64[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,884:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(less) in 0.002065897 sec
# DEBUG:2025-10-01 12:37:21,885:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,885:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,886:jax._src.cache_key:156: get_cache_key hash of serialized computation: 956df7836d0412b2f0e52d732bb88e3eb008da73f89b3364e6179169b339c615
# DEBUG:2025-10-01 12:37:21,886:jax._src.cache_key:162: get_cache_key hash after serializing computation: 956df7836d0412b2f0e52d732bb88e3eb008da73f89b3364e6179169b339c615
# DEBUG:2025-10-01 12:37:21,886:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,887:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 84c30d17ee367af2a13e41e88756dc96662daa1208da250f55a4d42b06b2995a
# DEBUG:2025-10-01 12:37:21,887:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,887:jax._src.cache_key:162: get_cache_key hash after serializing backend version: c8def54307c2dc4673e4275790de822e6e37c1e2e6212072e824fefeb97c0868
# DEBUG:2025-10-01 12:37:21,888:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,888:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: c8def54307c2dc4673e4275790de822e6e37c1e2e6212072e824fefeb97c0868
# DEBUG:2025-10-01 12:37:21,889:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-10-01 12:37:21,889:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: d61d520ff895651f870cd2969b7208fdb57642ac75609008484a92b5894241bc
# DEBUG:2025-10-01 12:37:21,889:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,890:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 3fee96cb2059533329a19233e0ff2f753481b33a6ed25182666a58160a9edc09
# DEBUG:2025-10-01 12:37:21,890:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,890:jax._src.cache_key:162: get_cache_key hash after serializing compression: a267ffcaa16688e5a5827efb964ad53d620658a22aa549e6863b0ca88a3c9428
# DEBUG:2025-10-01 12:37:21,891:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,891:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: a267ffcaa16688e5a5827efb964ad53d620658a22aa549e6863b0ca88a3c9428
# DEBUG:2025-10-01 12:37:21,891:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,892:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_less' with key 'jit_less-a267ffcaa16688e5a5827efb964ad53d620658a22aa549e6863b0ca88a3c9428'
# DEBUG:2025-10-01 12:37:21,900:jax._src.compiler:831: Not writing persistent cache entry for 'jit_less' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-10-01 12:37:21,900:jax._src.dispatch:198: Finished XLA compilation of jit(less) in 0.014827013 sec
# DEBUG:2025-10-01 12:37:21,928:jax._src.dispatch:198: Finished tracing + transforming dynamic_slice for pjit in 0.000276804 sec
# DEBUG:2025-10-01 12:37:21,929:jax._src.interpreters.pxla:1861: Compiling jit(dynamic_slice) with global shapes and types [ShapedArray(float64[16]), ShapedArray(int64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,932:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.001776934 sec
# DEBUG:2025-10-01 12:37:21,932:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,933:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,933:jax._src.cache_key:156: get_cache_key hash of serialized computation: adb3972227d760379b52aa1789f8924d923595c1dfad24afcf99e0eb0068cf8a
# DEBUG:2025-10-01 12:37:21,934:jax._src.cache_key:162: get_cache_key hash after serializing computation: adb3972227d760379b52aa1789f8924d923595c1dfad24afcf99e0eb0068cf8a
# DEBUG:2025-10-01 12:37:21,934:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,934:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: c89615eaee6649507f390b5123d3aa1667bd3ae83255a89a0e637d0d198bf344
# DEBUG:2025-10-01 12:37:21,934:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,935:jax._src.cache_key:162: get_cache_key hash after serializing backend version: ed54344a05b53de9cfdb5a0a5b7eb1eae9211574768c513a8675a25fa0edebef
# DEBUG:2025-10-01 12:37:21,935:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,935:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: ed54344a05b53de9cfdb5a0a5b7eb1eae9211574768c513a8675a25fa0edebef
# DEBUG:2025-10-01 12:37:21,935:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-10-01 12:37:21,936:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: f0a7cb62199af65927d7c5fd1a22cfe705236fb85046c18733bf570d3dfc5357
# DEBUG:2025-10-01 12:37:21,936:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,936:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 7d1c7509cb3f444e980f5c2b4d98d81390fdbe90a72a8690319abec9f4a8f6c9
# DEBUG:2025-10-01 12:37:21,936:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,936:jax._src.cache_key:162: get_cache_key hash after serializing compression: 19e818a04973015a3c900399c745930c4af0a0db9c88aab0b72c1bcbfd78de31
# DEBUG:2025-10-01 12:37:21,937:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,937:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 19e818a04973015a3c900399c745930c4af0a0db9c88aab0b72c1bcbfd78de31
# DEBUG:2025-10-01 12:37:21,937:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,937:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_dynamic_slice' with key 'jit_dynamic_slice-19e818a04973015a3c900399c745930c4af0a0db9c88aab0b72c1bcbfd78de31'
# DEBUG:2025-10-01 12:37:21,945:jax._src.compiler:831: Not writing persistent cache entry for 'jit_dynamic_slice' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-10-01 12:37:21,946:jax._src.dispatch:198: Finished XLA compilation of jit(dynamic_slice) in 0.012879372 sec
# DEBUG:2025-10-01 12:37:21,948:jax._src.dispatch:198: Finished tracing + transforming subtract for pjit in 0.000246763 sec
# DEBUG:2025-10-01 12:37:21,949:jax._src.interpreters.pxla:1861: Compiling jit(subtract) with global shapes and types [ShapedArray(float64[15]), ShapedArray(float64[15])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:21,951:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(subtract) in 0.001696110 sec
# DEBUG:2025-10-01 12:37:21,952:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:21,952:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:21,953:jax._src.cache_key:156: get_cache_key hash of serialized computation: 77a4b53a2288fd0958d1bf38046fed70f3caad285d42ca961bf1a5cf30f30f1b
# DEBUG:2025-10-01 12:37:21,953:jax._src.cache_key:162: get_cache_key hash after serializing computation: 77a4b53a2288fd0958d1bf38046fed70f3caad285d42ca961bf1a5cf30f30f1b
# DEBUG:2025-10-01 12:37:21,953:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:21,953:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 4316e4a5d2a012fefac2a7be5386558180d329360d22c9041ec887c7d448ab4e
# DEBUG:2025-10-01 12:37:21,953:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:21,954:jax._src.cache_key:162: get_cache_key hash after serializing backend version: c8c6b5436a655757a6b97dd27a38a85b00d47a843285385dd7f4efe3e9f10ea2
# DEBUG:2025-10-01 12:37:21,954:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,955:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: c8c6b5436a655757a6b97dd27a38a85b00d47a843285385dd7f4efe3e9f10ea2
# DEBUG:2025-10-01 12:37:21,955:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-10-01 12:37:21,955:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 8acb44f297162545e1f93fabc469c4350e64671a1a2ee8490aeee7d63092803d
# DEBUG:2025-10-01 12:37:21,955:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:21,956:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 2cc327ef69de397dd67dc063ff8e9275255f03d0bf3219c4502293d66e3c6e44
# DEBUG:2025-10-01 12:37:21,956:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:21,957:jax._src.cache_key:162: get_cache_key hash after serializing compression: bf256fd67ac4a5523f6cbdd41bd905cb78beb461bcf24e9a28885dfcdba4ed74
# DEBUG:2025-10-01 12:37:21,957:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:21,957:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: bf256fd67ac4a5523f6cbdd41bd905cb78beb461bcf24e9a28885dfcdba4ed74
# DEBUG:2025-10-01 12:37:21,957:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:21,958:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-bf256fd67ac4a5523f6cbdd41bd905cb78beb461bcf24e9a28885dfcdba4ed74'
# DEBUG:2025-10-01 12:37:21,966:jax._src.compiler:831: Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-10-01 12:37:21,966:jax._src.dispatch:198: Finished XLA compilation of jit(subtract) in 0.013930082 sec
# DEBUG:2025-10-01 12:37:21,989:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000263929 sec
# DEBUG:2025-10-01 12:37:21,990:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000126123 sec
# DEBUG:2025-10-01 12:37:21,991:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.003611803 sec
# DEBUG:2025-10-01 12:37:21,991:jax._src.interpreters.pxla:1861: Compiling jit(jax_mbar_gradient) with global shapes and types [ShapedArray(float64[16,2096]), ShapedArray(int64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:22,000:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.008541346 sec
# DEBUG:2025-10-01 12:37:22,001:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:22,001:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:22,002:jax._src.cache_key:156: get_cache_key hash of serialized computation: 88344471eaad05068cb7961cbf933f2766c2b3ca065cc481fa14df8d3bb7f35f
# DEBUG:2025-10-01 12:37:22,002:jax._src.cache_key:162: get_cache_key hash after serializing computation: 88344471eaad05068cb7961cbf933f2766c2b3ca065cc481fa14df8d3bb7f35f
# DEBUG:2025-10-01 12:37:22,002:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:22,003:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 3b162ec8f321129484c7495b4e8a444dcebd7f97907969e3dd4e9b94f48b02db
# DEBUG:2025-10-01 12:37:22,003:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:22,003:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 5ca59aaf65e200b51c6c8384ae38326c07e90a50114ca1c5cb8b3cc663fd3dc4
# DEBUG:2025-10-01 12:37:22,003:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,004:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 5ca59aaf65e200b51c6c8384ae38326c07e90a50114ca1c5cb8b3cc663fd3dc4
# DEBUG:2025-10-01 12:37:22,004:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-01 12:37:22,004:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: c239499211db8d7bebc2e8cf71fabf3959a479baf32f1e4dc66f349a5aaf76d3
# DEBUG:2025-10-01 12:37:22,005:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:22,005:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 68acdfdb32b54f117e61fb10b6ecdf8a70587bab31bda90efead2b97af9d16f3
# DEBUG:2025-10-01 12:37:22,005:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:22,005:jax._src.cache_key:162: get_cache_key hash after serializing compression: 07df9d2f9f39fcbc3cc264b0d9fe99e4b63f5b1027f9008681a179cd9ad87911
# DEBUG:2025-10-01 12:37:22,005:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,006:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 07df9d2f9f39fcbc3cc264b0d9fe99e4b63f5b1027f9008681a179cd9ad87911
# DEBUG:2025-10-01 12:37:22,006:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:22,006:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-07df9d2f9f39fcbc3cc264b0d9fe99e4b63f5b1027f9008681a179cd9ad87911'
# DEBUG:2025-10-01 12:37:22,040:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-10-01 12:37:22,040:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.038880587 sec
# DEBUG:2025-10-01 12:37:22,044:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.002046347 sec
# DEBUG:2025-10-01 12:37:22,045:jax._src.interpreters.pxla:1861: Compiling jit(_jit_self_consistent_update) with global shapes and types [ShapedArray(float64[16,2096]), ShapedArray(int64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:22,052:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_jit_self_consistent_update) in 0.006502867 sec
# DEBUG:2025-10-01 12:37:22,052:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:22,053:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:22,054:jax._src.cache_key:156: get_cache_key hash of serialized computation: 1ffe2f3a8b0363a4951acdbaab7ce678faebddd1487edce58835bea54d25968d
# DEBUG:2025-10-01 12:37:22,054:jax._src.cache_key:162: get_cache_key hash after serializing computation: 1ffe2f3a8b0363a4951acdbaab7ce678faebddd1487edce58835bea54d25968d
# DEBUG:2025-10-01 12:37:22,054:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:22,054:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 979c94df78a8ff7fcc5220cdca47bfbac0aa75c4828f3a010d2f87c40d097f10
# DEBUG:2025-10-01 12:37:22,055:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:22,055:jax._src.cache_key:162: get_cache_key hash after serializing backend version: ef2e939aa59643ce2cca2e41f7caeba0ec2f257b874ce63c5dfa56e092478d2e
# DEBUG:2025-10-01 12:37:22,055:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,055:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: ef2e939aa59643ce2cca2e41f7caeba0ec2f257b874ce63c5dfa56e092478d2e
# DEBUG:2025-10-01 12:37:22,055:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-01 12:37:22,056:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: a079693da84a7fda64b2493437500fbe702074390fda7f758f2786f8f4b1d1a1
# DEBUG:2025-10-01 12:37:22,056:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:22,056:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: a789a3c5d9575c604b19584d8e97e601324b4bf1aa686f2a68e10859b847fd3a
# DEBUG:2025-10-01 12:37:22,057:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:22,057:jax._src.cache_key:162: get_cache_key hash after serializing compression: 6d80cb620da36c2bd55dc03a459981f4b359e015b0f46cea496f160b1ddcb206
# DEBUG:2025-10-01 12:37:22,057:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,057:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 6d80cb620da36c2bd55dc03a459981f4b359e015b0f46cea496f160b1ddcb206
# DEBUG:2025-10-01 12:37:22,058:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-01 12:37:22,058:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__jit_self_consistent_update' with key 'jit__jit_self_consistent_update-6d80cb620da36c2bd55dc03a459981f4b359e015b0f46cea496f160b1ddcb206'
# DEBUG:2025-10-01 12:37:22,091:jax._src.compiler:831: Not writing persistent cache entry for 'jit__jit_self_consistent_update' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-10-01 12:37:22,091:jax._src.dispatch:198: Finished XLA compilation of jit(_jit_self_consistent_update) in 0.038450956 sec
# DEBUG:2025-10-01 12:37:22,093:jax._src.dispatch:198: Finished tracing + transforming dynamic_slice for pjit in 0.000189066 sec
# DEBUG:2025-10-01 12:37:22,094:jax._src.interpreters.pxla:1861: Compiling jit(dynamic_slice) with global shapes and types [ShapedArray(float64[16]), ShapedArray(int64[], weak_type=True)]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-01 12:37:22,096:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.001767635 sec
# DEBUG:2025-10-01 12:37:22,096:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-01 12:37:22,097:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-01 12:37:22,097:jax._src.cache_key:156: get_cache_key hash of serialized computation: 1cbf982d1dbea9c6a250ff32fcba7f355c2a042c2a458b50a0e7dea8c5eb565f
# DEBUG:2025-10-01 12:37:22,098:jax._src.cache_key:162: get_cache_key hash after serializing computation: 1cbf982d1dbea9c6a250ff32fcba7f355c2a042c2a458b50a0e7dea8c5eb565f
# DEBUG:2025-10-01 12:37:22,098:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-01 12:37:22,099:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 044a57a497adfbbdeeeb51c5665ec87526627031f5983f9e265332661d25386e
# DEBUG:2025-10-01 12:37:22,099:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-01 12:37:22,099:jax._src.cache_key:162: get_cache_key hash after serializing backend version: e846ab476c3edfe4c11915fe95b774a9988e54808b6759cef9151f519d6fd12a
# DEBUG:2025-10-01 12:37:22,100:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,100:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: e846ab476c3edfe4c11915fe95b774a9988e54808b6759cef9151f519d6fd12a
# DEBUG:2025-10-01 12:37:22,100:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-10-01 12:37:22,100:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 904d3f06460d19c185239c01ecaaee6eb72bb9be8e540cd109638ea64cf26afa
# DEBUG:2025-10-01 12:37:22,100:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-01 12:37:22,101:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: a6c7b340ea7f706d94dd3852f1f5efd525267a8a01cdf9484c5afd13265dbac5
# DEBUG:2025-10-01 12:37:22,101:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-01 12:37:22,101:jax._src.cache_key:162: get_cache_key hash after serializing compression: 158c7e97df5473776e2178dd3a1af1ff974d9e73f1f45202a46f3d3019533524
# DEBUG:2025-10-01 12:37:22,101:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-01 12:37:22,102:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 158c7e97df5473776e2178dd3a1af1ff974d9e73f1f45202a46f3d3019533524
# DEBUG:2025-10-01 12:37:22,102:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# ...
# DEBUG:2025-10-02 00:11:44,553:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-02 00:11:44,555:jax._src.cache_key:156: get_cache_key hash of serialized computation: c96e88f9eec937080e6d6ac472a2b4d3e4958115d7b0638a1f9726268e06f758
# DEBUG:2025-10-02 00:11:44,556:jax._src.cache_key:162: get_cache_key hash after serializing computation: c96e88f9eec937080e6d6ac472a2b4d3e4958115d7b0638a1f9726268e06f758
# DEBUG:2025-10-02 00:11:44,556:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-02 00:11:44,556:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 746c429cf806d92534aa3cbb2acc28b466d79b640a93d5735cfa276c429ac040
# DEBUG:2025-10-02 00:11:44,556:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-02 00:11:44,556:jax._src.cache_key:162: get_cache_key hash after serializing backend version: ca930a840f305b22e2bc3a3a6ab2323214bc545b325d3c1dd2c8f2998b4467b4
# DEBUG:2025-10-02 00:11:44,557:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,557:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: ca930a840f305b22e2bc3a3a6ab2323214bc545b325d3c1dd2c8f2998b4467b4
# DEBUG:2025-10-02 00:11:44,557:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 436aa0af060555ab91ab9ae8eae74bfa4545847128c99291dce22e7a6c5bfc44
# DEBUG:2025-10-02 00:11:44,558:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: ca16fd2297de664b3a6bb9cfa25e54f74c6a140bfc0ac7012529d652ccc3b665
# DEBUG:2025-10-02 00:11:44,558:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-02 00:11:44,558:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: d2ecd48e227297a5392251049b198002fa1cca3fa2d64e7150ef3d3158a6b914
# DEBUG:2025-10-02 00:11:44,558:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-02 00:11:44,558:jax._src.cache_key:162: get_cache_key hash after serializing compression: 7a6db9c4f3b104faeccd0162a7fa8345490b7f0f265bf9b49639d0a4e7c06962
# DEBUG:2025-10-02 00:11:44,559:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,559:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 7a6db9c4f3b104faeccd0162a7fa8345490b7f0f265bf9b49639d0a4e7c06962
# DEBUG:2025-10-02 00:11:44,559:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-02 00:11:44,560:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_core_adaptive' with key 'jit_jax_core_adaptive-7a6db9c4f3b104faeccd0162a7fa8345490b7f0f265bf9b49639d0a4e7c06962'
# DEBUG:2025-10-02 00:11:44,661:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_core_adaptive' because it took < 1.00 seconds to compile (0.10s)
# DEBUG:2025-10-02 00:11:44,662:jax._src.dispatch:198: Finished XLA compilation of jit(jax_core_adaptive) in 0.108071089 sec
# DEBUG:2025-10-02 00:11:44,716:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_gradient for pjit in 0.002291679 sec
# DEBUG:2025-10-02 00:11:44,717:jax._src.interpreters.pxla:1861: Compiling jit(jax_mbar_gradient) with global shapes and types [ShapedArray(float64[16,73600]), ShapedArray(int64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-02 00:11:44,726:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_gradient) in 0.008644581 sec
# DEBUG:2025-10-02 00:11:44,727:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-02 00:11:44,728:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-02 00:11:44,729:jax._src.cache_key:156: get_cache_key hash of serialized computation: 77f10cad77391d3c25101aaa2c093b474815374935e2042f6f840066eb48f4e2
# DEBUG:2025-10-02 00:11:44,730:jax._src.cache_key:162: get_cache_key hash after serializing computation: 77f10cad77391d3c25101aaa2c093b474815374935e2042f6f840066eb48f4e2
# DEBUG:2025-10-02 00:11:44,730:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-02 00:11:44,731:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 0f87f91181e81b3724e4d70e9768e962a41a1760d93dd3166856ccf96c98efc3
# DEBUG:2025-10-02 00:11:44,731:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-02 00:11:44,731:jax._src.cache_key:162: get_cache_key hash after serializing backend version: f4963000b1b733ed25e16180e1794bcf69ad645d40df3a33b9484e8f89a9981a
# DEBUG:2025-10-02 00:11:44,732:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,732:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: f4963000b1b733ed25e16180e1794bcf69ad645d40df3a33b9484e8f89a9981a
# DEBUG:2025-10-02 00:11:44,732:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-02 00:11:44,733:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 964dd5e4bdd46dd8ef90182117711629aa1107c38632b48026efd13c367a133f
# DEBUG:2025-10-02 00:11:44,733:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-02 00:11:44,733:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: f4f9937281775449ffa3eea9947bb6c59aa2a0ad75e00d37da50dfa769c7e0db
# DEBUG:2025-10-02 00:11:44,733:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-02 00:11:44,734:jax._src.cache_key:162: get_cache_key hash after serializing compression: 4ee196bdd942dd16c19975d71ac26e32b1b408e7b8cf47a35c39b135625f4de5
# DEBUG:2025-10-02 00:11:44,734:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,734:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 4ee196bdd942dd16c19975d71ac26e32b1b408e7b8cf47a35c39b135625f4de5
# DEBUG:2025-10-02 00:11:44,734:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-02 00:11:44,735:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_gradient' with key 'jit_jax_mbar_gradient-4ee196bdd942dd16c19975d71ac26e32b1b408e7b8cf47a35c39b135625f4de5'
# DEBUG:2025-10-02 00:11:44,797:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_mbar_gradient' because it took < 1.00 seconds to compile (0.06s)
# DEBUG:2025-10-02 00:11:44,798:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_gradient) in 0.070452929 sec
# DEBUG:2025-10-02 00:11:44,805:jax._src.dispatch:198: Finished tracing + transforming _jit_self_consistent_update for pjit in 0.002412558 sec
# DEBUG:2025-10-02 00:11:44,806:jax._src.interpreters.pxla:1861: Compiling jit(_jit_self_consistent_update) with global shapes and types [ShapedArray(float64[16,73600]), ShapedArray(int64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-02 00:11:44,815:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_jit_self_consistent_update) in 0.008334637 sec
# DEBUG:2025-10-02 00:11:44,816:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-02 00:11:44,816:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-02 00:11:44,818:jax._src.cache_key:156: get_cache_key hash of serialized computation: 5dfaf651d56fc6d5391eea487e24f183c147a494a6d53ca4e81f5a9ff0e8e3db
# DEBUG:2025-10-02 00:11:44,818:jax._src.cache_key:162: get_cache_key hash after serializing computation: 5dfaf651d56fc6d5391eea487e24f183c147a494a6d53ca4e81f5a9ff0e8e3db
# DEBUG:2025-10-02 00:11:44,818:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-02 00:11:44,818:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: e950b936d1a7df0acc126fcecfc148a8af981d51fa175023306a8cd5aca71180
# DEBUG:2025-10-02 00:11:44,819:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-02 00:11:44,819:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 439215997c3dfce80894501667ea5ed219f27d054e2dcdaf60975096b942a985
# DEBUG:2025-10-02 00:11:44,819:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,819:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 439215997c3dfce80894501667ea5ed219f27d054e2dcdaf60975096b942a985
# DEBUG:2025-10-02 00:11:44,820:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-02 00:11:44,820:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 9006f1f5e60090bcf0925f6f783914bb418049048830b3bc8589ebc9a4691640
# DEBUG:2025-10-02 00:11:44,820:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-02 00:11:44,820:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: cfe7257c2b0556d1c7ddc4fcc546d5115996bd1711822acf07b28b00b5579286
# DEBUG:2025-10-02 00:11:44,821:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-02 00:11:44,821:jax._src.cache_key:162: get_cache_key hash after serializing compression: e340468139aadaddf0f5dd7247a2ed6eb71ec8a14427bd0ae10a7fbd00ed3fe0
# DEBUG:2025-10-02 00:11:44,821:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,822:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: e340468139aadaddf0f5dd7247a2ed6eb71ec8a14427bd0ae10a7fbd00ed3fe0
# DEBUG:2025-10-02 00:11:44,822:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-02 00:11:44,822:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__jit_self_consistent_update' with key 'jit__jit_self_consistent_update-e340468139aadaddf0f5dd7247a2ed6eb71ec8a14427bd0ae10a7fbd00ed3fe0'
# DEBUG:2025-10-02 00:11:44,878:jax._src.compiler:831: Not writing persistent cache entry for 'jit__jit_self_consistent_update' because it took < 1.00 seconds to compile (0.06s)
# DEBUG:2025-10-02 00:11:44,879:jax._src.dispatch:198: Finished XLA compilation of jit(_jit_self_consistent_update) in 0.061791182 sec
# DEBUG:2025-10-02 00:11:44,883:jax._src.dispatch:198: Finished tracing + transforming jax_mbar_log_W_nk for pjit in 0.002583027 sec
# DEBUG:2025-10-02 00:11:44,884:jax._src.interpreters.pxla:1861: Compiling jit(jax_mbar_log_W_nk) with global shapes and types [ShapedArray(float64[16,73600]), ShapedArray(int64[16]), ShapedArray(float64[16])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-10-02 00:11:44,892:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(jax_mbar_log_W_nk) in 0.007352352 sec
# DEBUG:2025-10-02 00:11:44,893:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-10-02 00:11:44,893:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-10-02 00:11:44,895:jax._src.cache_key:156: get_cache_key hash of serialized computation: d3a5b6b615ae95bcda981613df6d5609dd39e5df87cd646a7ace446d4898de9c
# DEBUG:2025-10-02 00:11:44,896:jax._src.cache_key:162: get_cache_key hash after serializing computation: d3a5b6b615ae95bcda981613df6d5609dd39e5df87cd646a7ace446d4898de9c
# DEBUG:2025-10-02 00:11:44,896:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-10-02 00:11:44,896:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 2cb1b0582a7c6c6452be72842fe1616a5decc39ecd98239e0a62db14864353b2
# DEBUG:2025-10-02 00:11:44,897:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-10-02 00:11:44,897:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 84e2152cb964af16f8408243350bc4aaaf9c6e425b7463d27d487cecf94effa3
# DEBUG:2025-10-02 00:11:44,897:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,897:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 84e2152cb964af16f8408243350bc4aaaf9c6e425b7463d27d487cecf94effa3
# DEBUG:2025-10-02 00:11:44,898:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: ccd9c2889b05d7a9238b86f7b847b99d7b2a21893108a679db45f2f4ceff4f32
# DEBUG:2025-10-02 00:11:44,898:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: f6b38c22e5827479b54e1d868a10adda4b495c068df4117e2cb4163681edbbf3
# DEBUG:2025-10-02 00:11:44,899:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: 7c9d8943f48170b19cabaa40c8a903edb681c7876c9441669ee42df3c0faf005
# DEBUG:2025-10-02 00:11:44,899:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 88c515eea14b63941066f304c68daa26c58f5c04a78eb5b0b7d6500aadff8b87
# DEBUG:2025-10-02 00:11:44,899:jax._src.cache_key:156: get_cache_key hash of serialized compression: 5c4a59db52b7103852ed48a22fcd2cf336a48c7a4de3211294af3477ef82f814
# DEBUG:2025-10-02 00:11:44,900:jax._src.cache_key:162: get_cache_key hash after serializing compression: e21c1f3c4dec2827785ccc64191d2cc2b9b28c66950a5f0be9d09546807c5dea
# DEBUG:2025-10-02 00:11:44,900:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-10-02 00:11:44,900:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: e21c1f3c4dec2827785ccc64191d2cc2b9b28c66950a5f0be9d09546807c5dea
# DEBUG:2025-10-02 00:11:44,900:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-10-02 00:11:44,901:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_jax_mbar_log_W_nk' with key 'jit_jax_mbar_log_W_nk-e21c1f3c4dec2827785ccc64191d2cc2b9b28c66950a5f0be9d09546807c5dea'
# DEBUG:2025-10-02 00:11:44,950:jax._src.compiler:831: Not writing persistent cache entry for 'jit_jax_mbar_log_W_nk' because it took < 1.00 seconds to compile (0.05s)
# DEBUG:2025-10-02 00:11:44,951:jax._src.dispatch:198: Finished XLA compilation of jit(jax_mbar_log_W_nk) in 0.057826996 sec

# %%
def plot_dihedral_angles(traj_cont, atom_indices):
    dihedral_angles = md.compute_dihedrals(traj_cont, [atom_indices])
    dihedral_angles_deg = np.degrees(dihedral_angles[:, 0])
    #plt.figure(figsize=(8, 6))
    #plt.plot(np.arange(len(dihedral_angles_deg)), dihedral_angles_deg)
    #plt.xlabel('Frame')
    #plt.ylabel('Dihedral Angle (degrees)')
    #plt.title('Dihedral Angle Over Time')
    #plt.ylim(-180, 180)
    #plt.grid(True)
    #plt.show()
    #plt.close()
    plt.figure(figsize=(8, 6))
    sns.kdeplot(dihedral_angles_deg)
    plt.xlabel('Dihedral Angle (degrees)')
    plt.ylabel('Density')
    plt.title('Dihedral Angle Distribution')
    plt.xlim(-180, 180)
    plt.grid(True)
    plt.show()
    plt.close()
    return np.mean(dihedral_angles_deg)

# %%
def plot_distance(traj_cont, atom_indices):
    atom_pairs = np.array([atom_indices])
    distances = md.compute_distances(traj_cont, atom_pairs)
    distance = distances[:, 0]
    #plt.figure(figsize=(8, 6))
    #plt.plot(np.arange(len(distance)), distance
    #plt.xlabel('Frame')
    #plt.ylabel('Distance (nm)')
    #plt.title('Distance Over Time')
    #plt.ylim(0.3, 0.4)
    #plt.grid(True)
    #plt.show()
    #plt.close()
    plt.figure(figsize=(8, 6))
    sns.kdeplot(distance)
    plt.xlabel('Distance (nm)')
    plt.ylabel('Density')
    plt.title('Distance Distribution')
    plt.xlim(0.3, 0.4)
    plt.grid(True)
    plt.show()
    plt.close()
    return np.mean(distance)

# %%
from openmmtools.multistate import MultiStateReporter
import mdtraj as md
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

reporter_path = 'test_run.nc'
storage_path = 'test_run_checkpoint.nc'
pdb_path = 'ligand_in_solvent.pdb'

reporter = MultiStateReporter(reporter_path, open_mode='r')
pdb = md.load(pdb_path)
topology = pdb.topology

last_iteration = reporter.read_last_iteration()    
positions = []
pos_dict = {}

for i in range(last_iteration + 1):
    sampler_states = reporter.read_sampler_states(iteration=i)
    try:
        state_count = len(sampler_states)
        if state_count:
            print(f"Iteration {i} with {state_count} states")
        
        
        for ii in range(state_count):
            pos = sampler_states[ii].positions

            if ii not in pos_dict:
                pos_dict[ii] = []
            pos_dict[ii].append(pos)

            #for iii in dir(sampler_states[ii]):
                #print(iii, getattr(sampler_states[ii], iii))
            
            #if not any(np.array_equal(pos, p) for p in positions):
            positions.append(pos)
    except:
        continue

reporter.close()

traj = md.Trajectory(np.array(positions), topology)
ligand_indices = np.arange(0, 151)
traj.superpose(traj, 0, atom_indices=ligand_indices)
traj_ligand = traj.atom_slice(ligand_indices)

# Remove duplicate geometries
#precision = 1
#rounded_xyz = np.round(traj_ligand.xyz, precision)
#_, unique_indices = np.unique(rounded_xyz.reshape(rounded_xyz.shape[0], -1), axis=0, return_index=True)
#traj_ligand_unique = traj_ligand[unique_indices]
#export to dcd
traj_ligand.save_pdb("rest_ligand_samples.pdb")

for k, v in pos_dict.items():
    traj_k = md.Trajectory(np.array(v), topology)
    ligand_indices = np.arange(0, 151)
    traj_k.superpose(traj_k, 0, atom_indices=ligand_indices)
    traj_k_ligand = traj_k.atom_slice(ligand_indices)
    #calculate RMSD relative to intital structure
    rmsd = md.rmsd(traj_k_ligand, traj_k_ligand, 0)
    plt.plot(range(len(rmsd)), rmsd)

    #To calculate the RMSD between each frame and the previous frame
    #rmsd_fluctuations = []
    #for i in range(1, traj_k_ligand.n_frames):
        #current_frame = traj_k_ligand[i]
        #previous_frame = traj_k_ligand[i-1]
        #rmsd_val = md.rmsd(current_frame, previous_frame)
        #rmsd_fluctuations.append(rmsd_val[0])
    #rmsd_fluctuations = np.array(rmsd_fluctuations)
    #plt.plot(range(len(rmsd_fluctuations)), rmsd_fluctuations)
    
    plot_dihedral_angles(traj_k_ligand, [11, 10, 9, 4])
    plot_distance(traj_k_ligand, [55, 58])

    # Remove duplicate geometries
    #precision = 1
    #rounded_xyz = np.round(traj_ligand.xyz, precision)
    #_, unique_indices = np.unique(rounded_xyz.reshape(rounded_xyz.shape[0], -1), axis=0, return_index=True)
    #traj_ligand_unique = traj_ligand[unique_indices]
    #export to dcd

    traj_k_ligand.save_pdb(f"replica_{k}_ligand_samples.pdb")
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# Iteration 0 with 16 states
# Iteration 10 with 16 states
# Iteration 20 with 16 states
# Iteration 30 with 16 states
# Iteration 40 with 16 states
# Iteration 50 with 16 states
# Iteration 60 with 16 states
# Iteration 70 with 16 states
# Iteration 80 with 16 states
# Iteration 90 with 16 states
# Iteration 100 with 16 states
# Iteration 110 with 16 states
# Iteration 120 with 16 states
# Iteration 130 with 16 states
# Iteration 140 with 16 states
# Iteration 150 with 16 states
# Iteration 160 with 16 states
# Iteration 170 with 16 states
# Iteration 180 with 16 states
# Iteration 190 with 16 states
# Iteration 200 with 16 states
# Iteration 210 with 16 states
# Iteration 220 with 16 states
# Iteration 230 with 16 states
# Iteration 240 with 16 states
# Iteration 250 with 16 states
# Iteration 260 with 16 states
# Iteration 270 with 16 states
# Iteration 280 with 16 states
# Iteration 290 with 16 states
# Iteration 300 with 16 states
# Iteration 310 with 16 states
# Iteration 320 with 16 states
# Iteration 330 with 16 states
# Iteration 340 with 16 states
# Iteration 350 with 16 states
# Iteration 360 with 16 states
# Iteration 370 with 16 states
# Iteration 380 with 16 states
# Iteration 390 with 16 states
# Iteration 400 with 16 states
# Iteration 410 with 16 states
# Iteration 420 with 16 states
# Iteration 430 with 16 states
# Iteration 440 with 16 states
# Iteration 450 with 16 states
# Iteration 460 with 16 states
# Iteration 470 with 16 states
# Iteration 480 with 16 states
# Iteration 490 with 16 states
# Iteration 500 with 16 states
# Iteration 510 with 16 states
# Iteration 520 with 16 states
# Iteration 530 with 16 states
# Iteration 540 with 16 states
# Iteration 550 with 16 states
# Iteration 560 with 16 states
# Iteration 570 with 16 states
# Iteration 580 with 16 states
# Iteration 590 with 16 states
# Iteration 600 with 16 states
# Iteration 610 with 16 states
# Iteration 620 with 16 states
# Iteration 630 with 16 states
# Iteration 640 with 16 states
# Iteration 650 with 16 states
# Iteration 660 with 16 states
# Iteration 670 with 16 states
# Iteration 680 with 16 states
# Iteration 690 with 16 states
# Iteration 700 with 16 states
# Iteration 710 with 16 states
# Iteration 720 with 16 states
# Iteration 730 with 16 states
# Iteration 740 with 16 states
# Iteration 750 with 16 states
# Iteration 760 with 16 states
# Iteration 770 with 16 states
# Iteration 780 with 16 states
# Iteration 790 with 16 states
# Iteration 800 with 16 states
# Iteration 810 with 16 states
# Iteration 820 with 16 states
# Iteration 830 with 16 states
# Iteration 840 with 16 states
# Iteration 850 with 16 states
# Iteration 860 with 16 states
# Iteration 870 with 16 states
# Iteration 880 with 16 states
# Iteration 890 with 16 states
# Iteration 900 with 16 states
# Iteration 910 with 16 states
# Iteration 920 with 16 states
# Iteration 930 with 16 states
# Iteration 940 with 16 states
# Iteration 950 with 16 states
# Iteration 960 with 16 states
# Iteration 970 with 16 states
# Iteration 980 with 16 states
# Iteration 990 with 16 states
# Iteration 1000 with 16 states
# Iteration 1010 with 16 states
# Iteration 1020 with 16 states
# Iteration 1030 with 16 states
# Iteration 1040 with 16 states
# Iteration 1050 with 16 states
# Iteration 1060 with 16 states
# Iteration 1070 with 16 states
# Iteration 1080 with 16 states
# Iteration 1090 with 16 states
# Iteration 1100 with 16 states
# Iteration 1110 with 16 states
# Iteration 1120 with 16 states
# Iteration 1130 with 16 states
# Iteration 1140 with 16 states
# Iteration 1150 with 16 states
# Iteration 1160 with 16 states
# Iteration 1170 with 16 states
# Iteration 1180 with 16 states
# Iteration 1190 with 16 states
# Iteration 1200 with 16 states
# Iteration 1210 with 16 states
# Iteration 1220 with 16 states
# Iteration 1230 with 16 states
# Iteration 1240 with 16 states
# Iteration 1250 with 16 states
# Iteration 1260 with 16 states
# Iteration 1270 with 16 states
# Iteration 1280 with 16 states
# Iteration 1290 with 16 states
# Iteration 1300 with 16 states
# Iteration 1310 with 16 states
# Iteration 1320 with 16 states
# Iteration 1330 with 16 states
# Iteration 1340 with 16 states
# Iteration 1350 with 16 states
# Iteration 1360 with 16 states
# Iteration 1370 with 16 states
# Iteration 1380 with 16 states
# Iteration 1390 with 16 states
# Iteration 1400 with 16 states
# Iteration 1410 with 16 states
# Iteration 1420 with 16 states
# Iteration 1430 with 16 states
# Iteration 1440 with 16 states
# Iteration 1450 with 16 states
# Iteration 1460 with 16 states
# Iteration 1470 with 16 states
# Iteration 1480 with 16 states
# Iteration 1490 with 16 states
# Iteration 1500 with 16 states
# Iteration 1510 with 16 states
# Iteration 1520 with 16 states
# Iteration 1530 with 16 states
# Iteration 1540 with 16 states
# Iteration 1550 with 16 states
# Iteration 1560 with 16 states
# Iteration 1570 with 16 states
# Iteration 1580 with 16 states
# Iteration 1590 with 16 states
# Iteration 1600 with 16 states
# Iteration 1610 with 16 states
# Iteration 1620 with 16 states
# Iteration 1630 with 16 states
# Iteration 1640 with 16 states
# Iteration 1650 with 16 states
# Iteration 1660 with 16 states
# Iteration 1670 with 16 states
# Iteration 1680 with 16 states
# Iteration 1690 with 16 states
# Iteration 1700 with 16 states
# Iteration 1710 with 16 states
# Iteration 1720 with 16 states
# Iteration 1730 with 16 states
# Iteration 1740 with 16 states
# Iteration 1750 with 16 states
# Iteration 1760 with 16 states
# Iteration 1770 with 16 states
# Iteration 1780 with 16 states
# Iteration 1790 with 16 states
# Iteration 1800 with 16 states
# Iteration 1810 with 16 states
# Iteration 1820 with 16 states
# Iteration 1830 with 16 states
# Iteration 1840 with 16 states
# Iteration 1850 with 16 states
# Iteration 1860 with 16 states
# Iteration 1870 with 16 states
# Iteration 1880 with 16 states
# Iteration 1890 with 16 states
# Iteration 1900 with 16 states
# Iteration 1910 with 16 states
# Iteration 1920 with 16 states
# Iteration 1930 with 16 states
# Iteration 1940 with 16 states
# Iteration 1950 with 16 states
# Iteration 1960 with 16 states
# Iteration 1970 with 16 states
# Iteration 1980 with 16 states
# Iteration 1990 with 16 states
# Iteration 2000 with 16 states
# Iteration 2010 with 16 states
# Iteration 2020 with 16 states
# Iteration 2030 with 16 states
# Iteration 2040 with 16 states
# Iteration 2050 with 16 states
# Iteration 2060 with 16 states
# Iteration 2070 with 16 states
# Iteration 2080 with 16 states
# Iteration 2090 with 16 states
# Iteration 2100 with 16 states
# Iteration 2110 with 16 states
# Iteration 2120 with 16 states
# Iteration 2130 with 16 states
# Iteration 2140 with 16 states
# Iteration 2150 with 16 states
# Iteration 2160 with 16 states
# Iteration 2170 with 16 states
# Iteration 2180 with 16 states
# Iteration 2190 with 16 states
# Iteration 2200 with 16 states
# Iteration 2210 with 16 states
# Iteration 2220 with 16 states
# Iteration 2230 with 16 states
# Iteration 2240 with 16 states
# Iteration 2250 with 16 states
# Iteration 2260 with 16 states
# Iteration 2270 with 16 states
# Iteration 2280 with 16 states
# Iteration 2290 with 16 states
# Iteration 2300 with 16 states
# Iteration 2310 with 16 states
# Iteration 2320 with 16 states
# Iteration 2330 with 16 states
# Iteration 2340 with 16 states
# Iteration 2350 with 16 states
# Iteration 2360 with 16 states
# Iteration 2370 with 16 states
# Iteration 2380 with 16 states
# Iteration 2390 with 16 states
# Iteration 2400 with 16 states
# Iteration 2410 with 16 states
# Iteration 2420 with 16 states
# Iteration 2430 with 16 states
# Iteration 2440 with 16 states
# Iteration 2450 with 16 states
# Iteration 2460 with 16 states
# Iteration 2470 with 16 states
# Iteration 2480 with 16 states
# Iteration 2490 with 16 states
# Iteration 2500 with 16 states
# Iteration 2510 with 16 states
# Iteration 2520 with 16 states
# Iteration 2530 with 16 states
# Iteration 2540 with 16 states
# Iteration 2550 with 16 states
# Iteration 2560 with 16 states
# Iteration 2570 with 16 states
# Iteration 2580 with 16 states
# Iteration 2590 with 16 states
# Iteration 2600 with 16 states
# Iteration 2610 with 16 states
# Iteration 2620 with 16 states
# Iteration 2630 with 16 states
# Iteration 2640 with 16 states
# Iteration 2650 with 16 states
# Iteration 2660 with 16 states
# Iteration 2670 with 16 states
# Iteration 2680 with 16 states
# Iteration 2690 with 16 states
# Iteration 2700 with 16 states
# Iteration 2710 with 16 states
# Iteration 2720 with 16 states
# Iteration 2730 with 16 states
# Iteration 2740 with 16 states
# Iteration 2750 with 16 states
# Iteration 2760 with 16 states
# Iteration 2770 with 16 states
# Iteration 2780 with 16 states
# Iteration 2790 with 16 states
# Iteration 2800 with 16 states
# Iteration 2810 with 16 states
# Iteration 2820 with 16 states
# Iteration 2830 with 16 states
# Iteration 2840 with 16 states
# Iteration 2850 with 16 states
# Iteration 2860 with 16 states
# Iteration 2870 with 16 states
# Iteration 2880 with 16 states
# Iteration 2890 with 16 states
# Iteration 2900 with 16 states
# Iteration 2910 with 16 states
# Iteration 2920 with 16 states
# Iteration 2930 with 16 states
# Iteration 2940 with 16 states
# Iteration 2950 with 16 states
# Iteration 2960 with 16 states
# Iteration 2970 with 16 states
# Iteration 2980 with 16 states
# Iteration 2990 with 16 states
# Iteration 3000 with 16 states
# Iteration 3010 with 16 states
# Iteration 3020 with 16 states
# Iteration 3030 with 16 states
# Iteration 3040 with 16 states
# Iteration 3050 with 16 states
# Iteration 3060 with 16 states
# Iteration 3070 with 16 states
# Iteration 3080 with 16 states
# Iteration 3090 with 16 states
# Iteration 3100 with 16 states
# Iteration 3110 with 16 states
# Iteration 3120 with 16 states
# Iteration 3130 with 16 states
# Iteration 3140 with 16 states
# Iteration 3150 with 16 states
# Iteration 3160 with 16 states
# Iteration 3170 with 16 states
# Iteration 3180 with 16 states
# Iteration 3190 with 16 states
# Iteration 3200 with 16 states
# Iteration 3210 with 16 states
# Iteration 3220 with 16 states
# Iteration 3230 with 16 states
# Iteration 3240 with 16 states
# Iteration 3250 with 16 states
# Iteration 3260 with 16 states
# Iteration 3270 with 16 states
# Iteration 3280 with 16 states
# Iteration 3290 with 16 states
# Iteration 3300 with 16 states
# Iteration 3310 with 16 states
# Iteration 3320 with 16 states
# Iteration 3330 with 16 states
# Iteration 3340 with 16 states
# Iteration 3350 with 16 states
# Iteration 3360 with 16 states
# Iteration 3370 with 16 states
# Iteration 3380 with 16 states
# Iteration 3390 with 16 states
# Iteration 3400 with 16 states
# Iteration 3410 with 16 states
# Iteration 3420 with 16 states
# Iteration 3430 with 16 states
# Iteration 3440 with 16 states
# Iteration 3450 with 16 states
# Iteration 3460 with 16 states
# Iteration 3470 with 16 states
# Iteration 3480 with 16 states
# Iteration 3490 with 16 states
# Iteration 3500 with 16 states
# Iteration 3510 with 16 states
# Iteration 3520 with 16 states
# Iteration 3530 with 16 states
# Iteration 3540 with 16 states
# Iteration 3550 with 16 states
# Iteration 3560 with 16 states
# Iteration 3570 with 16 states
# Iteration 3580 with 16 states
# Iteration 3590 with 16 states
# Iteration 3600 with 16 states
# Iteration 3610 with 16 states
# Iteration 3620 with 16 states
# Iteration 3630 with 16 states
# Iteration 3640 with 16 states
# Iteration 3650 with 16 states
# Iteration 3660 with 16 states
# Iteration 3670 with 16 states
# Iteration 3680 with 16 states
# Iteration 3690 with 16 states
# Iteration 3700 with 16 states
# Iteration 3710 with 16 states
# Iteration 3720 with 16 states
# Iteration 3730 with 16 states
# Iteration 3740 with 16 states
# Iteration 3750 with 16 states
# Iteration 3760 with 16 states
# Iteration 3770 with 16 states
# Iteration 3780 with 16 states
# Iteration 3790 with 16 states
# Iteration 3800 with 16 states
# Iteration 3810 with 16 states
# Iteration 3820 with 16 states
# Iteration 3830 with 16 states
# Iteration 3840 with 16 states
# Iteration 3850 with 16 states
# Iteration 3860 with 16 states
# Iteration 3870 with 16 states
# Iteration 3880 with 16 states
# Iteration 3890 with 16 states
# Iteration 3900 with 16 states
# Iteration 3910 with 16 states
# Iteration 3920 with 16 states
# Iteration 3930 with 16 states
# Iteration 3940 with 16 states
# Iteration 3950 with 16 states
# Iteration 3960 with 16 states
# Iteration 3970 with 16 states
# Iteration 3980 with 16 states
# Iteration 3990 with 16 states
# Iteration 4000 with 16 states
# Iteration 4010 with 16 states
# Iteration 4020 with 16 states
# Iteration 4030 with 16 states
# Iteration 4040 with 16 states
# Iteration 4050 with 16 states
# Iteration 4060 with 16 states
# Iteration 4070 with 16 states
# Iteration 4080 with 16 states
# Iteration 4090 with 16 states
# Iteration 4100 with 16 states
# Iteration 4110 with 16 states
# Iteration 4120 with 16 states
# Iteration 4130 with 16 states
# Iteration 4140 with 16 states
# Iteration 4150 with 16 states
# Iteration 4160 with 16 states
# Iteration 4170 with 16 states
# Iteration 4180 with 16 states
# Iteration 4190 with 16 states
# Iteration 4200 with 16 states
# Iteration 4210 with 16 states
# Iteration 4220 with 16 states
# Iteration 4230 with 16 states
# Iteration 4240 with 16 states
# Iteration 4250 with 16 states
# Iteration 4260 with 16 states
# Iteration 4270 with 16 states
# Iteration 4280 with 16 states
# Iteration 4290 with 16 states
# Iteration 4300 with 16 states
# Iteration 4310 with 16 states
# Iteration 4320 with 16 states
# Iteration 4330 with 16 states
# Iteration 4340 with 16 states
# Iteration 4350 with 16 states
# Iteration 4360 with 16 states
# Iteration 4370 with 16 states
# Iteration 4380 with 16 states
# Iteration 4390 with 16 states
# Iteration 4400 with 16 states
# Iteration 4410 with 16 states
# Iteration 4420 with 16 states
# Iteration 4430 with 16 states
# Iteration 4440 with 16 states
# Iteration 4450 with 16 states
# Iteration 4460 with 16 states
# Iteration 4470 with 16 states
# Iteration 4480 with 16 states
# Iteration 4490 with 16 states
# Iteration 4500 with 16 states
# Iteration 4510 with 16 states
# Iteration 4520 with 16 states
# Iteration 4530 with 16 states
# Iteration 4540 with 16 states
# Iteration 4550 with 16 states
# Iteration 4560 with 16 states
# Iteration 4570 with 16 states
# Iteration 4580 with 16 states
# Iteration 4590 with 16 states
# Iteration 4600 with 16 states
# Iteration 4610 with 16 states
# Iteration 4620 with 16 states
# Iteration 4630 with 16 states
# Iteration 4640 with 16 states
# Iteration 4650 with 16 states
# Iteration 4660 with 16 states
# Iteration 4670 with 16 states
# Iteration 4680 with 16 states
# Iteration 4690 with 16 states
# Iteration 4700 with 16 states
# Iteration 4710 with 16 states
# Iteration 4720 with 16 states
# Iteration 4730 with 16 states
# Iteration 4740 with 16 states
# Iteration 4750 with 16 states
# Iteration 4760 with 16 states
# Iteration 4770 with 16 states
# Iteration 4780 with 16 states
# Iteration 4790 with 16 states
# Iteration 4800 with 16 states
# Iteration 4810 with 16 states
# Iteration 4820 with 16 states
# Iteration 4830 with 16 states
# Iteration 4840 with 16 states
# Iteration 4850 with 16 states
# Iteration 4860 with 16 states
# Iteration 4870 with 16 states
# Iteration 4880 with 16 states
# Iteration 4890 with 16 states
# Iteration 4900 with 16 states
# Iteration 4910 with 16 states
# Iteration 4920 with 16 states
# Iteration 4930 with 16 states
# Iteration 4940 with 16 states
# Iteration 4950 with 16 states
# Iteration 4960 with 16 states
# Iteration 4970 with 16 states
# Iteration 4980 with 16 states
# Iteration 4990 with 16 states
# Iteration 5000 with 16 states
# Iteration 5010 with 16 states
# Iteration 5020 with 16 states
# Iteration 5030 with 16 states
# Iteration 5040 with 16 states
# Iteration 5050 with 16 states
# Iteration 5060 with 16 states
# Iteration 5070 with 16 states
# Iteration 5080 with 16 states
# Iteration 5090 with 16 states
# Iteration 5100 with 16 states
# Iteration 5110 with 16 states
# Iteration 5120 with 16 states
# Iteration 5130 with 16 states
# Iteration 5140 with 16 states
# Iteration 5150 with 16 states
# Iteration 5160 with 16 states
# Iteration 5170 with 16 states
# Iteration 5180 with 16 states
# Iteration 5190 with 16 states
# Iteration 5200 with 16 states
# Iteration 5210 with 16 states
# Iteration 5220 with 16 states
# Iteration 5230 with 16 states
# Iteration 5240 with 16 states
# Iteration 5250 with 16 states
# Iteration 5260 with 16 states
# Iteration 5270 with 16 states
# Iteration 5280 with 16 states
# Iteration 5290 with 16 states
# Iteration 5300 with 16 states
# Iteration 5310 with 16 states
# Iteration 5320 with 16 states
# Iteration 5330 with 16 states
# Iteration 5340 with 16 states
# Iteration 5350 with 16 states
# Iteration 5360 with 16 states
# Iteration 5370 with 16 states
# Iteration 5380 with 16 states
# Iteration 5390 with 16 states
# Iteration 5400 with 16 states
# Iteration 5410 with 16 states
# Iteration 5420 with 16 states
# Iteration 5430 with 16 states
# Iteration 5440 with 16 states
# Iteration 5450 with 16 states
# Iteration 5460 with 16 states
# Iteration 5470 with 16 states
# Iteration 5480 with 16 states
# Iteration 5490 with 16 states
# Iteration 5500 with 16 states
# Iteration 5510 with 16 states
# Iteration 5520 with 16 states
# Iteration 5530 with 16 states
# Iteration 5540 with 16 states
# Iteration 5550 with 16 states
# Iteration 5560 with 16 states
# Iteration 5570 with 16 states
# Iteration 5580 with 16 states
# Iteration 5590 with 16 states
# Iteration 5600 with 16 states
# Iteration 5610 with 16 states
# Iteration 5620 with 16 states
# Iteration 5630 with 16 states
# Iteration 5640 with 16 states
# Iteration 5650 with 16 states
# Iteration 5660 with 16 states
# Iteration 5670 with 16 states
# Iteration 5680 with 16 states
# Iteration 5690 with 16 states
# Iteration 5700 with 16 states
# Iteration 5710 with 16 states
# Iteration 5720 with 16 states
# Iteration 5730 with 16 states
# Iteration 5740 with 16 states
# Iteration 5750 with 16 states
# Iteration 5760 with 16 states
# Iteration 5770 with 16 states
# Iteration 5780 with 16 states
# Iteration 5790 with 16 states
# Iteration 5800 with 16 states
# Iteration 5810 with 16 states
# Iteration 5820 with 16 states
# Iteration 5830 with 16 states
# Iteration 5840 with 16 states
# Iteration 5850 with 16 states
# Iteration 5860 with 16 states
# Iteration 5870 with 16 states
# Iteration 5880 with 16 states
# Iteration 5890 with 16 states
# Iteration 5900 with 16 states
# Iteration 5910 with 16 states
# Iteration 5920 with 16 states
# Iteration 5930 with 16 states
# Iteration 5940 with 16 states
# Iteration 5950 with 16 states
# Iteration 5960 with 16 states
# Iteration 5970 with 16 states
# Iteration 5980 with 16 states
# Iteration 5990 with 16 states
# Iteration 6000 with 16 states
# Iteration 6010 with 16 states
# Iteration 6020 with 16 states
# Iteration 6030 with 16 states
# Iteration 6040 with 16 states
# Iteration 6050 with 16 states
# Iteration 6060 with 16 states
# Iteration 6070 with 16 states
# Iteration 6080 with 16 states
# Iteration 6090 with 16 states
# Iteration 6100 with 16 states
# Iteration 6110 with 16 states
# Iteration 6120 with 16 states
# Iteration 6130 with 16 states
# Iteration 6140 with 16 states
# Iteration 6150 with 16 states
# Iteration 6160 with 16 states
# Iteration 6170 with 16 states
# Iteration 6180 with 16 states
# Iteration 6190 with 16 states
# Iteration 6200 with 16 states
# Iteration 6210 with 16 states
# Iteration 6220 with 16 states
# Iteration 6230 with 16 states
# Iteration 6240 with 16 states
# Iteration 6250 with 16 states
# Iteration 6260 with 16 states
# Iteration 6270 with 16 states
# Iteration 6280 with 16 states
# Iteration 6290 with 16 states
# Iteration 6300 with 16 states
# Iteration 6310 with 16 states
# Iteration 6320 with 16 states
# Iteration 6330 with 16 states
# Iteration 6340 with 16 states
# Iteration 6350 with 16 states
# Iteration 6360 with 16 states
# Iteration 6370 with 16 states
# Iteration 6380 with 16 states
# Iteration 6390 with 16 states
# Iteration 6400 with 16 states
# Iteration 6410 with 16 states
# Iteration 6420 with 16 states
# Iteration 6430 with 16 states
# Iteration 6440 with 16 states
# Iteration 6450 with 16 states
# Iteration 6460 with 16 states
# Iteration 6470 with 16 states
# Iteration 6480 with 16 states
# Iteration 6490 with 16 states
# Iteration 6500 with 16 states
# Iteration 6510 with 16 states
# Iteration 6520 with 16 states
# Iteration 6530 with 16 states
# Iteration 6540 with 16 states
# Iteration 6550 with 16 states
# Iteration 6560 with 16 states
# Iteration 6570 with 16 states
# Iteration 6580 with 16 states
# Iteration 6590 with 16 states
# Iteration 6600 with 16 states
# Iteration 6610 with 16 states
# Iteration 6620 with 16 states
# Iteration 6630 with 16 states
# Iteration 6640 with 16 states
# Iteration 6650 with 16 states
# Iteration 6660 with 16 states
# Iteration 6670 with 16 states
# Iteration 6680 with 16 states
# Iteration 6690 with 16 states
# Iteration 6700 with 16 states
# Iteration 6710 with 16 states
# Iteration 6720 with 16 states
# Iteration 6730 with 16 states
# Iteration 6740 with 16 states
# Iteration 6750 with 16 states
# Iteration 6760 with 16 states
# Iteration 6770 with 16 states
# Iteration 6780 with 16 states
# Iteration 6790 with 16 states
# Iteration 6800 with 16 states
# Iteration 6810 with 16 states
# Iteration 6820 with 16 states
# Iteration 6830 with 16 states
# Iteration 6840 with 16 states
# Iteration 6850 with 16 states
# Iteration 6860 with 16 states
# Iteration 6870 with 16 states
# Iteration 6880 with 16 states
# Iteration 6890 with 16 states
# Iteration 6900 with 16 states
# Iteration 6910 with 16 states
# Iteration 6920 with 16 states
# Iteration 6930 with 16 states
# Iteration 6940 with 16 states
# Iteration 6950 with 16 states
# Iteration 6960 with 16 states
# Iteration 6970 with 16 states
# Iteration 6980 with 16 states
# Iteration 6990 with 16 states
# Iteration 7000 with 16 states
# Iteration 7010 with 16 states
# Iteration 7020 with 16 states
# Iteration 7030 with 16 states
# Iteration 7040 with 16 states
# Iteration 7050 with 16 states
# Iteration 7060 with 16 states
# Iteration 7070 with 16 states
# Iteration 7080 with 16 states
# Iteration 7090 with 16 states
# Iteration 7100 with 16 states
# Iteration 7110 with 16 states
# Iteration 7120 with 16 states
# Iteration 7130 with 16 states
# Iteration 7140 with 16 states
# Iteration 7150 with 16 states
# Iteration 7160 with 16 states
# Iteration 7170 with 16 states
# Iteration 7180 with 16 states
# Iteration 7190 with 16 states
# Iteration 7200 with 16 states
# Iteration 7210 with 16 states
# Iteration 7220 with 16 states
# Iteration 7230 with 16 states
# Iteration 7240 with 16 states
# Iteration 7250 with 16 states
# Iteration 7260 with 16 states
# Iteration 7270 with 16 states
# Iteration 7280 with 16 states
# Iteration 7290 with 16 states
# Iteration 7300 with 16 states
# Iteration 7310 with 16 states
# Iteration 7320 with 16 states
# Iteration 7330 with 16 states
# Iteration 7340 with 16 states
# Iteration 7350 with 16 states
# Iteration 7360 with 16 states
# Iteration 7370 with 16 states
# Iteration 7380 with 16 states
# Iteration 7390 with 16 states
# Iteration 7400 with 16 states
# Iteration 7410 with 16 states
# Iteration 7420 with 16 states
# Iteration 7430 with 16 states
# Iteration 7440 with 16 states
# Iteration 7450 with 16 states
# Iteration 7460 with 16 states
# Iteration 7470 with 16 states
# Iteration 7480 with 16 states
# Iteration 7490 with 16 states
# Iteration 7500 with 16 states
# Iteration 7510 with 16 states
# Iteration 7520 with 16 states
# Iteration 7530 with 16 states
# Iteration 7540 with 16 states
# Iteration 7550 with 16 states
# Iteration 7560 with 16 states
# Iteration 7570 with 16 states
# Iteration 7580 with 16 states
# Iteration 7590 with 16 states
# Iteration 7600 with 16 states
# Iteration 7610 with 16 states
# Iteration 7620 with 16 states
# Iteration 7630 with 16 states
# Iteration 7640 with 16 states
# Iteration 7650 with 16 states
# Iteration 7660 with 16 states
# Iteration 7670 with 16 states
# Iteration 7680 with 16 states
# Iteration 7690 with 16 states
# Iteration 7700 with 16 states
# Iteration 7710 with 16 states
# Iteration 7720 with 16 states
# Iteration 7730 with 16 states
# Iteration 7740 with 16 states
# Iteration 7750 with 16 states
# Iteration 7760 with 16 states
# Iteration 7770 with 16 states
# Iteration 7780 with 16 states
# Iteration 7790 with 16 states
# Iteration 7800 with 16 states
# Iteration 7810 with 16 states
# Iteration 7820 with 16 states
# Iteration 7830 with 16 states
# Iteration 7840 with 16 states
# Iteration 7850 with 16 states
# Iteration 7860 with 16 states
# Iteration 7870 with 16 states
# Iteration 7880 with 16 states
# Iteration 7890 with 16 states
# Iteration 7900 with 16 states
# Iteration 7910 with 16 states
# Iteration 7920 with 16 states
# Iteration 7930 with 16 states
# Iteration 7940 with 16 states
# Iteration 7950 with 16 states
# Iteration 7960 with 16 states
# Iteration 7970 with 16 states
# Iteration 7980 with 16 states
# Iteration 7990 with 16 states
# Iteration 8000 with 16 states
# Iteration 8010 with 16 states
# Iteration 8020 with 16 states
# Iteration 8030 with 16 states
# Iteration 8040 with 16 states
# Iteration 8050 with 16 states
# Iteration 8060 with 16 states
# Iteration 8070 with 16 states
# Iteration 8080 with 16 states
# Iteration 8090 with 16 states
# Iteration 8100 with 16 states
# Iteration 8110 with 16 states
# Iteration 8120 with 16 states
# Iteration 8130 with 16 states
# Iteration 8140 with 16 states
# Iteration 8150 with 16 states
# Iteration 8160 with 16 states
# Iteration 8170 with 16 states
# Iteration 8180 with 16 states
# Iteration 8190 with 16 states
# Iteration 8200 with 16 states
# Iteration 8210 with 16 states
# Iteration 8220 with 16 states
# Iteration 8230 with 16 states
# Iteration 8240 with 16 states
# Iteration 8250 with 16 states
# Iteration 8260 with 16 states
# Iteration 8270 with 16 states
# Iteration 8280 with 16 states
# Iteration 8290 with 16 states
# Iteration 8300 with 16 states
# Iteration 8310 with 16 states
# Iteration 8320 with 16 states
# Iteration 8330 with 16 states
# Iteration 8340 with 16 states
# Iteration 8350 with 16 states
# Iteration 8360 with 16 states
# Iteration 8370 with 16 states
# Iteration 8380 with 16 states
# Iteration 8390 with 16 states
# Iteration 8400 with 16 states
# Iteration 8410 with 16 states
# Iteration 8420 with 16 states
# Iteration 8430 with 16 states
# Iteration 8440 with 16 states
# Iteration 8450 with 16 states
# Iteration 8460 with 16 states
# Iteration 8470 with 16 states
# Iteration 8480 with 16 states
# Iteration 8490 with 16 states
# Iteration 8500 with 16 states
# Iteration 8510 with 16 states
# Iteration 8520 with 16 states
# Iteration 8530 with 16 states
# Iteration 8540 with 16 states
# Iteration 8550 with 16 states
# Iteration 8560 with 16 states
# Iteration 8570 with 16 states
# Iteration 8580 with 16 states
# Iteration 8590 with 16 states
# Iteration 8600 with 16 states
# Iteration 8610 with 16 states
# Iteration 8620 with 16 states
# Iteration 8630 with 16 states
# Iteration 8640 with 16 states
# Iteration 8650 with 16 states
# Iteration 8660 with 16 states
# Iteration 8670 with 16 states
# Iteration 8680 with 16 states
# Iteration 8690 with 16 states
# Iteration 8700 with 16 states
# Iteration 8710 with 16 states
# Iteration 8720 with 16 states
# Iteration 8730 with 16 states
# Iteration 8740 with 16 states
# Iteration 8750 with 16 states
# Iteration 8760 with 16 states
# Iteration 8770 with 16 states
# Iteration 8780 with 16 states
# Iteration 8790 with 16 states
# Iteration 8800 with 16 states
# Iteration 8810 with 16 states
# Iteration 8820 with 16 states
# Iteration 8830 with 16 states
# Iteration 8840 with 16 states
# Iteration 8850 with 16 states
# Iteration 8860 with 16 states
# Iteration 8870 with 16 states
# Iteration 8880 with 16 states
# Iteration 8890 with 16 states
# Iteration 8900 with 16 states
# Iteration 8910 with 16 states
# Iteration 8920 with 16 states
# Iteration 8930 with 16 states
# Iteration 8940 with 16 states
# Iteration 8950 with 16 states
# Iteration 8960 with 16 states
# Iteration 8970 with 16 states
# Iteration 8980 with 16 states
# Iteration 8990 with 16 states
# Iteration 9000 with 16 states
# Iteration 9010 with 16 states
# Iteration 9020 with 16 states
# Iteration 9030 with 16 states
# Iteration 9040 with 16 states
# Iteration 9050 with 16 states
# Iteration 9060 with 16 states
# Iteration 9070 with 16 states
# Iteration 9080 with 16 states
# Iteration 9090 with 16 states
# Iteration 9100 with 16 states
# Iteration 9110 with 16 states
# Iteration 9120 with 16 states
# Iteration 9130 with 16 states
# Iteration 9140 with 16 states
# Iteration 9150 with 16 states
# Iteration 9160 with 16 states
# Iteration 9170 with 16 states
# Iteration 9180 with 16 states
# Iteration 9190 with 16 states
# Iteration 9200 with 16 states
# Iteration 9210 with 16 states
# Iteration 9220 with 16 states
# Iteration 9230 with 16 states
# Iteration 9240 with 16 states
# Iteration 9250 with 16 states
# Iteration 9260 with 16 states
# Iteration 9270 with 16 states
# Iteration 9280 with 16 states
# Iteration 9290 with 16 states
# Iteration 9300 with 16 states
# Iteration 9310 with 16 states
# Iteration 9320 with 16 states
# Iteration 9330 with 16 states
# Iteration 9340 with 16 states
# Iteration 9350 with 16 states
# Iteration 9360 with 16 states
# Iteration 9370 with 16 states
# Iteration 9380 with 16 states
# Iteration 9390 with 16 states
# Iteration 9400 with 16 states
# Iteration 9410 with 16 states
# Iteration 9420 with 16 states
# Iteration 9430 with 16 states
# Iteration 9440 with 16 states
# Iteration 9450 with 16 states
# Iteration 9460 with 16 states
# Iteration 9470 with 16 states
# Iteration 9480 with 16 states
# Iteration 9490 with 16 states
# Iteration 9500 with 16 states
# Iteration 9510 with 16 states
# Iteration 9520 with 16 states
# Iteration 9530 with 16 states
# Iteration 9540 with 16 states
# Iteration 9550 with 16 states
# Iteration 9560 with 16 states
# Iteration 9570 with 16 states
# Iteration 9580 with 16 states
# Iteration 9590 with 16 states
# Iteration 9600 with 16 states
# Iteration 9610 with 16 states
# Iteration 9620 with 16 states
# Iteration 9630 with 16 states
# Iteration 9640 with 16 states
# Iteration 9650 with 16 states
# Iteration 9660 with 16 states
# Iteration 9670 with 16 states
# Iteration 9680 with 16 states
# Iteration 9690 with 16 states
# Iteration 9700 with 16 states
# Iteration 9710 with 16 states
# Iteration 9720 with 16 states
# Iteration 9730 with 16 states
# Iteration 9740 with 16 states
# Iteration 9750 with 16 states
# Iteration 9760 with 16 states
# Iteration 9770 with 16 states
# Iteration 9780 with 16 states
# Iteration 9790 with 16 states
# Iteration 9800 with 16 states
# Iteration 9810 with 16 states
# Iteration 9820 with 16 states
# Iteration 9830 with 16 states
# Iteration 9840 with 16 states
# Iteration 9850 with 16 states
# Iteration 9860 with 16 states
# Iteration 9870 with 16 states
# Iteration 9880 with 16 states
# Iteration 9890 with 16 states
# Iteration 9900 with 16 states
# Iteration 9910 with 16 states
# Iteration 9920 with 16 states
# Iteration 9930 with 16 states
# Iteration 9940 with 16 states
# Iteration 9950 with 16 states
# Iteration 9960 with 16 states
# Iteration 9970 with 16 states
# Iteration 9980 with 16 states
# Iteration 9990 with 16 states
# Iteration 10000 with 16 states

# %%
velocity_data_list = []
reporter = MultiStateReporter(reporter_path, open_mode='r')
pdb = md.load(pdb_path)
topology = pdb.topology
for i in range(0, 5000):
    states = reporter.read_sampler_states(iteration=i)
    if states:
        for re, ii in enumerate(states):
            print('replica', re)
            velocity_data_list.append(ii.velocities)
            #for iii in dir(ii):
                #print(iii, getattr(ii, iii))
# Out:
# Warning: The openmmtools.multistate API is experimental and may change in future releases
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# ...
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15
# replica 0
# replica 1
# replica 2
# replica 3
# replica 4
# replica 5
# replica 6
# replica 7
# replica 8
# replica 9
# replica 10
# replica 11
# replica 12
# replica 13
# replica 14
# replica 15

# %%
import pandas as pd
import numpy as np
from pint import UnitRegistry
import mdtraj as md
from openmm import unit
from openmm.unit import Quantity

BOLTZ = 1.380649e-23 # J/K
AMU_TO_KG = 1.66053906660e-27      # kg/amu
NM_TO_M = 1.0e-9                  # m/nm
PS_TO_S = 1.0e-12                 # s/ps

masses = np.array([atom.element.mass for atom in traj_ligand.topology.atoms])
masses_in_si = masses * AMU_TO_KG  # Convert to kg

temperatures = []

# Loop through each frame's velocity data
for frame_velocities_data in velocity_data_list:
    velocities = unit.Quantity(frame_velocities_data[:151], unit.nanometer/unit.picosecond)
    velocities_in_si = velocities * (NM_TO_M / PS_TO_S)  # Convert to m/s
    
    # Calculate kinetic energy per atom using openmm.unit
    v2_per_atom = np.sum(velocities_in_si**2, axis=1) # (m/s)^2
    ke_per_atom = 0.5 * masses_in_si * v2_per_atom # kg*(m/s)^2 = J
    total_kinetic_energy = np.sum(ke_per_atom) # J

    # Degrees of freedom (approximated as 3N)
    num_dof = 3 * traj_ligand.topology.n_atoms
    
    # Calculate temperature using openmm.unit
    temperature = (2 * total_kinetic_energy) / (num_dof * BOLTZ)
    temp = temperature._value
    temperatures.append(temp)

temperatures = [q._value for q in temperatures]
df = pd.DataFrame() 
for frame, i in enumerate(temperatures): 
    df.loc[frame, 'Temperature'] = i

df.sort_values(by='Temperature', inplace=True)
df.index.name = 'Frame'
frames_to_extract = list(df.iloc[:101, :].index)
df.to_csv('rest_temperatures.csv', index=True)

# %%
subset_traj = traj[frames_to_extract]
subset_traj.save_pdb(f"lambda_1_tempering_samples.pdb")

# %%
NMPS_TO_MS = NM_TO_M / PS_TO_S  # = 1e3 -> nm/ps -> m/s

masses_amu = np.array([atom.element.mass for atom in traj.topology.atoms])  # amu
masses_kg = masses_amu * AMU_TO_KG
N = traj.topology.n_atoms

def analyze_frame(frame_velocities_nmps, masses_kg, masses_amu, print_out=True):
    # Convert velocities to m/s
    v_ms = np.array(frame_velocities_nmps) * NMPS_TO_MS   # m/s

    # Mass-weighted COM velocity (use kg)
    v_com = np.sum(masses_kg[:,None] * v_ms, axis=0) / np.sum(masses_kg)

    # velocities relative to COM
    v_rel = v_ms - v_com

    # per-atom v^2
    v2_per_atom = np.sum(v_rel**2, axis=1)   # m^2/s^2

    # KE per atom (J)
    ke_per_atom = 0.5 * masses_kg * v2_per_atom
    total_ke = np.sum(ke_per_atom)

    # diagnostics
    # DOF choices:
    dof_3N = 3 * N
    dof_3N_minus_COM3 = 3 * N - 3   # if you remove overall translation
    # if you have constraints (e.g. bonds fixed), reduce DOF by number_constraints

    temp_3N = (2.0 * total_ke) / (dof_3N * BOLTZ)
    temp_minus3 = (2.0 * total_ke) / (dof_3N_minus_COM3 * BOLTZ)

    mean_ke_per_dof = total_ke / dof_3N_minus_COM3   # choose one denominator for comparison
    expected_ke_per_dof_300 = 0.5 * BOLTZ * 300.0

    rms_speed = np.sqrt(np.mean(v2_per_atom))
    mean_speed = np.mean(np.sqrt(v2_per_atom))

    if print_out:
        print("N atoms:", N)
        print("Sample masses (amu):", masses_amu[:6])
        print("Sample masses (kg):", masses_kg[:6])
        print("v_com (m/s):", v_com)
        print("RMS speed (m/s):", rms_speed)
        print("Mean speed (m/s):", mean_speed)
        print("Total KE (J):", total_ke)
        print("Mean KE per DOF (J):", mean_ke_per_dof)
        print("Expected <KE> per DOF at 300K (J):", expected_ke_per_dof_300)
        print("Ratio (observed / expected) per-DOF:", mean_ke_per_dof / expected_ke_per_dof_300)
        print("Temperature using DOF = 3N ->", temp_3N, "K")
        print("Temperature using DOF = 3N-3 ->", temp_minus3, "K")
        print("If you expect 300K but you get ~200K, ratio temp_observed/300K =", float(temp_minus3)/300.0)
    return {
        'v_com': v_com,
        'rms_speed': rms_speed,
        'mean_speed': mean_speed,
        'total_ke': total_ke,
        'temp_3N': float(temp_3N),
        'temp_minus3': float(temp_minus3),
        'mean_ke_per_dof': mean_ke_per_dof,
        'expected_ke_per_dof_300': expected_ke_per_dof_300
    }


# Run diagnostics on first frame (or a few frames)
res = analyze_frame(velocity_data_list[0], masses_kg, masses_amu)
# Out:
# N atoms: 5047
# Sample masses (amu): [12.01078 12.01078 15.99943 12.01078 12.01078 14.00672]
# Sample masses (kg): [1.99443694e-26 1.99443694e-26 2.65676786e-26 1.99443694e-26
#  1.99443694e-26 2.32587058e-26]
# v_com (m/s): [0. 0. 0.]
# RMS speed (m/s): 0.0
# Mean speed (m/s): 0.0
# Total KE (J): 0.0
# Mean KE per DOF (J): 0.0
# Expected <KE> per DOF at 300K (J): 2.0709735e-21
# Ratio (observed / expected) per-DOF: 0.0
# Temperature using DOF = 3N -> 0.0 K
# Temperature using DOF = 3N-3 -> 0.0 K
# If you expect 300K but you get ~200K, ratio temp_observed/300K = 0.0

# %%
states = reporter.read_thermodynamic_states()
print(len(states), len(states[0]))
for replica_idx, state in enumerate(states[0]):
    print(f"Replica {replica_idx}")
    print(state.lambda_rest_bonds, state.lambda_rest_angles, state.lambda_rest_torsions, state.lambda_rest_electrostatics, state.lambda_rest_sterics)
# Out:
# 2 16
# Replica 0
# 1.0 1.0 1.0 0.0 0.0
# Replica 1
# 0.9742801224824941 0.9742801224824941 0.9742801224824941 -0.02571987751750593 -0.050778242935496376
# Replica 2
# 0.948868643399086 0.948868643399086 0.948868643399086 -0.051131356600913946 -0.09964829757397797
# Replica 3
# 0.9237893365035003 0.9237893365035003 0.9237893365035003 -0.07621066349649974 -0.14661326176242284
# Replica 4
# 0.89906388800025 0.89906388800025 0.89906388800025 -0.10093611199974994 -0.1916841252938739
# Replica 5
# 0.8747119063974691 0.8747119063974691 0.8747119063974691 -0.1252880936025309 -0.23487908080650532
# Replica 6
# 0.8507509494580457 0.8507509494580457 0.8507509494580457 -0.14924905054195425 -0.2762228219962336
# Replica 7
# 0.8271965662646666 0.8271965662646666 0.8271965662646666 -0.17280343373533336 -0.31574584075994505
# Replica 8
# 0.8040623523896276 0.8040623523896276 0.8040623523896276 -0.19593764761037236 -0.35348373346965833
# Replica 9
# 0.7813600161815335 0.7813600161815335 0.7813600161815335 -0.2186399838184665 -0.38947652511279374
# Replica 10
# 0.7590994542409617 0.7590994542409617 0.7590994542409617 -0.2409005457590383 -0.42376801857107416
# Replica 11
# 0.7372888342484881 0.7372888342484881 0.7372888342484881 -0.2627111657515119 -0.4564051748925054
# Replica 12
# 0.7159346834239927 0.7159346834239927 0.7159346834239927 -0.2840653165760073 -0.48743752907058735
# Replica 13
# 0.6950419810292597 0.6950419810292597 0.6950419810292597 -0.30495801897074026 -0.5169166446069222
# Replica 14
# 0.6746142534704729 0.6746142534704729 0.6746142534704729 -0.3253857465295271 -0.5448956090144765
# Replica 15
# 0.6546536707079771 0.6546536707079771 0.6546536707079771 -0.3453463292920229 -0.5714285714285714
