# %%
# imports
import os
import torch
import espaloma as esp

# define or load a molecule of interest via the Open Force Field toolkit
from openff.toolkit.topology import Molecule
molecule = Molecule.from_file("bioactive_min.sdf")

# create an Espaloma Graph object to represent the molecule of interest
molecule_graph = esp.Graph(molecule)

# load pretrained model
espaloma_model = esp.get_model("latest")

# apply a trained espaloma model to assign parameters
espaloma_model(molecule_graph.heterograph)

# create an OpenMM System for the specified molecule
openmm_system = esp.graphs.deploy.openmm_system_from_graph(molecule_graph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 import os
#       3 import torch
# ----> 4 import espaloma as esp
#       6 # define or load a molecule of interest via the Open Force Field toolkit
#       7 from openff.toolkit.topology import Molecule
#
# File ~/anaconda3/envs/espaloma/lib/python3.12/site-packages/espaloma/__init__.py:6
#       1 """
#       2 espaloma
#       3 Extensible Surrogate Potential of Ab initio Learned and Optimized by Message-passing Algorithm
#       4 """
# ----> 6 from . import metrics, units, data, app, graphs, mm, nn
#       7 from .app.experiment import *
#       8 from .graphs.graph import Graph
#
# File ~/anaconda3/envs/espaloma/lib/python3.12/site-packages/espaloma/app/__init__.py:1
# ----> 1 from . import experiment, report
#
# File ~/anaconda3/envs/espaloma/lib/python3.12/site-packages/espaloma/app/experiment.py:21
#      17     def __init__(self):
#      18         super(Experiment, self).__init__()
# ---> 21 class Train(Experiment):
#      22     """Training experiment.
#      23
#      24     Parameters
#    (...)     52
#      53     """
#      55     def __init__(
#      56         self,
#      57         net,
#    (...)     65         device=torch.device("cpu"),
#      66     ):
#
# File ~/anaconda3/envs/espaloma/lib/python3.12/site-packages/espaloma/app/experiment.py:59, in Train()
#      21 class Train(Experiment):
#      22     """Training experiment.
#      23
#      24     Parameters
#    (...)     52
#      53     """
#      55     def __init__(
#      56         self,
#      57         net,
#      58         data,
# ---> 59         metrics=[esp.metrics.TypingCrossEntropy()],
#      60         optimizer=lambda net: torch.optim.Adam(net.parameters(), 1e-3),
#      61         n_epochs=100,
#      62         record_interval=1,
#      63         normalize=esp.data.normalize.ESOL100LogNormalNormalize,
#      64         scheduler=None,
#      65         device=torch.device("cpu"),
#      66     ):
#      67         super(Train, self).__init__()
#      69         # bookkeeping
#
# AttributeError: partially initialized module 'espaloma' has no attribute 'metrics' (most likely due to a circular import)
