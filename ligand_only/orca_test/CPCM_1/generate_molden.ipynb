# %%
# !/home/haolan/orca-6.1.0-f.0_linux_x86-64/bin/orca_2mkl ANI2x_0001_opt -molden
# Out:
# Reading the input file ANI2x_0001_opt.gbw               ... done
# Writing the output file ANI2x_0001_opt.molden.input     ... done
